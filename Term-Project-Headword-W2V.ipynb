# %%
import os, re
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import treebank
from nltk.corpus import dependency_treebank
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
import pprint
from nltk.parse.corenlp import CoreNLPDependencyParser
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from gensim.models import Word2Vec
import numpy as np
import re
from numpy.linalg import norm
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer

# %%
ps = PorterStemmer()
wnl = WordNetLemmatizer()
lancaster=LancasterStemmer()
sb = SnowballStemmer("english")
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %%
class Habitat:
    oid = -1
    name = ""

# %%
train_path = "./BioNLP-OST-2019_BB-norm_train/"
test_path = "./BioNLP-OST-2019_BB-norm_test/"
dev_path = "./BioNLP-OST-2019_BB-norm_dev/"
BB_train = os.listdir(train_path)
BB_test = os.listdir(test_path)
BB_dev = os.listdir(dev_path)
obp_file = "OntoBiotope_BioNLP-OST-2019.obo"

# %%
ontology = open(obp_file,encoding="utf8").read()

# %%
BB_train_a1 = sorted([name for name in BB_train if name.endswith("a1")])
BB_train_a2 = sorted([name for name in BB_train if name.endswith("a2")])
BB_train_txt = sorted([name for name in BB_train if name.endswith("txt")])

BB_dev_a1 = sorted([name for name in BB_dev if name.endswith("a1")])
BB_dev_a2 = sorted([name for name in BB_dev if name.endswith("a2")])
BB_dev_txt = sorted([name for name in BB_dev if name.endswith("txt")])

BB_test_a1 = sorted([name for name in BB_test if name.endswith("a1")])
BB_test_txt = sorted([name for name in BB_test if name.endswith("txt")])

# %%
def l_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = lancaster.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def s_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = sb.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def original_phrase(phrase):
    return phrase

# %%
def p_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = ps.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def lemmatize_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = wnl.lemmatize(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def switch_to_lower(phrase):
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = phrase[i].lower()
    phrase = " ".join(phrase)
    return phrase

# %%
def get_jaccard_sim(p1, p2, processor):
    p1 = processor(switch_to_lower(p1))
    p2 = processor(switch_to_lower(p2))
    p1, p2= p1.split(" "), p2.split(" ")
    union = set(p1+p2)
    intersection = [word for word in set(p1) if word in set(p2)]
    return len(intersection)/len(union)

# %%
phrase_reducer = lemmatize_phrase

# %%
def get_headword(phrase):
    #print(phrase)
    if phrase == phrase.upper():
        return ""
    
    parses = dep_parser.parse(phrase.split())
    triples = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses]
    
    try:
        if(len(triples) > 0 and len(triples[0]) > 0 and len(triples[0][0]) > 0 and len(triples[0][0][0]) > 0 and triples[0][0][0][0] is not None):
            return triples[0][0][0][0]
        else:
            return phrase
    except:
        return phrase

# %%
def add_documents(txt, processor):
    document = []
    #txt = processor(txt)
    sentence_list = sent_tokenize(txt)
    
    for sentence in sentence_list:
        sentence = sentence.replace('-', ' ')
        
        word_list = word_tokenize(sentence)
        word_list = [word for word in word_list if word not in stopwords.words("english") and word.isalnum()]
        for i in range(len(word_list)):
            if word_list[i].isnumeric():
                word_list[i] = "##number##"
            if word_list[i] != word_list[i].upper():
                word_list[i] = processor(word_list[i].lower())
             
        document.append(word_list)
    #print(document)
    return document

# %%
documents = []
for i in range(len(BB_train_txt)):
    txt = open(train_path + BB_train_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_dev_txt)):
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_test_txt)):
    txt = open(test_path + BB_test_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

# %%
model = Word2Vec(documents, min_count=1)

# %%
def get_phrase_embedding(phrase, model, processor):
    original_phrase = phrase
    phrase = phrase.replace('-', ' ')
    hyphenless_phrase = phrase
    phrase = nltk.word_tokenize(phrase)
    phrase = [word for word in phrase if word.lower() not in stopwords.words("english") and word.isalnum()]
    for i in range(len(phrase)):
        if phrase[i].isnumeric():
            phrase[i] = "##number##"
        if phrase[i] != phrase[i].upper():
            phrase[i] = processor(phrase[i].lower())
    #print(phrase)
    phrase_size = len(phrase)
    vec_size = len(model[list(model.wv.vocab)[0]])
    embedded_sum = np.zeros(vec_size)
    if(phrase_size == 0):
        return -1
    for word in phrase:
        if word not in list(model.wv.vocab):
            return -1
        embedded_sum = embedded_sum + np.array(model[word])
    embedded_sum = embedded_sum / phrase_size
    
    ####
    hw = get_headword(hyphenless_phrase)
    if hw == "":
        pass
        #print(hyphenless_phrase)
    else:
        hw_emb = np.array(model[processor(switch_to_lower(hw))])
        embedded_sum = (embedded_sum + hw_emb)/2
    ####
    return embedded_sum

# %%
def generate_habitat_map(processor, model):
    habitat_list = ontology.split("\n\n[Term]\n")[1:]
    habitat_map = {}
    habitat_map_originals = {}
    habitat_embeddings = {}
    for h in habitat_list:
        #new_habitat = Habitat()
        h = h.split("\n")
        oid = re.findall(r"(?<=id: OBT:)[0-9]+", h[0])[0]
        name = (re.findall(r"(?<=name: ).+", h[1])[0])
        original_name = name
        if name != name.upper():
            name = switch_to_lower(name)
            name = processor(name)
    
        habitat_map[name] = oid
        habitat_map_originals[oid] = name
        embedding = get_phrase_embedding(name, model, processor)
        if type(embedding) == type(np.array([1])):
            habitat_embeddings[name] = embedding
    
        # word2vec buraya eklenmeli 
        for h_line in h:
            if "synonym" in h_line:
                synonym_name = (re.findall(r"(?<=synonym: \").+(?=\")", h_line)[0])
                if synonym_name != synonym_name.upper():
                    synonym_name = switch_to_lower(synonym_name)
                    synonym_name = processor(synonym_name)
                if "EXACT" in h_line and synonym_name not in habitat_map:
                    habitat_map[synonym_name] = oid
                    if type(embedding) == type(np.array([1])):
                        habitat_embeddings[synonym_name] = embedding
                    
    return habitat_map, habitat_map_originals, habitat_embeddings

# %%
habitat_map, habitat_map_originals, habitat_embeddings = generate_habitat_map(phrase_reducer, model)
# Out:
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def add_habitats(a1, a2, processor, model):
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    
    
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]: 
                named_entity = (a1[a1_line].split("\t")[2])
                named_entity = named_entity.replace('-', ' ')
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                if named_entity not in habitat_map:
                    habitat_map[named_entity] = oid
                
                if habitat_map_originals[oid] not in habitat_embeddings:
                    habitat_embeddings[habitat_map_originals[oid]] = []
                
                if type(habitat_embeddings[habitat_map_originals[oid]]) == list:
                    emb = get_phrase_embedding(named_entity, model, processor)
                    if type(emb) == int:
                        print("no embedding for", named_entity)
                    habitat_embeddings[habitat_map_originals[oid]].append(emb)

# %%
for i in range(len(BB_train_txt)):    
    a1 = open(train_path + BB_train_a1[i],encoding="utf8").read()
    a2 = open(train_path + BB_train_a2[i],encoding="utf8").read()
    add_habitats(a1, a2, phrase_reducer, model)
# Out:
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
for key in habitat_embeddings:
    if type(habitat_embeddings[key]) == list:
        vec_size = len(habitat_embeddings[key][0])
        temp_vec = np.zeros(vec_size)
        for vec in habitat_embeddings[key]:
            temp_vec += vec
        temp_vec /= len(habitat_embeddings[key])
        habitat_embeddings[key] = temp_vec

# %%
def predict_habitats_exact_matching(a1, txt, a1_name, processor, pred_file_name):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            cands += 1
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + "---exact"
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                found = True
            else:
                #print(name)
                pre_named_entity = get_headword(name)
                #print(pre_named_entity)
                named_entity = processor(pre_named_entity)
                if named_entity in habitat_map:
                    matches += 1
                    match = name + " - " + habitat_map[named_entity] + "---headwordexact"
                    print(match)
                    match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                    found = True
        if found:
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
            count += 1
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def predict_habitats(a1, txt, a1_name, processor, pred_file_name, model):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] + " ---exact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
             
            #print(name)
            pre_named_entity = get_headword(name)
            #print(pre_named_entity)
            named_entity = processor(pre_named_entity)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] +" ---headwordexact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                found = True
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
            
            cands += 1
            name = (line.split("\t")[2])
            name = name.replace("-", " ")
            named_entity = name
            entity_vec = get_phrase_embedding(named_entity, model, processor)
            match_id = ""
            largest_prod = 0
            if type(entity_vec) != int:
                largest_prod = np.dot(entity_vec, habitat_embeddings[list(habitat_embeddings)[0]])/(norm(entity_vec)*norm(habitat_embeddings[list(habitat_embeddings)[0]]))
                match_id = habitat_map[list(habitat_embeddings)[0]]
                for habitat in habitat_embeddings:
                    prod = np.dot(entity_vec,habitat_embeddings[habitat])/(norm(entity_vec)*norm(habitat_embeddings[habitat]))
                    if prod > largest_prod:
                        largest_prod = prod
                        match_id = habitat_map[habitat]
            else:
                print("Doc:", a1_name," no embedding for:", named_entity)
                continue
                
            match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
            match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
            #print(line.split("\t")[0], "matched with w2v")
            #print(match_list)
            #print(match)
            
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
            count += 1
            
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
annotations_test = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    pred_file_name = "./dev_preds/" + BB_dev_a2[i]
    annotations_test[BB_dev_a1[i]] = predict_habitats(a1, txt, BB_dev_a1[i], phrase_reducer, pred_file_name, model)
# Out:
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# MALT
# MALT
# CD20
# CD3
# MALT
# CD20
# CD3
# PALCAM
# LPM
# HCLA
# HMDM
# PMN
# PMN
# PMN
# PMN
# PMN
# PMN
# PMN
# MSM
# SB

# %%
def test_habitats(a1, a2, processor):
    
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    match_list = {}
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]:
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                match_list[t] = [oid, named_entity]
    return match_list

# %%
dev_a2 = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    a2 = open(dev_path + BB_dev_a2[i],encoding="utf8").read()
    dev_a2[BB_dev_a1[i]] = test_habitats(a1,a2, phrase_reducer)

# %%
true_pred_count = 0
false_pred_count = 0
total_count = 0
for key in dev_a2:
    """print()
    print(key)
    print(dev_a2[key])
    print("**************")"""
    total_count += len(dev_a2[key])
    if key in annotations_test:
        for pred in annotations_test[key]:            
            if annotations_test[key][pred][0] == dev_a2[key][pred][0]:
                true_pred_count += 1
                if annotations_test[key][pred][2] == "w2v":
                    print(key)
                    print(True)
                    #print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred], " Type:", annotations_test[key][pred][2])
                    print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                    print("Cosine Similarity:", annotations_test[key][pred][3])
                    print()
            else:
                if annotations_test[key][pred][2] == "w2v":
                    print(key)
                    print(False)
                    #print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred], " Type:", annotations_test[key][pred][2])
                    print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                    print("Cosine Similarity:", annotations_test[key][pred][3])
                    print()
                false_pred_count += 1
# Out:
# BB-norm-10496597.a1
# False
# Word: gastric mucosal  Prediction: gastric acid  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 0.9801690731013221
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: plant organ  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.7070052062376516
#
# BB-norm-10496597.a1
# False
# Word: gastric MALT  Prediction: antibiotic-containing medium  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.9651657054653775
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: plant organ  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.7070052062376516
#
# BB-norm-10496597.a1
# False
# Word: CD20  Prediction: stomach  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.6664793356071138
#
# BB-norm-10496597.a1
# False
# Word: CD3  Prediction: surgical device  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.5360062872055927
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: plant organ  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.7070052062376516
#
# BB-norm-10496597.a1
# False
# Word: lymphocytic  Prediction: taleggio  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.48461138476968374
#
# BB-norm-10496597.a1
# False
# Word: lymphocytic  Prediction: taleggio  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.48461138476968374
#
# BB-norm-10496597.a1
# False
# Word: Lymphoepithelial  Prediction: antagonist  Real: epithelium  Type: w2v
# Cosine Similarity: 0.3142902904590708
#
# BB-norm-10496597.a1
# False
# Word: gastric biopsies  Prediction: surface water  Real: medical sample  Type: w2v
# Cosine Similarity: 0.9679826446624196
#
# BB-norm-10496597.a1
# False
# Word: CD20  Prediction: stomach  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.6664793356071138
#
# BB-norm-10496597.a1
# False
# Word: CD3  Prediction: surgical device  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.5360062872055927
#
# BB-norm-10496597.a1
# False
# Word: gastric MALT  Prediction: antibiotic-containing medium  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.9651657054653775
#
# BB-norm-11989773.a1
# False
# Word: food handlers  Prediction: surface sediment  Real: worker  Type: w2v
# Cosine Similarity: 0.9502515993866355
#
# BB-norm-11989773.a1
# False
# Word: PALCAM  Prediction: wound  Real: agar  Type: w2v
# Cosine Similarity: 0.2918436765139538
#
# BB-norm-11989773.a1
# False
# Word: LPM  Prediction: hospital equipment  Real: agar  Type: w2v
# Cosine Similarity: 0.40207281068993833
#
# BB-norm-11989773.a1
# False
# Word: HCLA  Prediction: oil contaminated sediment  Real: agar  Type: w2v
# Cosine Similarity: 0.31506456901882307
#
# BB-norm-11989773.a1
# False
# Word: food handler  Prediction: surface sediment  Real: worker  Type: w2v
# Cosine Similarity: 0.9502515993866355
#
# BB-norm-11989773.a1
# False
# Word: food handlers  Prediction: surface sediment  Real: worker  Type: w2v
# Cosine Similarity: 0.9502515993866355
#
# BB-norm-12109661.a1
# False
# Word: control group  Prediction: enterocyte  Real: child  Type: w2v
# Cosine Similarity: 0.9983078096354611
#
# BB-norm-1214327.a1
# False
# Word: fish samples  Prediction: medical sample  Real: fish  Type: w2v
# Cosine Similarity: 0.9993035024786127
#
# BB-norm-14633026.a1
# False
# Word: Culex pipiens molestus  Prediction: periodontal pocket  Real: mosquito  Type: w2v
# Cosine Similarity: 0.41785094395149547
#
# BB-norm-15293611.a1
# False
# Word: paediatric cystic fibrosis units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9969789640400192
#
# BB-norm-15293611.a1
# False
# Word: paediatric  Prediction: animal based juice  Real: child  Type: w2v
# Cosine Similarity: 0.8428008343766537
#
# BB-norm-15293611.a1
# False
# Word: adult cystic fibrosis units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.997490956179283
#
# BB-norm-15293611.a1
# False
# Word: cystic fibrosis (CF) units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9970674745370254
#
# BB-norm-15293611.a1
# False
# Word: regional adult CF units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9973749126767136
#
# BB-norm-15293611.a1
# False
# Word: regional paediatric CF units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9969839970799722
#
# BB-norm-15293611.a1
# False
# Word: paediatric  Prediction: animal based juice  Real: child  Type: w2v
# Cosine Similarity: 0.8428008343766537
#
# BB-norm-15618837.a1
# False
# Word: Gastric biopsies  Prediction: surface water  Real: medical sample  Type: w2v
# Cosine Similarity: 0.9679826446624196
#
# BB-norm-16273411.a1
# False
# Word: neonatal  Prediction: starter culture  Real: newborn infant  Type: w2v
# Cosine Similarity: 0.9088659137949326
#
# BB-norm-16273411.a1
# False
# Word: 38 year old secondary recurrent aborter  Prediction: surface of cheese  Real: pregnant woman  Type: w2v
# Cosine Similarity: 0.994192242095115
#
# BB-norm-16458564.a1
# False
# Word: study population  Prediction: immunodeficient person  Real: child  Type: w2v
# Cosine Similarity: 0.9972751399709896
#
# BB-norm-16458564.a1
# False
# Word: age matched healthy controls  Prediction: probiotic food  Real: healthy person  Type: w2v
# Cosine Similarity: 0.9685676048208306
#
# BB-norm-16458564.a1
# False
# Word: mucous  Prediction: conjugation phenotype  Real: mucus  Type: w2v
# Cosine Similarity: 0.5636721255171412
#
# BB-norm-16458564.a1
# False
# Word: piped water  Prediction: fracture water  Real: drinking water  Type: w2v
# Cosine Similarity: 0.9336414332400844
#
# BB-norm-16458564.a1
# False
# Word: fresh water supply  Prediction: hospital water supply  Real: drinking water supply  Type: w2v
# Cosine Similarity: 0.9906730878129113
#
# BB-norm-16458564.a1
# True
# Word: unhygienic septic tank  Prediction: septic tank  Real: septic tank  Type: w2v
# Cosine Similarity: 0.9816245264005977
#
# BB-norm-16514151.a1
# False
# Word: rich medium  Prediction: liquid medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.998874933541186
#
# BB-norm-18094887.a1
# False
# Word: Adoratopsylla antiquorum antiquorum  Prediction: public transport  Real: flea  Type: w2v
# Cosine Similarity: 0.3920350012811781
#
# BB-norm-18094887.a1
# False
# Word: Ctenocephalides felis felis  Prediction: yeast extract  Real: flea  Type: w2v
# Cosine Similarity: 0.8604794948140897
#
# BB-norm-18094887.a1
# False
# Word: Polygenis atopus  Prediction: ciprofloxacin tolerant  Real: flea  Type: w2v
# Cosine Similarity: 0.6162202442633754
#
# BB-norm-18094887.a1
# False
# Word: Polygenis rimatus  Prediction: scimudin  Real: flea  Type: w2v
# Cosine Similarity: 0.6023290498625503
#
# BB-norm-18094887.a1
# False
# Word: Polygenis roberti roberti  Prediction: epithelial layer  Real: flea  Type: w2v
# Cosine Similarity: 0.5704665555824214
#
# BB-norm-18094887.a1
# False
# Word: Polygenis tripus  Prediction: norfloxacin tolerant  Real: flea  Type: w2v
# Cosine Similarity: 0.5829383927810327
#
# BB-norm-18094887.a1
# False
# Word: Rhopalopsyllus lugubris  Prediction: home-made food  Real: flea  Type: w2v
# Cosine Similarity: 0.5867911541310048
#
# BB-norm-18094887.a1
# False
# Word: Rhopalopsyllus lutzi lutzi  Prediction: ripening room  Real: flea  Type: w2v
# Cosine Similarity: 0.7492663243699967
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma aureolatum  Prediction: primate  Real: tick  Type: w2v
# Cosine Similarity: 0.4791791225728049
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma cajennense  Prediction: liver  Real: tick  Type: w2v
# Cosine Similarity: 0.6023588017921845
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma dubitatum  Prediction: cellar  Real: tick  Type: w2v
# Cosine Similarity: 0.5379870677319673
#
# BB-norm-18094887.a1
# False
# Word: Ixodes loricatus  Prediction: urinary tract  Real: tick  Type: w2v
# Cosine Similarity: 0.5157046017978839
#
# BB-norm-18694716.a1
# False
# Word: LTQ Orbitrap high resolution mass spectrometer  Prediction: human milk  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.9669634813875406
#
# BB-norm-18694716.a1
# False
# Word: mixtures of pure compounds and uniformly 13C labeled cell extracts  Prediction: cell  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9878595544647137
#
# BB-norm-18694716.a1
# False
# Word: LTQ Obitrap  Prediction: modified-atmosphere-packed food  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.5259203629384982
#
# BB-norm-19339076.a1
# True
# Word: lactose free M17 medium supplemented with glucose only (GM17)  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990622230113833
#
# BB-norm-19339076.a1
# True
# Word: lactose free M17 medium supplemented with lactose only (LM17)  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9988354647859238
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990419455208672
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990068056983167
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990419455208672
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990068056983167
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990419455208672
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9990068056983167
#
# BB-norm-19552770.a1
# False
# Word: Perdix perdix  Prediction: human body  Real: partridge  Type: w2v
# Cosine Similarity: 0.8146429941610067
#
# BB-norm-19552770.a1
# False
# Word: Perdix perdix  Prediction: human body  Real: partridge  Type: w2v
# Cosine Similarity: 0.8146429941610067
#
# BB-norm-19552770.a1
# True
# Word: Cloacal swabs of partridges  Prediction: rectal swab  Real: rectal swab  Type: w2v
# Cosine Similarity: 0.9107590092785924
#
# BB-norm-19552770.a1
# False
# Word: Cloacal  Prediction: machinery  Real: cloaca  Type: w2v
# Cosine Similarity: 0.3219447470914143
#
# BB-norm-19552770.a1
# False
# Word: cloacal swabs  Prediction: vaginal swab  Real: rectal swab  Type: w2v
# Cosine Similarity: 0.9099299404644636
#
# BB-norm-19552770.a1
# False
# Word: younger ones  Prediction: enterocyte  Real: livestock  Type: w2v
# Cosine Similarity: 0.9973169611704095
#
# BB-norm-19552770.a1
# False
# Word: animal species  Prediction: agricultural specie  Real: animal  Type: w2v
# Cosine Similarity: 0.9998251155706653
#
# BB-norm-20174624.a1
# True
# Word: human innate immune system  Prediction: innate immune system  Real: innate immune system  Type: w2v
# Cosine Similarity: 0.9997959444972253
#
# BB-norm-20174624.a1
# False
# Word: PMNs  Prediction: malt  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.6170196648314905
#
# BB-norm-20174624.a1
# False
# Word: HMDM  Prediction: liquid egg mixed  Real: macrophage  Type: w2v
# Cosine Similarity: 0.3705271731128002
#
# BB-norm-20174624.a1
# False
# Word: HMDMs  Prediction: fermented beverage  Real: macrophage  Type: w2v
# Cosine Similarity: 0.4301008551290639
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: human PMNs  Prediction: adult human  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9880532780863546
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: laboratory animal  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9442826675425152
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: extreme high temperature environment  Real: intestine  Type: w2v
# Cosine Similarity: 0.998391080875128
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stools  Prediction: gram-positive  Real: healthy person  Type: w2v
# Cosine Similarity: 0.9799927320610373
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: extreme high temperature environment  Real: intestine  Type: w2v
# Cosine Similarity: 0.998391080875128
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stools  Prediction: gram-positive  Real: healthy person  Type: w2v
# Cosine Similarity: 0.9799927320610373
#
# BB-norm-20580604.a1
# False
# Word: water content of the stools  Prediction: intestinal content  Real: body fluid  Type: w2v
# Cosine Similarity: 0.9954358623345375
#
# BB-norm-20580604.a1
# False
# Word: probiotic group  Prediction: egg cell  Real: adult human  Type: w2v
# Cosine Similarity: 0.9980305490153609
#
# BB-norm-20580604.a1
# False
# Word: placebo group  Prediction: egg cell  Real: adult human  Type: w2v
# Cosine Similarity: 0.9980619348146755
#
# BB-norm-20580604.a1
# False
# Word: probiotic groups  Prediction: egg cell  Real: adult human  Type: w2v
# Cosine Similarity: 0.9980305490153609
#
# BB-norm-20580604.a1
# False
# Word: placebo groups  Prediction: egg cell  Real: adult human  Type: w2v
# Cosine Similarity: 0.9980619348146755
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stool  Prediction: gram-positive  Real: healthy person  Type: w2v
# Cosine Similarity: 0.9799927320610373
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: blood serum  Real: anus  Type: w2v
# Cosine Similarity: 0.8150756235418893
#
# BB-norm-21270066.a1
# False
# Word: perianal ulceration  Prediction: antibiotic sensitive  Real: ulcer  Type: w2v
# Cosine Similarity: 0.8038493988963455
#
# BB-norm-21270066.a1
# False
# Word: HIV positive men who have sex with men  Prediction: catalase positive  Real: man  Type: w2v
# Cosine Similarity: 0.9543205563600534
#
# BB-norm-21270066.a1
# False
# Word: men  Prediction: plant residue  Real: man  Type: w2v
# Cosine Similarity: 0.589053233050283
#
# BB-norm-21270066.a1
# False
# Word: MSM  Prediction: duodenal ulcer  Real: ill person  Type: w2v
# Cosine Similarity: 0.8455169962877878
#
# BB-norm-21270066.a1
# False
# Word: rectal  Prediction: nasopharyngeal mucosa  Real: rectum  Type: w2v
# Cosine Similarity: 0.6554079546011784
#
# BB-norm-21270066.a1
# False
# Word: MSM attending sexually transmitted infection clinics  Prediction: fermented fresh cheese  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9859024730875985
#
# BB-norm-21270066.a1
# False
# Word: anorectal  Prediction: paired  Real: rectum  Type: w2v
# Cosine Similarity: 0.23866161173433706
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: blood serum  Real: anus  Type: w2v
# Cosine Similarity: 0.8150756235418893
#
# BB-norm-21270066.a1
# False
# Word: rectal  Prediction: nasopharyngeal mucosa  Real: rectum  Type: w2v
# Cosine Similarity: 0.6554079546011784
#
# BB-norm-21270066.a1
# False
# Word: MSM with proctitis  Prediction: duodenal ulcer  Real: ill person  Type: w2v
# Cosine Similarity: 0.8548875250273265
#
# BB-norm-21270066.a1
# False
# Word: MSM with perianal ulcer disease  Prediction: duodenal ulcer  Real: ill person  Type: w2v
# Cosine Similarity: 0.9885439775342378
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: blood serum  Real: anus  Type: w2v
# Cosine Similarity: 0.8150756235418893
#
# BB-norm-21543877.a1
# False
# Word: human population  Prediction: immunodeficient person  Real: human  Type: w2v
# Cosine Similarity: 0.9971617498451394
#
# BB-norm-21695078.a1
# False
# Word: female mouse model of genital tract chlamydia infection  Prediction: enterocyte  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 0.9970462482630468
#
# BB-norm-21695078.a1
# False
# Word: oviduct  Prediction: sulfur oxidizing  Real: urogenital tract part  Type: w2v
# Cosine Similarity: 0.3739030234977769
#
# BB-norm-21695078.a1
# True
# Word: mucosal  Prediction: mucosal tissue  Real: mucosal tissue  Type: w2v
# Cosine Similarity: 0.9030603650996386
#
# BB-norm-21695078.a1
# False
# Word: intranasal  Prediction: norfloxacin sensitive  Real: nose  Type: w2v
# Cosine Similarity: 0.5967235262880335
#
# BB-norm-21695078.a1
# False
# Word: T cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-21695078.a1
# True
# Word: mucosal  Prediction: mucosal tissue  Real: mucosal tissue  Type: w2v
# Cosine Similarity: 0.9030603650996386
#
# BB-norm-21894542.a1
# False
# Word: world's oceans  Prediction: open-ocean  Real: marine water  Type: w2v
# Cosine Similarity: 0.916867088131601
#
# BB-norm-21894542.a1
# False
# Word: bacterial flora  Prediction: gastric acid  Real: microflora  Type: w2v
# Cosine Similarity: 0.9922908373488369
#
# BB-norm-21894542.a1
# True
# Word: marine organisms  Prediction: living organism  Real: living organism  Type: w2v
# Cosine Similarity: 0.9948882479194894
#
# BB-norm-25114119.a1
# False
# Word: aerosolized  Prediction: ice cream  Real: aerosol  Type: w2v
# Cosine Similarity: 0.28131954394307757
#
# BB-norm-351567.a1
# False
# Word: cellophane membrane disks  Prediction: starter culture  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.9294841634402966
#
# BB-norm-460951.a1
# False
# Word: pulmonary  Prediction: formaggio di fossa  Real: lung  Type: w2v
# Cosine Similarity: 0.7874990255967753
#
# BB-norm-460951.a1
# False
# Word: pulmonary  Prediction: formaggio di fossa  Real: lung  Type: w2v
# Cosine Similarity: 0.7874990255967753
#
# BB-norm-9521147.a1
# False
# Word: microtiter plates  Prediction: patient with infectious disease  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.9524026139962253
#
# BB-norm-9553794.a1
# False
# Word: vacuum  packed cold smoked salmon stored at 5 degrees C  Prediction: antimicrobial activity  Real: salmon meat  Type: w2v
# Cosine Similarity: 0.9918940150049292
#
# BB-norm-9553794.a1
# False
# Word: spoiled cold smoked salmon  Prediction: spoiled food  Real: salmon meat  Type: w2v
# Cosine Similarity: 0.8662557233627838
#
# BB-norm-9553794.a1
# False
# Word: Gram negative flora  Prediction: gram-negative  Real: microflora  Type: w2v
# Cosine Similarity: 0.9941345315727511
#
# BB-norm-9553794.a1
# False
# Word: vacuum packages  Prediction: mucous membrane  Real: vacuum-packed food  Type: w2v
# Cosine Similarity: 0.700904098724093
#
# BB-norm-9553794.a1
# False
# Word: Gram negative flora  Prediction: gram-negative  Real: microflora  Type: w2v
# Cosine Similarity: 0.9941345315727511
#
# BB-norm-F-14624315-000.a1
# False
# Word: Maasdammer  Prediction: ubiquitous  Real: semi soft cheese  Type: w2v
# Cosine Similarity: 0.3109585347955344
#
# BB-norm-F-20167385-000.a1
# True
# Word: Casera  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9976604663687701
#
# BB-norm-F-20167385-003.a1
# True
# Word: Casera  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9976604663687701
#
# BB-norm-F-20167385-003.a1
# True
# Word: Casera  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9976604663687701
#
# BB-norm-F-20167385-003.a1
# True
# Word: Casera cheese surface  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999611336328975
#
# BB-norm-F-20167385-004.a1
# False
# Word: SB  Prediction: fish  Real: agar  Type: w2v
# Cosine Similarity: 0.5927261071047388
#
# BB-norm-F-20167385-004.a1
# False
# Word: Gorgonzola surfaces  Prediction: mucosal surface  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9998075479246558
#
# BB-norm-F-20167385-004.a1
# False
# Word: Scimudin surfaces  Prediction: mucosal surface  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9998376871487036
#
# BB-norm-F-20167385-004.a1
# False
# Word: Taleggio surfaces  Prediction: mucosal surface  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.999819207406459
#
# BB-norm-F-20167385-004.a1
# True
# Word: Casera  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9976604663687701
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of Taleggio  cheeses  Prediction: surface of cheese  Real: microflora  Type: w2v
# Cosine Similarity: 0.9980461290410294
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of Gorgonzola cheeses  Prediction: ripened cheese  Real: microflora  Type: w2v
# Cosine Similarity: 0.9980061734218372
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of Formaggio di Fossa cheeses  Prediction: surface of cheese  Real: microflora  Type: w2v
# Cosine Similarity: 0.9973534605131626
#
# BB-norm-F-20167385-008.a1
# False
# Word: white mould rind  Prediction: fruit rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9985206942145018
#
# BB-norm-F-20167385-008.a1
# True
# Word: Casera Valtellina  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9261652120317367
#
# BB-norm-F-20167385-008.a1
# False
# Word: rind  Prediction: fruit rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9993965374856745
#
# BB-norm-F-20167385-009.a1
# True
# Word: Casera cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999611336328975
#
# BB-norm-F-20167385-009.a1
# True
# Word: Gorgonzola cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999668085787393
#
# BB-norm-F-20167385-009.a1
# True
# Word: Scimudin cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999645332077711
#
# BB-norm-F-20167385-010.a1
# True
# Word: rind of Gorgonzola cheeses  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9998955741874527
#
# BB-norm-F-20167385-010.a1
# True
# Word: rind of Scimudin cheeses  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9998863625453489
#
# BB-norm-F-20167385-010.a1
# True
# Word: surface of Gobbeen cheese  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.999958015232281
#
# BB-norm-F-20167385-011.a1
# True
# Word: Fontina cheese surface  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999633470841947
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola rind  Prediction: food rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9989526409001492
#
# BB-norm-F-20167385-011.a1
# False
# Word: Taleggio rind  Prediction: food rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.998731923411381
#
# BB-norm-F-20167385-011.a1
# True
# Word: surface of Gorgonzola cheeses  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999668085787393
#
# BB-norm-F-20167385-011.a1
# True
# Word: surface of Scimudin cheeses  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999645332077711
#
# BB-norm-F-20167385-011.a1
# False
# Word: Scimudin surfaces  Prediction: mucosal surface  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9998376871487036
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola surfaces  Prediction: mucosal surface  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9998075479246558
#
# BB-norm-F-20167385-011.a1
# False
# Word: Fontina rind  Prediction: fruit rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9988986691659834
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola rinds  Prediction: food rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9989526409001492
#
# BB-norm-F-20167385-014.a1
# True
# Word: surface of Formaggio di  Fossa cheese  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9999203702114485
#
# BB-norm-F-25036636-001.a1
# False
# Word: moist bloomy rinds  Prediction: food rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9985305461590936
#
# BB-norm-F-25036636-001.a1
# False
# Word: dry natural rinds  Prediction: food rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9990348832859415
#
# BB-norm-F-25036636-005.a1
# False
# Word: rinds  Prediction: fruit rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9993965374856745

# %%
recall = true_pred_count/total_count
recall
# Out:
# 0.5442622950819672

# %%
precision = true_pred_count/(true_pred_count + false_pred_count)
precision
# Out:
# 0.5442622950819672

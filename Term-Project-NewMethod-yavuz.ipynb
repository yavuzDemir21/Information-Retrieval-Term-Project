# %%
import os, re
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import treebank
from nltk.corpus import dependency_treebank
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
import pprint
from nltk.parse.corenlp import CoreNLPDependencyParser
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from gensim.models import Word2Vec

# %%
ps = PorterStemmer()
wnl = WordNetLemmatizer()
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %%
class Habitat:
    oid = -1
    name = ""

# %%
train_path = "./BioNLP-OST-2019_BB-norm_train/"
test_path = "./BioNLP-OST-2019_BB-norm_test/"
dev_path = "./BioNLP-OST-2019_BB-norm_dev/"
BB_train = os.listdir(train_path)
BB_test = os.listdir(test_path)
BB_dev = os.listdir(dev_path)
obp_file = "OntoBiotope_BioNLP-OST-2019.obo"

# %%
ontology = open(obp_file,encoding="utf8").read()

# %%
BB_train_a1 = sorted([name for name in BB_train if name.endswith("a1")])
BB_train_a2 = sorted([name for name in BB_train if name.endswith("a2")])
BB_train_txt = sorted([name for name in BB_train if name.endswith("txt")])

BB_dev_a1 = sorted([name for name in BB_dev if name.endswith("a1")])
BB_dev_a2 = sorted([name for name in BB_dev if name.endswith("a2")])
BB_dev_txt = sorted([name for name in BB_dev if name.endswith("txt")])

BB_test_a1 = sorted([name for name in BB_test if name.endswith("a1")])
BB_test_txt = sorted([name for name in BB_test if name.endswith("txt")])

# %%
def original_phrase(phrase):
    return phrase

# %%
def stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        phrase[i] = ps.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def lemmatize_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        phrase[i] = wnl.lemmatize(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def get_headword(phrase):
    #print(phrase)
    if phrase == phrase.upper():
        return ""
    
    parses = dep_parser.parse(phrase.split())
    triples = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses]
    
    try:
        if(len(triples) > 0 and len(triples[0]) > 0 and len(triples[0][0]) > 0 and len(triples[0][0][0]) > 0 and triples[0][0][0][0] is not None):
            return triples[0][0][0][0]
        else:
            return phrase
    except:
        return phrase

# %%
phrase_reducer = lemmatize_phrase

# %%
def generate_habitat_map(processor):
    habitat_list = ontology.split("\n\n[Term]\n")[1:]
    habitat_map = {}
    habitat_map_originals = {}
    for h in habitat_list:
        #new_habitat = Habitat()
        h = h.split("\n")
        oid = re.findall(r"(?<=id: OBT:)[0-9]+", h[0])[0]
        name = (re.findall(r"(?<=name: ).+", h[1])[0])
        if name != name.upper():
            name = name.lower()
            name = processor(name)
    
        habitat_map[name] = oid
        habitat_map_originals[oid] = name
    
        for h_line in h:
            if "synonym" in h_line:
                synonym_name = (re.findall(r"(?<=synonym: \").+(?=\")", h_line)[0])
                if synonym_name != synonym_name.upper():
                    synonym_name = synonym_name.lower()
                    synonym_name = processor(synonym_name)
                if "EXACT" in h_line and synonym_name not in habitat_map:
                    habitat_map[synonym_name] = oid
    return habitat_map, habitat_map_originals

# %%
habitat_map, habitat_map_originals = generate_habitat_map(phrase_reducer)

# %%
def add_habitats(a1, a2, processor):
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]: 
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = named_entity.lower()
                    named_entity = processor(named_entity)
                if named_entity not in habitat_map:
                    habitat_map[named_entity] = oid
                
                print(habitat_map_originals[oid], " ---- ", named_entity)
                
                    #print("Newly added entity:", named_entity, oid)
                    #print("Original entity:", habitat_map_originals[oid])

# %%
add_habitats(open(train_path + BB_train_a1[0],encoding="utf8").read(),\
             open(train_path + BB_train_a2[0],encoding="utf8").read(),\
             phrase_reducer)
# Out:
# nutrient broth  ----  selective broth based on hypertonic strontium chloride
# nutrient broth  ----  selective broth based on the bi-selenite ion
# egg and egg product  ----  egg product
# whole egg  ----  egg
# whole egg  ----  egg
# egg and egg product  ----  egg pulp
# nutrient broth  ----  strontium chloride m broth
# nutrient broth  ----  strontium selenite broth
# nutrient broth  ----  strontium selenite a broth
# nutrient broth  ----  bi-selenite based medium
# egg and egg product  ----  egg product
# whole egg  ----  egg
# nutrient broth  ----  strontium chloride m broth

# %%
for i in range(len(BB_train_txt)):    
    a1 = open(train_path + BB_train_a1[i],encoding="utf8").read()
    a2 = open(train_path + BB_train_a2[i],encoding="utf8").read()
    add_habitats(a1, a2, phrase_reducer)

# %%
def predict_habitats_exact_matching(a1, txt, a1_name, processor, pred_file_name):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            cands += 1
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = name.lower()
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + "---exact"
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                found = True
            else:
                #print(name)
                pre_named_entity = get_headword(name)
                #print(pre_named_entity)
                named_entity = processor(pre_named_entity)
                if named_entity in habitat_map:
                    matches += 1
                    match = name + " - " + habitat_map[named_entity] + "---headwordexact"
                    print(match)
                    match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                    found = True
        if found:
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
            count += 1
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def add_documents(txt, processor):
    document = []
    txt = processor(txt)
    sentence_list = sent_tokenize(txt)
    
    for sentence in sentence_list:
        word_list = word_tokenize(sentence)
        word_list = [processor(word) for word in word_list if word not in stopwords.words("english") and word.isalnum()]
        for i in range(len(word_list)):
            if word_list[i].isnumeric():
                word_list[i] = "##number##"
        document.append(word_list)
    #print(document)
    return document

# %%
documents = []
for i in range(len(BB_train_txt)):
    txt = open(train_path + BB_train_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

for i in range(len(BB_dev_txt)):
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

for i in range(len(BB_test_txt)):
    txt = open(test_path + BB_test_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

# %%
open(train_path + BB_train_a1[0],encoding="utf8").read().split('\n')
# Out:
# ['T1\tTitle 0 141\tAn evaluation of selective broths based on the bi-selenite ion and on hypertonic strontium chloride in Salmonellae detection in egg products.',
#  'T2\tParagraph 142 579\tOf the 104 isolations of Salmonella sp. from egg pulp, 97 were obtained from strontium chloride M broth, 42 from strontium selenite broth and 57 from strontium selenite A broth. The results suggest that the first medium may be used more successfully than bi-selenite based media for enrichment and subsequent detection of salmonellae in egg products; however, the growth of S. pullorum was not satisfactory in strontium chloride M broth.',
#  'T3\tHabitat 17 39;67 99\tselective broths based on hypertonic strontium chloride',
#  'T4\tHabitat 17 62\tselective broths based on the bi-selenite ion',
#  'T5\tMicroorganism 103 114\tSalmonellae',
#  'T6\tHabitat 128 140\tegg products',
#  'T7\tHabitat 128 131\tegg',
#  'T8\tMicroorganism 167 177\tSalmonella',
#  'T9\tHabitat 187 190\tegg',
#  'T10\tHabitat 187 195\tegg pulp',
#  'T11\tHabitat 219 245\tstrontium chloride M broth',
#  'T12\tHabitat 255 279\tstrontium selenite broth',
#  'T13\tHabitat 292 318\tstrontium selenite A broth',
#  'T14\tHabitat 397 420\tbi-selenite based media',
#  'T15\tMicroorganism 464 475\tsalmonellae',
#  'T16\tHabitat 479 491\tegg products',
#  'T17\tHabitat 479 482\tegg',
#  'T18\tMicroorganism 516 527\tS. pullorum',
#  'T19\tHabitat 552 578\tstrontium chloride M broth',
#  '']

# %%
open(train_path + BB_train_a2[0],encoding="utf8").read().split('\n')
# Out:
# ['N1\tOntoBiotope Annotation:T3 Referent:OBT:000360',
#  'N2\tOntoBiotope Annotation:T4 Referent:OBT:000360',
#  'N3\tNCBI_Taxonomy Annotation:T5 Referent:590',
#  'N4\tOntoBiotope Annotation:T6 Referent:OBT:001086',
#  'N5\tOntoBiotope Annotation:T7 Referent:OBT:001847',
#  'N6\tNCBI_Taxonomy Annotation:T8 Referent:599',
#  'N7\tOntoBiotope Annotation:T9 Referent:OBT:001847',
#  'N8\tOntoBiotope Annotation:T10 Referent:OBT:001086',
#  'N9\tOntoBiotope Annotation:T11 Referent:OBT:000360',
#  'N10\tOntoBiotope Annotation:T12 Referent:OBT:000360',
#  'N11\tOntoBiotope Annotation:T13 Referent:OBT:000360',
#  'N12\tOntoBiotope Annotation:T14 Referent:OBT:000360',
#  'N13\tNCBI_Taxonomy Annotation:T15 Referent:590',
#  'N14\tOntoBiotope Annotation:T16 Referent:OBT:001086',
#  'N15\tOntoBiotope Annotation:T17 Referent:OBT:001847',
#  'N16\tNCBI_Taxonomy Annotation:T18 Referent:605',
#  'N17\tOntoBiotope Annotation:T19 Referent:OBT:000360',
#  '']

# %%
habitat_map
# Out:
# {'fermented cheese': '003381',
#  'enriched dough': '002017',
#  'lean dough': '002100',
#  'fermented cereal-based product': '003144',
#  'crusty bread': '002417',
#  'fresh cheese': '002043',
#  'whey cheese': '003440',
#  'brined cheese': '003406',
#  'processed cheese': '002202',
#  'feta': '003448',
#  'streched curd cheese': '003432',
#  'pasta filata': '003432',
#  'plastic curd cheese': '003432',
#  'pulled-curd cheese': '003432',
#  'mozzarella': '003452',
#  'caciocavallo': '003467',
#  'ricotta': '003456',
#  'brocciu': '003443',
#  'schabziger': '003457',
#  'sapsago': '003521',
#  'sérac': '003457',
#  'ripened cheese': '003428',
#  'soft cheese': '003459',
#  'semi soft cheese': '003458',
#  'semi hard cheese': '003458',
#  'hard cheese': '003450',
#  'extra hard cheese': '003489',
#  'american cheese': '002319',
#  'velveeta': '002633',
#  'the laughing cow': '002329',
#  'la vache qui rit': '002329',
#  'fromage blanc': '003561',
#  'quark': '002568',
#  'quarg': '002568',
#  'cottage cheese': '002408',
#  'chhena': '002393',
#  'chhana': '002393',
#  'queso blanco': '002569',
#  'queso fresco': '002570',
#  'petit-suisse': '003564',
#  'faisselle': '003560',
#  'mould ripened cheese': '003492',
#  'blue veined cheese': '003486',
#  'bleu': '003496',
#  'roquefort': '003518',
#  'camembert': '003500',
#  'brie': '003498',
#  "carré de l'est": '003501',
#  'buche de chèvre': '003499',
#  'parmesan': '003514',
#  'asiago': '003495',
#  'romano': '003517',
#  'spalen': '003523',
#  'cheddar': '003469',
#  'granular': '000297',
#  'gruyère': '003476',
#  'comté': '003470',
#  'cantal': '003468',
#  'brick cheese': '003466',
#  'limburger': '003509',
#  'trappist': '003482',
#  'gouda': '003474',
#  'raclette': '003480',
#  'fontina': '003472',
#  'stilton': '003524',
#  'gorgonzola': '003504',
#  'danablu': '003502',
#  'blue wensleydate': '003497',
#  'hand cheese': '003506',
#  'neufchatel': '003513',
#  'laguiole': '003477',
#  'kiri': '002325',
#  'cancoillotte': '002320',
#  'crème de brie de meaux': '002322',
#  'beaufort': '003465',
#  'beefsteak': '002359',
#  'beef steak': '002359',
#  'carpaccio': '003085',
#  'cocoa': '001960',
#  'cocoa butter': '001963',
#  'cocoa powder': '001964',
#  'nugget': '002729',
#  'camel milk': '001924',
#  'ewe milk': '002022',
#  'buffalo milk': '001918',
#  'fermented butter': '003143',
#  'beurre': '003143',
#  'hand': '001589',
#  'merguez': '002133',
#  'chipolata': '001952',
#  'chorizo': '003253',
#  'salami': '003563',
#  'fuet': '003562',
#  'morcela de arroz': '003244',
#  'algae a food': '001858',
#  'laurel': '002501',
#  'rosemary': '002588',
#  'sage': '002591',
#  'tarragon': '002621',
#  'thyme': '002623',
#  'broccoli': '002374',
#  'brussel sprout a food': '002375',
#  'cauliflower a food': '002384',
#  'chinese cabbage': '002321',
#  'head cabbage': '002477',
#  'garlic a food': '002460',
#  'onion': '002539',
#  'shallot': '002598',
#  'aubergine': '002347',
#  'baby corn': '002350',
#  'courgette': '002410',
#  'cucumber': '002418',
#  'gherkin': '002461',
#  'melon a food': '002519',
#  'okra': '002537',
#  'pumpkin': '002566',
#  'sweet pepper': '002617',
#  'tomato a food': '002625',
#  'cherry tomato': '002392',
#  'pear tomato': '002549',
#  'plum tomato': '002559',
#  'watermelon a food': '002641',
#  'fungi a food': '002055',
#  'cep': '003250',
#  'common mushroom': '003254',
#  'button mushroom': '003254',
#  'champignon mushroom': '003254',
#  'cultivated mushroom': '003254',
#  'table mushroom': '003254',
#  'white mushroom': '003254',
#  'brown mushroom': '003249',
#  'baby bella': '003249',
#  'brown cap mushroom': '003249',
#  'chestnut mushroom': '003249',
#  'cremini': '003249',
#  'crimini mushroom': '003249',
#  'italian brown': '003249',
#  'italian mushroom': '003249',
#  'roman brown mushroom': '003249',
#  'swiss brown mushroom': '003249',
#  'portobello mushroom': '003270',
#  'morel': '003267',
#  'truffle': '003275',
#  'basil': '002357',
#  'celery leaf': '002387',
#  'chard': '002388',
#  'chive': '002398',
#  'escarole': '002438',
#  'grape leaf': '002464',
#  'lettuce': '002506',
#  'mint': '002528',
#  'parsley': '002545',
#  'rocket': '002587',
#  'tzatziki': '003347',
#  'spinach': '002604',
#  'watercress': '002639',
#  'witloof': '002652',
#  'beetroot': '002361',
#  'carrot': '002382',
#  'celeriac': '002385',
#  'horseradish': '002483',
#  'parsnip': '002546',
#  'potato a food': '002561',
#  'radish': '002573',
#  'salsify': '002594',
#  'swede': '002615',
#  'sweet potato': '002618',
#  'turnip': '002632',
#  'yam': '002656',
#  'artichoke': '002345',
#  'asparagus': '002346',
#  'bamboo shoot': '002352',
#  'cardoon': '002380',
#  'celery': '002386',
#  'fennel': '002444',
#  'leek': '002504',
#  'palm heart': '002543',
#  'rhubarb': '002579',
#  'bean': '001897',
#  'lentil': '002104',
#  'pea': '002175',
#  'nut': '001665',
#  'almond a food': '001859',
#  'coconut a food': '001965',
#  'pecan': '002181',
#  'pistachio': '002189',
#  'cocoa bean': '001961',
#  'olive a food': '003158',
#  'peanut a food': '002177',
#  'peanut and primary derivative thereof': '001697',
#  'sesame oil': '002245',
#  'sesame seed': '002246',
#  'walnut': '002302',
#  'walnut and primary derivative thereof': '001838',
#  'walnut oil': '002303',
#  'rice': '002580',
#  'dark chocolate': '001514',
#  'steak tartare': '002266',
#  'fried rice': '002048',
#  'dosa': '003412',
#  'pico de gallo': '002555',
#  'corn tortilla': '001503',
#  'sashimi': '002239',
#  'sushi': '003171',
#  'ceviche': '001942',
#  'cebiche': '001942',
#  'fruit based dish': '001565',
#  'sorbet': '003166',
#  'fish sashimi': '002031',
#  'meat sashimi': '002131',
#  'pie': '002185',
#  'compote': '001969',
#  'fruit salad': '002052',
#  'pudding': '002204',
#  'blood sausage': '001906',
#  'black pudding': '002366',
#  'rice pudding': '002224',
#  'cheesecake': '003185',
#  'sugar confectionery': '001802',
#  'cupcake': '003134',
#  'éclair': '003242',
#  'custard cake': '003135',
#  'burger': '001466',
#  'hamburger': '002071',
#  'cheeseburger': '001945',
#  'frikadeller': '002049',
#  'meatball': '001638',
#  'prawn': '002563',
#  'lamb meat': '002095',
#  'meat patty': '002130',
#  'gram-positive': '000649',
#  'gram-negative': '000648',
#  'neisser-positive': '000473',
#  'neisser-negative': '000472',
#  'phenotype wrt metabolic activity': '000019',
#  'catalase activity': '000060',
#  'catalase positive': '000222',
#  'catalase negative': '000221',
#  'microscopic morphological phenotype': '000116',
#  'physiological phenotype': '000025',
#  'conjugating': '000243',
#  'gram stain phenotype': '000296',
#  'neisser stain phenotype': '000174',
#  'phenotype wrt morphology': '000020',
#  'conjugation phenotype': '000065',
#  'biofilm phenotype': '001005',
#  'presence of quorum sensing': '000143',
#  'presence of nanotube': '000142',
#  'multicellular arrangement phenotype': '000353',
#  'cellular shape phenotype': '000228',
#  'rod-shaped': '000848',
#  'bacilliform': '000848',
#  'coccobacillus': '000563',
#  'round-shaped': '000850',
#  'spiral-shaped': '000888',
#  'spirillum': '001329',
#  'spirochete': '001330',
#  'comma-shaped': '001043',
#  'comma shaped': '001043',
#  'stalked': '000892',
#  'star-shaped': '000893',
#  'pleomorphic': '000817',
#  'square-shaped': '000891',
#  'filamentous': '000629',
#  'sheathed': '000865',
#  'trichome forming': '000928',
#  'trichome-forming': '000928',
#  'colony morphology phenotype': '000064',
#  'liquid culture morphology phenotype': '000105',
#  'taxi phenotype': '000157',
#  'aerotactic': '000182',
#  'negative aerotactic': '000763',
#  'positive aerotactic': '000821',
#  'chemotactic': '000230',
#  'positive chemotactic': '000822',
#  'negative chemotactic': '000764',
#  'osmotactic': '000369',
#  'anemotactic': '000192',
#  'barotactic': '000207',
#  'durotactic': '000262',
#  'electrotactic': '000265',
#  'gravitactic': '000300',
#  'hydrotactic': '000317',
#  'magnetotactic': '000335',
#  'phototactic': '000387',
#  'rheotactic': '000409',
#  'thermotactic': '000452',
#  'thigmotactic': '000454',
#  'gliding': '000295',
#  'swarming': '000439',
#  'swimming': '000440',
#  'twitching': '000460',
#  'phenotype wrt adhesion': '000015',
#  'planktonic': '000139',
#  'free floating': '000139',
#  'decarboxylase activity': '000068',
#  'decarboxylase negative': '000251',
#  'decarboxylase positive': '000252',
#  'oxidase activity': '000371',
#  'oxidase negative': '000784',
#  'oxidase positive': '000785',
#  'halotolerant': '002711',
#  'acido tolerant': '002883',
#  'acid tolerant': '002883',
#  'acidotolerant': '002883',
#  'phenotype wrt habitat osmolarity': '000128',
#  'osmotolerant': '000370',
#  'osmophile': '000367',
#  'osmophobe': '000368',
#  'phenotype wrt growth': '000018',
#  'sporulating': '000150',
#  'spore forming': '000150',
#  'spore liberation': '000150',
#  'spore-forming': '000150',
#  'flocculent': '000286',
#  'flocculant': '000286',
#  'flocculating': '000286',
#  'pigmented': '000809',
#  'purple pigmented': '001272',
#  'violet pigmented': '001372',
#  'indigo pigmented': '001156',
#  'blue pigmented': '001008',
#  'green pigmented': '001137',
#  'yellow pigmented': '001386',
#  'orange pigmented': '001240',
#  'red pigmented': '001280',
#  'brown pigmented': '001019',
#  'black pigmented': '001007',
#  'golden pigmented': '001131',
#  'silver pigmented': '001318',
#  'white pigmented': '001382',
#  'cream pigmented': '001054',
#  'pink pigmented': '001255',
#  'maroon pigmented': '001197',
#  'fluorescent pigmented': '001107',
#  'antimicrobial resistant': '002337',
#  'antifungal resistant': '002677',
#  'antiviral resistant': '002680',
#  'antibacterial resistant': '002671',
#  'antiyeast resistant': '002683',
#  'phenotype wrt carbon source': '000379',
#  'phenotype wrt reducing equivalent source': '000385',
#  'phenotype wrt living energy source': '000383',
#  'lithotroph': '000712',
#  'organotroph': '000778',
#  'fermentative': '001105',
#  'fermentation ability': '001105',
#  'fermentation capacity': '001105',
#  'methanogenic': '000733',
#  'syntrophic': '000443',
#  'hydrogen oxidizing': '002991',
#  'sulfur oxidizing': '003028',
#  'ferrous iron oxidizing': '002984',
#  'ammonia oxidizing': '002955',
#  'anammox': '003036',
#  'arsenic oxidizing': '002959',
#  'photoorganoheterotroph': '003299',
#  'photo organoheterotroph': '003299',
#  'psychrotrophic': '000402',
#  'extreme thermophile': '000275',
#  'thermal resistant': '002945',
#  'heat resistant': '002987',
#  'cold resistant': '002975',
#  'extreme cold resistant': '002982',
#  'extreme heat resistant': '002983',
#  'disease resistant': '001997',
#  'phenotype wrt drug impact': '000381',
#  'phenotype wrt antimicrobial impact': '000378',
#  'phenotype wrt disease impact': '000125',
#  'phenotype wrt metal concentration impact': '000384',
#  'phenotype wrt relative humidity impact': '000137',
#  'desiccation resistant': '001992',
#  'desiccation tolerant': '001994',
#  'desiccation sensitive': '001993',
#  'disease tolerant': '001999',
#  'disease sensitive': '001998',
#  'antimicrobial sensitive': '002338',
#  'antiyeast sensitive': '002684',
#  'antifungal sensitive': '002678',
#  'antiviral sensitive': '002681',
#  'antibacterial sensitive': '002672',
#  'antimicrobial tolerant': '002339',
#  'antiyeast tolerant': '002685',
#  'antifungal tolerant': '002679',
#  'antiviral tolerant': '002682',
#  'antibacterial tolerant': '002673',
#  'antibiotic tolerant': '002676',
#  'antibiotic sensitive': '002675',
#  'metal sensitive': '002522',
#  'metal tolerant': '002523',
#  'vancomycin sensitive': '002875',
#  'meticillin sensitive': '002818',
#  'methicillin sensitive': '002818',
#  'moxifloxacin sensitive': '002821',
#  'ciprofloxacin sensitive': '002774',
#  'vancomycin tolerant': '002876',
#  'meticillin tolerant': '002819',
#  'methicillin tolerant': '002819',
#  'moxifloxacin tolerant': '002822',
#  'ciprofloxacin tolerant': '002775',
#  'phenotype wrt chemical composition': '001712',
#  'penicillin resistant': '002829',
#  'penicillin sensitive': '002830',
#  'penicillin tolerant': '002831',
#  'acido resistant': '002881',
#  'acid resistant': '002881',
#  'acidoresistant': '002881',
#  'alkali resistant': '002886',
#  'alkaline resistant': '002886',
#  'acido sensitive': '002882',
#  'acid sensitive': '002882',
#  'acidosensitive': '002882',
#  'alkali sensitive': '002887',
#  'phenotype wrt molecule impact': '000133',
#  'phenotype wrt temperature impact': '000138',
#  'stress resistant': '000152',
#  'stress sensitive': '000153',
#  'stress tolerant': '000154',
#  'drug resistant': '000598',
#  'drug tolerant': '000600',
#  'drug sensitive': '000599',
#  'lichen forming': '000104',
#  'lichen-forming': '000104',
#  'bloom forming': '000057',
#  'bloom-forming': '000057',
#  'phenotype wrt radiation impact': '000136',
#  'radiation resistant': '002212',
#  'radiation sensitive': '002213',
#  'radiation tolerant': '002214',
#  'uv radiation resistant': '002330',
#  'ultraviolet resistant': '002330',
#  'uva radiation resistant': '002659',
#  'uv-a radiation resistant': '002659',
#  'uv-a resistant': '002659',
#  'uvb radiation resistant': '002662',
#  'uv-b radiation resistant': '002662',
#  'uv-b resistant': '002662',
#  'uvc radiation resistant': '002665',
#  'uv-c radiation resistant': '002665',
#  'uv-c resistant': '002665',
#  'ionizing radiation resistant': '002492',
#  'ionizing radiation sensitive': '002493',
#  'ionizing radiation tolerant': '002494',
#  'uvc radiation sensitive': '002666',
#  'uv-c radiation sensitive': '002666',
#  'uv-c sensitive': '002666',
#  'uvb radiation sensitive': '002663',
#  'uv-b radiation sensitive': '002663',
#  'uv-b sensitive': '002663',
#  'uva radiation sensitive': '002660',
#  'uv-a radiation sensitive': '002660',
#  'uv-a sensitive': '002660',
#  'uv radiation sensitive': '002331',
#  'ultraviolet sensitive': '002331',
#  'uv sensitive': '002331',
#  'uv radiation tolerant': '002332',
#  'ultraviolet tolerant': '002332',
#  'uv tolerant': '002332',
#  'uvc radiation tolerant': '002667',
#  'uv-c radiation tolerant': '002667',
#  'uv-c tolerant': '002667',
#  'uvb radiation tolerant': '002664',
#  'uv-b radiation tolerant': '002664',
#  'uv-b tolerant': '002664',
#  'uva radiation tolerant': '002661',
#  'uv-a radiation tolerant': '002661',
#  'uv-a tolerant': '002661',
#  'freeze-thaw resistant': '002985',
#  'part of food': '000373',
#  'surface of food': '000902',
#  'transconjugating': '000456',
#  'paired': '000789',
#  'grape-like clustered': '000652',
#  'chained': '000552',
#  'cuboidal': '000578',
#  'tetrad': '000914',
#  'singled': '000872',
#  'thermal tolerant': '002290',
#  'thermal sensitive': '002289',
#  'heat sensitive': '002478',
#  'extreme cold sensitive': '002440',
#  'extreme heat sensitive': '002442',
#  'freeze-thaw sensitive': '002453',
#  'cold sensitive': '002404',
#  'heat tolerant': '002480',
#  'extreme cold tolerant': '002441',
#  'extreme heat tolerant': '002443',
#  'freeze-thaw tolerant': '002454',
#  'cold tolerant': '002406',
#  'halophile': '000656',
#  'conidial': '000242',
#  'non-sporulating': '000122',
#  'home-made food': '001145',
#  'salted food': '002238',
#  'soybean and related product': '001781',
#  'leaf based drink': '003059',
#  'malt': '003215',
#  'malted barley': '003215',
#  'head': '001142',
#  'tail': '001346',
#  'powdered food': '001728',
#  'goulash': '003053',
#  'maize and primary derivative thereof': '002120',
#  'pozol': '003595',
#  'pozole': '003069',
#  'stew': '001337',
#  'birria': '001448',
#  'stewed food': '002269',
#  'dashi': '001515',
#  'kombu': '002093',
#  'okpehe': '001676',
#  'beer yeast': '000511',
#  'brewer yeast': '000511',
#  "brewer's yeast": '000511',
#  'brewery yeast': '000511',
#  'brewing yeast': '000511',
#  'wine yeast': '000968',
#  'oenological yeast': '000968',
#  'lager yeast': '001170',
#  "lager brewer's yeast": '001170',
#  'lager-brewing yeast': '001170',
#  'ale yeast': '000981',
#  "ale brewer's yeast": '000981',
#  'baking powder': '000999',
#  'baking soda': '001000',
#  'sodium bicarbonate': '001000',
#  'starter yeast': '000894',
#  'commercial starter': '000894',
#  'commercial yeast': '000894',
#  'yeast starter': '000894',
#  'saccharomyces cerevisiae starter': '000474',
#  'lyophilized milk starter': '001188',
#  'sourdough starter': '003537',
#  'commercial sourdough': '003537',
#  'selected sourdough': '003537',
#  'sourdough bread starter': '003537',
#  'emmer wheat product': '002705',
#  'durum wheat product': '002701',
#  'bread wheat product': '002690',
#  'common wheat': '002690',
#  'spelt product': '002746',
#  'dinkel wheat': '002746',
#  'einkorn wheat product': '002702',
#  'einkorn': '002702',
#  'khorasan product': '002723',
#  'barley and primary derivative thereof': '001893',
#  'rye and primary derivative thereof': '002233',
#  'oat and primary derivative thereof': '002154',
#  'lupin and related product': '001622',
#  'lupine': '001622',
#  'grain and primary derivative thereof': '001132',
#  'buckwheat and primary derivative thereof': '001462',
#  'sunflower seed': '002276',
#  'triticale and primary derivative thereof': '002295',
#  'poppy seed and primary derivative thereof': '001723',
#  'quinoa and primary derivative thereof': '001734',
#  'quinoa seed': '001734',
#  'teff and primary derivative thereof': '002285',
#  'tef': '002285',
#  'chia seed and primary derivative thereof': '001484',
#  'millet and primary derivative thereof': '002137',
#  'amaranth and primary derivative thereof': '001403',
#  'pumpkin seed and primary derivative thereof': '001731',
#  'flaxseed and primary derivative thereof': '001551',
#  'linseed': '001551',
#  'hemp seed and primary derivative thereof': '001593',
#  'sourdough bread': '002745',
#  'yeast bread': '002756',
#  'enriched bread': '002435',
#  'gluten-free bread': '002462',
#  'final sourdough': '003415',
#  'chief sourdough': '003407',
#  'type i sourdough': '003436',
#  'type ii sourdough': '003437',
#  'type iii sourdough': '003438',
#  'traditional sourdough': '003435',
#  'artisan bakery sourdough': '003435',
#  'artisanal sourdough': '003435',
#  'natural fermented sourdough': '003435',
#  'natural sourdough': '003435',
#  'naturally fermented sourdough': '003435',
#  'spontaneous sourdough': '003435',
#  'spontaneously fermented sourdough': '003435',
#  'traditionnal sourdough': '003435',
#  'leavened bread': '002503',
#  'laboratory sourdough': '003420',
#  'viennoiserie': '002301',
#  'croissant': '002416',
#  'vienna bread': '002333',
#  'danish pastry': '002323',
#  'brioche': '002373',
#  'pastry product': '002174',
#  'bun': '001920',
#  'sweet dough': '002280',
#  'leavened dough': '003421',
#  'cream pastry': '002413',
#  'puff pastry': '002565',
#  'knieküchle': '002326',
#  'food fermentation equipment': '001556',
#  'fermentation vat': '002025',
#  'ripening room': '003301',
#  'milled food': '001209',
#  'bran': '001458',
#  'fermented dough': '003414',
#  'storage box': '002270',
#  'oven': '001241',
#  'dough mixer': '002000',
#  'phenotype wrt shape': '000386',
#  'smooth colony': '000880',
#  'fluffy colony': '000632',
#  'structured colony': '000897',
#  'pseudohyphae growth': '000144',
#  'pseudohyphae': '000144',
#  'hypha growth': '000099',
#  'hypha': '000099',
#  'sexual reproduction': '000148',
#  'ascus formation': '000148',
#  'ascospore formation': '000148',
#  'sexual growth': '000148',
#  'asexual reproduction': '000051',
#  'asexual growth': '000051',
#  'sexual mating': '000147',
#  'homothallic': '000310',
#  'heterothallic': '000305',
#  'phenotype wrt ploidy': '000022',
#  'haploid': '000096',
#  'diploid': '000069',
#  'tetraploid': '000159',
#  'aneuploid': '000037',
#  'triploid': '000163',
#  'autoploid': '000053',
#  'alloploid': '000036',
#  'mata': '000172',
#  'matalpha': '000173',
#  'auxotroph': '000203',
#  'prototroph': '000399',
#  'phenotypre wrt genetic': '000024',
#  'wild-type': '000169',
#  'wild type': '000169',
#  'mutant': '000118',
#  'crabtree positive': '000577',
#  'crabtree-positive': '000577',
#  'crabtree negative': '000576',
#  'crabtree-negative': '000576',
#  'petite positive': '003067',
#  'petite colony': '003067',
#  'petite mutant': '003067',
#  'petite strain': '003067',
#  'petite yeast': '003067',
#  'small colony': '000879',
#  'big colony': '000513',
#  'flor': '002035',
#  'flor forming': '002035',
#  'drosophila': '001531',
#  'tilsit': '003526',
#  'gubbeen': '003505',
#  'taleggio': '003525',
#  'liederkranz': '003508',
#  'saint-paulin': '003520',
#  'saint paulin': '003520',
#  'fuzhuan brick tea': '003540',
#  'fu brick tea': '003540',
#  'fu-zhuan brick tea': '003540',
#  'meju': '003387',
#  'chili pepper and related product': '001950',
#  'chili pepper': '002395',
#  'chile pepper': '002395',
#  'chilli': '002395',
#  'chilli pepper': '002395',
#  'chili sauce': '003352',
#  'pressed food': '001267',
#  'berry and primary derivative thereof': '001901',
#  'blackberry and primary derivative thereof': '001903',
#  'blackcurrant and primary derivative thereof': '001904',
#  'blueberry and primary derivative thereof': '001907',
#  'raspberry and primary derivative thereof': '002218',
#  'redcurrant and primary derivative thereof': '002220',
#  'strawberry and primary derivative thereof': '002272',
#  'lemon and primary derivative thereof': '002103',
#  'lime and primary derivative thereof': '002106',
#  'mandarin and primary derivative thereof': '002121',
#  'orange and primary derivative thereof': '002162',
#  'date and primary derivative thereof': '001989',
#  'fig and primary derivative thereof': '002027',
#  'kaki and primary derivative thereof': '002090',
#  'olive and primary derivative thereof': '003109',
#  'avocado and primary derivative thereof': '001887',
#  'banana and primary derivative thereof': '001891',
#  'durian and primary derivative thereof': '002010',
#  'kiwi and primary derivative thereof': '002091',
#  'litchi and primary derivative thereof': '002111',
#  'mango and primary derivative thereof': '002122',
#  'pineapple and primary derivative thereof': '002188',
#  'guacamole': '003356',
#  'apple and primary derivative thereof': '001879',
#  'pear and primary derivative thereof': '002179',
#  'quince and primary derivative thereof': '002208',
#  'apricot and primary derivative thereof': '001881',
#  'cherry and primary derivative thereof': '001946',
#  'nectarine and primary derivative thereof': '002150',
#  'peach and primary derivative thereof': '002176',
#  'plum and primary derivative thereof': '002191',
#  'cinnamon and related product': '001954',
#  'citronella grass and related product': '001955',
#  'clove and related product': '001957',
#  'sweet corn': '002616',
#  'ginger and related product': '002061',
#  'lavander and related product': '002099',
#  'oregano and related product': '002164',
#  'white mustard and related product': '002310',
#  'winter savory and related product': '002312',
#  'wasabi and related product': '002304',
#  'amaranth': '001860',
#  'buckwheat': '001917',
#  'chia seed': '001948',
#  'flaxseed': '002033',
#  'hemp seed': '002076',
#  'pumpkin seed': '002206',
#  'quinoa': '002209',
#  'barley product': '002355',
#  'maize': '002513',
#  'poppy seed': '002195',
#  'millet': '002525',
#  'oat a food': '002536',
#  'rye': '002590',
#  'teff': '002622',
#  'triticale': '002626',
#  'wheat product': '002643',
#  'lupin': '002118',
#  'lupin seed': '002119',
#  'neutralophile': '000359',
#  'filament-shaped': '000628',
#  'gram-variable': '000650',
#  'microaerotolerant': '000735',
#  'microanaerobe': '000736',
#  'beeswax': '002962',
#  'propolis': '003016',
#  'dietary supplement': '001070',
#  'royal jelly': '003071',
#  'bee pollen': '003040',
#  'frog leg': '002457',
#  'fermented fresh cheese': '003556',
#  'fermented cottage cheese': '003592',
#  'sour cream': '003397',
#  'plant based juice': '003530',
#  'animal based juice': '000984',
#  'fruit based juice': '003534',
#  'vegetable based juice': '003539',
#  'cereal based drink': '003087',
#  'legume based drink': '003061',
#  'nut based drink': '003064',
#  'oleaginous seed based drink': '003108',
#  'oat beverage': '003423',
#  'rice beverage': '003427',
#  'corn beverage': '003410',
#  'spelt beverage': '003431',
#  'soy beverage': '003366',
#  'lupin beverage': '003360',
#  'cowpea beverage': '003354',
#  'peanut beverage': '003362',
#  'almond beverage': '003349',
#  'coconut beverage': '003353',
#  'hazelnut beverage': '003357',
#  'pistachio beverage': '003363',
#  'walnut beverage': '003370',
#  'sesame beverage': '003395',
#  'flaxseed beverage': '003382',
#  'hempseed beverage': '003384',
#  'sunflower beverage': '003401',
#  'quinoa beverage': '003364',
#  'teff beverage': '003434',
#  'amaranth milk': '003350',
#  'soybean': '002259',
#  'ionised food': '001603',
#  'ionized food': '001603',
#  'pressure treated food': '001729',
#  'pressuretreated food': '001729',
#  'high pressure treated food': '002079',
#  'cantaloupe a food': '002770',
#  'muskmelon': '002728',
#  'octopus and product thereof': '002155',
#  'cuttlefish and product thereof': '001986',
#  'animal roe': '001872',
#  'fish roe and product thereof': '003149',
#  'caviar': '003375',
#  'sturgeon egg': '003375',
#  'sturgeon roe': '003375',
#  'kazunoko': '003208',
#  'masago': '003216',
#  'tobiko': '003235',
#  'cod roe': '003191',
#  'sea urchin roe': '003273',
#  'echinoderm and product thereof': '001535',
#  'sea cucumber and product thereof': '002241',
#  'filmjölk': '003197',
#  'långfil': '003214',
#  'viili': '003238',
#  'kumis': '003210',
#  'koumiss': '003210',
#  'kumys': '003210',
#  'amasi': '003181',
#  'dahi': '003194',
#  'dadih': '003193',
#  'dadiah': '003193',
#  'matsoni': '003217',
#  ' caspian sea yoghurt': '003217',
#  'matzoon': '003217',
#  'mabisi': '003574',
#  'chibwantu': '003580',
#  'munkoyo': '003218',
#  'yak milk': '002316',
#  'xueo': '003240',
#  'reheated food': '002221',
#  'griddled food': '002068',
#  'griddle cooked food': '002068',
#  'griddle-cooked food': '002068',
#  'scalded food': '002240',
#  'simmered food': '002249',
#  'blanched food': '001905',
#  'preserved food': '001266',
#  'plant based drink': '003013',
#  'wheatgrass juice': '003589',
#  'beet juice': '003576',
#  'carrot juice': '003578',
#  'celery juice': '003579',
#  'cucumber juice': '003582',
#  'tejuino': '003601',
#  'tejuíno': '003601',
#  'corn milk': '003447',
#  'turnip juice': '003588',
#  'lemon juice': '003584',
#  'tomato juice': '003587',
#  'pineapple juice': '003586',
#  'grain based drink': '003054',
#  'hazelnut and primary derivative thereof': '001590',
#  'hazelnut': '002074',
#  'cranberry and primary derivative thereof': '001979',
#  'cranberry a food': '002412',
#  'clam juice': '003088',
#  'meat juice': '001636',
#  'oat milk': '003454',
#  'rice milk': '003455',
#  'spelt milk': '003460',
#  'teff milk': '003461',
#  'flax milk': '003416',
#  'hemp milk': '003418',
#  'sesame milk': '003429',
#  'sunflower milk': '003433',
#  'quinoa milk': '003393',
#  'cowpea milk': '003378',
#  'lupin milk': '003386',
#  'soy milk': '003399',
#  'soymilk': '003399',
#  'almond milk': '003373',
#  'coconut milk': '003376',
#  'coconut water': '003377',
#  'hazelnut milk': '003383',
#  'peanut milk': '003390',
#  'pistachio milk': '003391',
#  'walnut milk': '003402',
#  'barley milk': '003442',
#  'barley beverage': '003405',
#  'cashew and primary derivative thereof': '001475',
#  'cashew seed': '001936',
#  'cashew apple': '001935',
#  'cashew beverage': '003351',
#  'cashew milk': '003374',
#  'medical sample': '000110',
#  'urine sediment': '000462',
#  'salivary sediment': '000416',
#  'sputum sediment': '000431',
#  'cell sediment': '000227',
#  'furniture': '000291',
#  'bed a furniture': '000506',
#  'chair': '000553',
#  'table a furniture': '000908',
#  'washing machine': '000954',
#  'stool a furniture': '000896',
#  'sofa a furniture': '000882',
#  'dental chair': '000255',
#  'hospital bed': '002484',
#  'kitchen sponge': '000699',
#  'dishcloth': '000594',
#  'kitchen sink': '000698',
#  'bathroom sink': '000503',
#  'faucet handle': '002707',
#  'sink drain': '000873',
#  'dish towel': '002787',
#  'high chair tray': '000666',
#  'jellyfish': '001165',
#  'sap': '001297',
#  'gelatine a ingredient': '001130',
#  'silo': '000423',
#  'textile': '000447',
#  'towel': '000926',
#  'paper towel': '001245',
#  'sauna': '000856',
#  'toilet': '000920',
#  'public toilet': '000404',
#  'toilet seat': '000922',
#  'bathroom equipment': '000208',
#  'toilet equipment': '000455',
#  'bedroom equipment': '000210',
#  'kitchen equipment': '000330',
#  'bed sheet': '000507',
#  'pillow a equipment': '000810',
#  'feather pillow': '001101',
#  'bedspread': '000509',
#  'landfill': '000331',
#  'waste treatment environment': '000167',
#  'waste container': '002877',
#  'kitchen garbage': '001168',
#  'dustbin': '002902',
#  'emesis basin': '003140',
#  'dumpster': '002901',
#  'shoe factory': '001770',
#  'shoe': '000420',
#  'theatre shoe': '002748',
#  'theatre boot': '002748',
#  'hospital gown': '000672',
#  'surgical gown': '001343',
#  'paper gown': '001244',
#  'medical glove': '000728',
#  'scrub a clothing': '000861',
#  'surgical cap': '000905',
#  'boot swab': '000217',
#  'slaugterhouse equipment': '001322',
#  'brisket saw': '001461',
#  'meat hook': '001635',
#  "butcher's knife": '001467',
#  'cutting table': '001510',
#  'cutting board': '000582',
#  'apron': '002891',
#  'coffeemaker': '000566',
#  'countertop': '000575',
#  'dishwasher': '000595',
#  'tableware': '000909',
#  'cutlery': '001509',
#  'drinking glass': '001079',
#  'dinner plate': '001072',
#  'spoon': '002262',
#  'chopstick': '001486',
#  'fork a utensil': '002040',
#  'knife': '002092',
#  'toothpick': '001827',
#  'eating utensil': '001084',
#  'toiletry': '000923',
#  'chewing stick': '001032',
#  'toothpaste': '001357',
#  'toothbrush': '001356',
#  'shampoo': '001311',
#  'shaving cream': '001312',
#  'baby wipe': '000995',
#  'tampon': '001348',
#  'panty liner': '001243',
#  'cotton swab': '001052',
#  'facial tissue': '001096',
#  'handkerchief': '000658',
#  'sanitary towel': '001296',
#  'incontinence pad': '001155',
#  'blender': '000520',
#  'freezer': '000636',
#  'refrigerator': '000837',
#  'microwave oven': '000738',
#  'water heater system': '000958',
#  'water heater': '001378',
#  'hot water tank': '001149',
#  'boiler': '001010',
#  'calorifier': '001025',
#  'heat exchanger': '002909',
#  'shower head': '003229',
#  'nozzle': '002918',
#  'water tap': '002949',
#  'thermometer a medical device': '000916',
#  'oral thermometer': '001239',
#  'rectal thermometer': '001279',
#  'ear thermometer': '001083',
#  'forehead thermometer': '001118',
#  'spirometer': '000889',
#  'public transport': '000405',
#  'subway': '000899',
#  'passenger train': '000795',
#  'school bus': '000859',
#  'airplane': '000480',
#  'bus driver': '003313',
#  'prostitute': '003324',
#  'veterinarian': '003331',
#  'guinea fowl meat': '002469',
#  'quail meat': '002567',
#  'ratite meat': '002576',
#  'ostrich meat': '002731',
#  "pig's trotter": '002556',
#  'animal brain and product thereof': '001410',
#  'animal tongue and product thereof': '001423',
#  'animal kidney and product thereof': '001414',
#  'animal liver and product thereof': '001415',
#  'animal roe and product thereof': '001419',
#  'animal skin and product thereof': '001420',
#  'animal stomach and product thereof': '001421',
#  'animal heart and product thereof': '001413',
#  ...}

# %%
len(documents)
# Out:
# 2079

# %%
model = Word2Vec(documents, min_count=1)

# %%
len(model.wv.vocab)
# Out:
# 5721

# %%
count = 0
a = 0
for hb in habitat_map.keys():
    words = hb.split(' ')
    for w in words:
        a += 1
        try:
            model[w]
        except:
            count += 1
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:8: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
a
# Out:
# 9583

# %%
count
# Out:
# 4815

# %%
model['cheese'].shape
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# (100,)

# %%
annotations_test = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    pred_file_name = "./dev_preds/" + BB_dev_a2[i]
    annotations_test[BB_dev_a1[i]] = predict_habitats(a1, txt, BB_dev_a1[i], phrase_reducer, pred_file_name)

# %%
annotations_test

# %%
def test_habitats(a1, a2, processor):
    
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    match_list = {}
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]:
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = named_entity.lower()
                    named_entity = processor(named_entity)
                match_list[t] = [oid, named_entity]
    return match_list

# %%
dev_a2 = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    a2 = open(dev_path + BB_dev_a2[i],encoding="utf8").read()
    dev_a2[BB_dev_a1[i]] = test_habitats(a1,a2, phrase_reducer)

# %%
true_pred_count = 0
false_pred_count = 0
total_count = 0
for key in dev_a2:
    """print()
    print(key)
    print(dev_a2[key])
    print("**************")"""
    total_count += len(dev_a2[key])
    if key in annotations_test:
        for pred in annotations_test[key]:            
            if annotations_test[key][pred][0] == dev_a2[key][pred][0]:
                true_pred_count += 1
            else:
                print(key)
                print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred])
                print("Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]])
                false_pred_count += 1

# %%
recall = true_pred_count/total_count
recall

# %%
precision = true_pred_count/(true_pred_count + false_pred_count)
precision

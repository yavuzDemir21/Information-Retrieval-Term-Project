# %%
import os, re
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import treebank
from nltk.corpus import dependency_treebank
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
import pprint
from nltk.parse.corenlp import CoreNLPDependencyParser
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from gensim.models import Word2Vec, FastText
import numpy as np
import re
from numpy.linalg import norm
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from string import punctuation
from scipy.spatial import distance
import fasttext

# %% [markdown]
# CoreNLPDependencyParser needs a local service running. More details can be found in the readme file of the repo.

# %%
ps = PorterStemmer()
wnl = WordNetLemmatizer()
lancaster=LancasterStemmer()
sb = SnowballStemmer("english")
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %% [markdown]
# BioWordVec model is needed to be downloaded 1-level outside of the repository. It can be downloaded from here: https://github.com/ncbi-nlp/BioSentVec

# %%
model_path = '../BioWordVec_PubMed_MIMICIII_d200.bin'

# %%
model = FastText.load_fasttext_format(model_path)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   """Entry point for launching an IPython kernel.

# %%
class Habitat:
    oid = -1
    name = ""

# %%
train_path = "./BioNLP-OST-2019_BB-norm_train/"
test_path = "./BioNLP-OST-2019_BB-norm_test/"
dev_path = "./BioNLP-OST-2019_BB-norm_dev/"
BB_train = os.listdir(train_path)
BB_test = os.listdir(test_path)
BB_dev = os.listdir(dev_path)
obp_file = "OntoBiotope_BioNLP-OST-2019.obo"

# %%
ontology = open(obp_file,encoding="utf8").read()

# %%
BB_train_a1 = sorted([name for name in BB_train if name.endswith("a1")])
BB_train_a2 = sorted([name for name in BB_train if name.endswith("a2")])
BB_train_txt = sorted([name for name in BB_train if name.endswith("txt")])

BB_dev_a1 = sorted([name for name in BB_dev if name.endswith("a1")])
BB_dev_a2 = sorted([name for name in BB_dev if name.endswith("a2")])
BB_dev_txt = sorted([name for name in BB_dev if name.endswith("txt")])

BB_test_a1 = sorted([name for name in BB_test if name.endswith("a1")])
BB_test_txt = sorted([name for name in BB_test if name.endswith("txt")])

# %%
def l_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = lancaster.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def s_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = sb.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def original_phrase(phrase):
    return phrase

# %%
def p_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = ps.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def lemmatize_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = wnl.lemmatize(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def switch_to_lower(phrase):
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = phrase[i].lower()
    phrase = " ".join(phrase)
    return phrase

# %%
def get_jaccard_sim(p1, p2, processor):
    p1 = processor(switch_to_lower(p1))
    p2 = processor(switch_to_lower(p2))
    p1, p2= p1.split(" "), p2.split(" ")
    union = set(p1+p2)
    intersection = [word for word in set(p1) if word in set(p2)]
    return len(intersection)/len(union)

# %%
phrase_reducer = lemmatize_phrase

# %%
def get_headword(phrase):
    #print(phrase)
    if phrase == phrase.upper():
        return ""
    
    parses = dep_parser.parse(phrase.split())
    triples = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses]
    
    try:
        if(len(triples) > 0 and len(triples[0]) > 0 and len(triples[0][0]) > 0 and len(triples[0][0][0]) > 0 and triples[0][0][0][0] is not None):
            return triples[0][0][0][0]
        else:
            return phrase
    except:
        return phrase

# %%
def add_documents(txt, processor):
    document = []
    #txt = processor(txt)
    sentence_list = sent_tokenize(txt)
    
    for sentence in sentence_list:
        sentence = sentence.replace('-', ' ')
        
        word_list = word_tokenize(sentence)
        word_list = [word for word in word_list if word not in stopwords.words("english") and word.isalnum()]
        for i in range(len(word_list)):
            if word_list[i].isnumeric():
                word_list[i] = "##number##"
            if word_list[i] != word_list[i].upper():
                word_list[i] = processor(word_list[i].lower())
             
        document.append(word_list)
    #print(document)
    return document

# %%
documents = []
for i in range(len(BB_train_txt)):
    txt = open(train_path + BB_train_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_dev_txt)):
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_test_txt)):
    txt = open(test_path + BB_test_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

# %%
#model = Word2Vec(documents, min_count=1)

# %%
def get_phrase_embedding(phrase, model, processor):
    original_phrase = phrase
    phrase = phrase.replace('-', ' ')
    hyphenless_phrase = phrase
    phrase = nltk.word_tokenize(phrase)
    phrase = [word for word in phrase if word.lower() not in stopwords.words("english") and word.isalnum()]
    for i in range(len(phrase)):
        if phrase[i].isnumeric():
            phrase[i] = "##number##"
        if phrase[i] != phrase[i].upper():
            phrase[i] = processor(phrase[i].lower())
    #print(phrase)
    phrase_size = len(phrase)
    vec_size = len(model[list(model.wv.vocab)[0]])
    embedded_sum = np.zeros(vec_size)
    if(phrase_size == 0):
        return -1
    for word in phrase:
        try:
            embedded_sum = embedded_sum + np.array(model[word])
        except:
            return -1
    embedded_sum = embedded_sum / phrase_size
    
    ####
    hw = get_headword(hyphenless_phrase)
    if hw == "":
        pass
        #print(hyphenless_phrase)
    else:
        hw_emb = np.array(model[processor(switch_to_lower(hw))])
        embedded_sum = (embedded_sum + hw_emb)/2
    ####
    return embedded_sum

# %%
def generate_habitat_map(processor, model):
    habitat_list = ontology.split("\n\n[Term]\n")[1:]
    habitat_map = {}
    habitat_map_originals = {}
    habitat_embeddings = {}
    for h in habitat_list:
        #new_habitat = Habitat()
        h = h.split("\n")
        oid = re.findall(r"(?<=id: OBT:)[0-9]+", h[0])[0]
        name = (re.findall(r"(?<=name: ).+", h[1])[0])
        original_name = name
        if name != name.upper():
            name = switch_to_lower(name)
            name = processor(name)
    
        habitat_map[name] = oid
        habitat_map_originals[oid] = name
        embedding = get_phrase_embedding(name, model, processor)
        if type(embedding) == type(np.array([1])):
            habitat_embeddings[name] = embedding
    
        # word2vec buraya eklenmeli 
        for h_line in h:
            if "synonym" in h_line:
                synonym_name = (re.findall(r"(?<=synonym: \").+(?=\")", h_line)[0])
                if synonym_name != synonym_name.upper():
                    synonym_name = switch_to_lower(synonym_name)
                    synonym_name = processor(synonym_name)
                if "EXACT" in h_line and synonym_name not in habitat_map:
                    habitat_map[synonym_name] = oid
                    if type(embedding) == type(np.array([1])):
                        habitat_embeddings[synonym_name] = embedding
                    
    return habitat_map, habitat_map_originals, habitat_embeddings

# %%
habitat_map, habitat_map_originals, habitat_embeddings = generate_habitat_map(phrase_reducer, model)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def add_habitats(a1, a2, processor, model):
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    
    
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]: 
                named_entity = (a1[a1_line].split("\t")[2])
                named_entity = named_entity.replace('-', ' ')
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                if named_entity not in habitat_map:
                    habitat_map[named_entity] = oid
                
                if habitat_map_originals[oid] not in habitat_embeddings:
                    habitat_embeddings[habitat_map_originals[oid]] = []
                
                if type(habitat_embeddings[habitat_map_originals[oid]]) == list:
                    emb = get_phrase_embedding(named_entity, model, processor)
                    if type(emb) == int:
                        print("no embedding for", named_entity)
                    habitat_embeddings[habitat_map_originals[oid]].append(emb)

# %%
for i in range(len(BB_train_txt)):    
    a1 = open(train_path + BB_train_a1[i],encoding="utf8").read()
    a2 = open(train_path + BB_train_a2[i],encoding="utf8").read()
    add_habitats(a1, a2, phrase_reducer, model)

# %%
for key in habitat_embeddings:
    if type(habitat_embeddings[key]) == list:
        vec_size = len(habitat_embeddings[key][0])
        temp_vec = np.zeros(vec_size)
        for vec in habitat_embeddings[key]:
            temp_vec += vec
        temp_vec /= len(habitat_embeddings[key])
        habitat_embeddings[key] = temp_vec

# %%
def predict_habitats_exact_matching(a1, txt, a1_name, processor, pred_file_name):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            cands += 1
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + "---exact"
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                found = True
            else:
                #print(name)
                pre_named_entity = get_headword(name)
                #print(pre_named_entity)
                named_entity = processor(pre_named_entity)
                if named_entity in habitat_map:
                    matches += 1
                    match = name + " - " + habitat_map[named_entity] + "---headwordexact"
                    print(match)
                    match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                    found = True
        if found:
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
            count += 1
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def get_jaccard_sim(p1, p2, processor):
    p1 = processor(switch_to_lower(p1))
    p2 = processor(switch_to_lower(p2))
    p1, p2= p1.split(" "), p2.split(" ")
    union = set(p1+p2)
    intersection = [word for word in set(p1) if word in set(p2)]
    return len(intersection)/len(union)

# %%
def predict_habitats(a1, txt, a1_name, processor, pred_file_name, model):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] + " ---exact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue

                    
            sim_score = 0.3
            match_id = ""
            hb = ''
            for habitat in habitat_map:
                score = get_jaccard_sim(named_entity, habitat, processor)
                if score > sim_score:
                    sim_score = score
                    match_id = habitat_map[habitat]
                    hb = habitat
            if match_id != "":
                match_list[line.split("\t")[0]] = [match_id, named_entity, "jaccard", hb]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
                count += 1
                continue
            
            #print(name)
            pre_named_entity = get_headword(name)
            #print(pre_named_entity)
            named_entity = processor(pre_named_entity)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] +" ---headwordexact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                found = True
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
            
            cands += 1
            name = (line.split("\t")[2])
            name = name.replace("-", " ")
            named_entity = name
            entity_vec = get_phrase_embedding(named_entity, model, processor)
            match_id = ""
            largest_prod = 0
            if type(entity_vec) != int:
                largest_prod = np.dot(entity_vec, habitat_embeddings[list(habitat_embeddings)[0]])/(norm(entity_vec)*norm(habitat_embeddings[list(habitat_embeddings)[0]]))
                match_id = habitat_map[list(habitat_embeddings)[0]]
                for habitat in habitat_embeddings:
                    prod = np.dot(entity_vec,habitat_embeddings[habitat])/(norm(entity_vec)*norm(habitat_embeddings[habitat]))
                    if prod > largest_prod:
                        largest_prod = prod
                        match_id = habitat_map[habitat]
            else:
                print("Doc:", a1_name," no embedding for:", named_entity)
                continue
                
            match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
            match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
            #print(line.split("\t")[0], "matched with w2v")
            #print(match_list)
            #print(match)
            
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
            count += 1
            
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def predict_habitats_threshold(a1, txt, a1_name, processor, pred_file_name, model, threshold):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            
            
            cands += 1
            name = (line.split("\t")[2])
            name = name.replace("-", " ")
            named_entity = name
            entity_vec = get_phrase_embedding(named_entity, model, processor)
            match_id = ""
            largest_prod = 0
            if type(entity_vec) != int:
                largest_prod = np.dot(entity_vec, habitat_embeddings[list(habitat_embeddings)[0]])/(norm(entity_vec)*norm(habitat_embeddings[list(habitat_embeddings)[0]]))
                match_id = habitat_map[list(habitat_embeddings)[0]]
                for habitat in habitat_embeddings:
                    prod = np.dot(entity_vec,habitat_embeddings[habitat])/(norm(entity_vec)*norm(habitat_embeddings[habitat]))
                    if prod > largest_prod:
                        largest_prod = prod
                        match_id = habitat_map[habitat]
            
            if largest_prod > threshold:
                match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
                match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
                #print(line.split("\t")[0], "matched with w2v")
                #print(match_list)
                #print(match)
                
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
                count += 1
                continue

            
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] + " ---exact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
             
            #print(name)
            pre_named_entity = get_headword(name)
            #print(pre_named_entity)
            named_entity = processor(pre_named_entity)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] +" ---headwordexact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                found = True
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
            
            
            match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
            match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
            #print(line.split("\t")[0], "matched with w2v")
            #print(match_list)
            #print(match)
            
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
            count += 1
            
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %% [markdown]
# # Generate Predictions for Dev Set

# %%
annotations_test = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    pred_file_name = "./dev_preds/" + BB_dev_a2[i]
    annotations_test[BB_dev_a1[i]] = predict_habitats(a1, txt, BB_dev_a1[i], phrase_reducer, pred_file_name, model)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def test_habitats(a1, a2, processor):
    
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    match_list = {}
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]:
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                match_list[t] = [oid, named_entity]
    return match_list

# %%
dev_a2 = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    a2 = open(dev_path + BB_dev_a2[i],encoding="utf8").read()
    dev_a2[BB_dev_a1[i]] = test_habitats(a1,a2, phrase_reducer)

# %%
true_pred_count = 0
false_pred_count = 0
total_count = 0
for key in dev_a2:
    total_count += len(dev_a2[key])
    if key in annotations_test:
        for pred in annotations_test[key]:            
            if annotations_test[key][pred][0] == dev_a2[key][pred][0]:
                true_pred_count += 1
                print(key)
                print(True)
                print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                print()
            else:
                print(key)
                print(False)
                print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                print()
                false_pred_count += 1
# Out:
# BB-norm-10496597.a1
# False
# Word: gastric mucosal-associated lymphoid tissue  Prediction: animal tissue  Real: lymphatic system part  Type: headwordexact
#
# BB-norm-10496597.a1
# False
# Word: gastric mucosal  Prediction: stomach  Real: gastric mucosa  Type: jaccard  Habitat: gastric
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: murine  Real: lymphatic system part  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: gastric MALT  Prediction: stomach  Real: lymphatic system part  Type: jaccard  Habitat: gastric
#
# BB-norm-10496597.a1
# False
# Word: patients with helicobacter pylori-chronic active gastritis  Prediction: patient  Real: patient with infectious disease  Type: headwordexact
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: murine  Real: lymphatic system part  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: CD20  Prediction: oil-water separator  Real: lymphocyte  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: CD3  Prediction: rice chip  Real: lymphocyte  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: murine  Real: lymphatic system part  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: cd20-positive cell  Prediction: cell  Real: lymphocyte  Type: jaccard  Habitat: cell
#
# BB-norm-10496597.a1
# False
# Word: Lymphoepithelial  Prediction: pleomorphic  Real: epithelium  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: gastric biopsy  Prediction: stomach  Real: medical sample  Type: jaccard  Habitat: gastric
#
# BB-norm-10496597.a1
# False
# Word: CD20  Prediction: oil-water separator  Real: lymphocyte  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: CD3  Prediction: rice chip  Real: lymphocyte  Type: w2v
#
# BB-norm-10496597.a1
# False
# Word: gastric MALT  Prediction: stomach  Real: lymphatic system part  Type: jaccard  Habitat: gastric
#
# BB-norm-11989773.a1
# False
# Word: chicken nugget processing plant  Prediction: food processing factory  Real: meat industry  Type: jaccard  Habitat: food processing plant
#
# BB-norm-11989773.a1
# False
# Word: chicken  Prediction: chicken  Real: chicken meat  Type: exact
#
# BB-norm-11989773.a1
# False
# Word: food handler  Prediction: food  Real: worker  Type: jaccard  Habitat: food
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: exact
#
# BB-norm-11989773.a1
# False
# Word: chicken  Prediction: chicken  Real: chicken meat  Type: exact
#
# BB-norm-11989773.a1
# False
# Word: chicken nugget processing plant  Prediction: food processing factory  Real: meat industry  Type: jaccard  Habitat: food processing plant
#
# BB-norm-11989773.a1
# False
# Word: PALCAM  Prediction: bovine serum  Real: agar  Type: w2v
#
# BB-norm-11989773.a1
# False
# Word: LPM  Prediction: turbot  Real: agar  Type: w2v
#
# BB-norm-11989773.a1
# False
# Word: HCLA  Prediction: rocket  Real: agar  Type: w2v
#
# BB-norm-11989773.a1
# False
# Word: food handler  Prediction: food  Real: worker  Type: jaccard  Habitat: food
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: exact
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: exact
#
# BB-norm-11989773.a1
# False
# Word: food handler  Prediction: food  Real: worker  Type: jaccard  Habitat: food
#
# BB-norm-12109661.a1
# False
# Word: H. pylori-positive subject  Prediction: human  Real: patient with infectious disease  Type: jaccard  Habitat: subject
#
# BB-norm-12109661.a1
# False
# Word: H. pylori-negative subject  Prediction: human  Real: healthy person  Type: jaccard  Habitat: subject
#
# BB-norm-12109661.a1
# False
# Word: H. pylori-infected monkey  Prediction: monkey  Real: laboratory animal  Type: jaccard  Habitat: monkey
#
# BB-norm-12109661.a1
# False
# Word: control monkey  Prediction: monkey  Real: laboratory animal  Type: jaccard  Habitat: monkey
#
# BB-norm-12109661.a1
# False
# Word: control group  Prediction: cheese  Real: child  Type: jaccard  Habitat: control cheese
#
# BB-norm-12109661.a1
# False
# Word: young japanese people  Prediction: patient with infectious disease  Real: child  Type: jaccard  Habitat: people
#
# BB-norm-1214327.a1
# False
# Word: gastroenteritis patient  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient
#
# BB-norm-1214327.a1
# False
# Word: healthy carrier  Prediction: carrier  Real: healthy person  Type: jaccard  Habitat: carrier
#
# BB-norm-1356998.a1
# False
# Word: human  Prediction: human  Real: patient with infectious disease  Type: exact
#
# BB-norm-1356998.a1
# False
# Word: patients suffering from rickettsial disease of different degrees of severity  Prediction: patient  Real: patient with infectious disease  Type: headwordexact
#
# BB-norm-1356998.a1
# False
# Word: human  Prediction: human  Real: patient with infectious disease  Type: exact
#
# BB-norm-14633026.a1
# False
# Word: Culex pipiens molestus  Prediction: glossina  Real: mosquito  Type: w2v
#
# BB-norm-15293611.a1
# False
# Word: paediatric cystic fibrosis units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
#
# BB-norm-15293611.a1
# False
# Word: adult cystic fibrosis units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
#
# BB-norm-15293611.a1
# False
# Word: cystic fibrosis (CF) units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
#
# BB-norm-15293611.a1
# False
# Word: regional adult CF units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
#
# BB-norm-15293611.a1
# False
# Word: regional paediatric CF units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
#
# BB-norm-15618837.a1
# False
# Word: gastric biopsy  Prediction: stomach  Real: medical sample  Type: jaccard  Habitat: gastric
#
# BB-norm-16273411.a1
# False
# Word: human  Prediction: human  Real: pregnant woman  Type: exact
#
# BB-norm-16273411.a1
# False
# Word: animal  Prediction: animal  Real: female animal  Type: exact
#
# BB-norm-16458564.a1
# False
# Word: study population  Prediction: tortoise  Real: child  Type: jaccard  Habitat: tortoise population
#
# BB-norm-16458564.a1
# False
# Word: child with diarrhea  Prediction: child  Real: ill person  Type: jaccard  Habitat: child
#
# BB-norm-16458564.a1
# False
# Word: age matched healthy controls  Prediction: stratified marine water column  Real: healthy person  Type: w2v
#
# BB-norm-16458564.a1
# False
# Word: child with diarrhea  Prediction: child  Real: ill person  Type: jaccard  Habitat: child
#
# BB-norm-16458564.a1
# False
# Word: child le than two year of age  Prediction: child  Real: baby  Type: jaccard  Habitat: child le than 2 year of age
#
# BB-norm-16458564.a1
# False
# Word: mucous  Prediction: mucous membrane  Real: mucus  Type: jaccard  Habitat: mucous membrane
#
# BB-norm-16458564.a1
# False
# Word: child  Prediction: child  Real: patient with infectious disease  Type: exact
#
# BB-norm-16458564.a1
# False
# Word: child  Prediction: child  Real: patient with infectious disease  Type: exact
#
# BB-norm-16458564.a1
# False
# Word: piped water  Prediction: water  Real: drinking water  Type: jaccard  Habitat: water
#
# BB-norm-16458564.a1
# False
# Word: child  Prediction: child  Real: patient with infectious disease  Type: exact
#
# BB-norm-16458564.a1
# False
# Word: fresh water supply  Prediction: freshwater  Real: drinking water supply  Type: jaccard  Habitat: fresh water
#
# BB-norm-18094887.a1
# False
# Word: Adoratopsylla antiquorum antiquorum  Prediction: osmitopsis asteriscoides  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Ctenocephalides felis felis  Prediction: rat flea  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Polygenis atopus  Prediction: osmitopsis asteriscoides  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Polygenis rimatus  Prediction: ornithodoros moubata  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Polygenis roberti roberti  Prediction: schabziger  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Polygenis tripus  Prediction: antelope  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Rhopalopsyllus lugubris  Prediction: ornithodoros moubata  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Rhopalopsyllus lutzi lutzi  Prediction: ornithodoros moubata  Real: flea  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma aureolatum  Prediction: osmitopsis asteriscoides  Real: tick  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma cajennense  Prediction: ornithodoros moubata  Real: tick  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: Amblyomma dubitatum  Prediction: ornithodoros moubata  Real: tick  Type: w2v
#
# BB-norm-18094887.a1
# False
# Word: ixodes loricatus  Prediction: wood tick  Real: tick  Type: jaccard  Habitat: ixodes ricinus
#
# BB-norm-18094887.a1
# False
# Word: animal blood  Prediction: animal blood  Real: blood  Type: exact
#
# BB-norm-18094887.a1
# False
# Word: human blood  Prediction: monocyte  Real: blood  Type: jaccard  Habitat: human blood monocyte
#
# BB-norm-18094887.a1
# False
# Word: animal serum  Prediction: animal  Real: blood serum  Type: jaccard  Habitat: animal
#
# BB-norm-18094887.a1
# False
# Word: human serum  Prediction: human  Real: experimental medium  Type: jaccard  Habitat: human
#
# BB-norm-18094887.a1
# False
# Word: opossum serum  Prediction: opossum  Real: experimental medium  Type: jaccard  Habitat: opossum
#
# BB-norm-18094887.a1
# False
# Word: dog serum  Prediction: dog  Real: experimental medium  Type: jaccard  Habitat: dog
#
# BB-norm-18094887.a1
# False
# Word: horse serum  Prediction: horse  Real: experimental medium  Type: jaccard  Habitat: horse
#
# BB-norm-18094887.a1
# False
# Word: human serum  Prediction: human  Real: blood serum  Type: jaccard  Habitat: human
#
# BB-norm-18094887.a1
# False
# Word: serum  Prediction: blood serum  Real: experimental medium  Type: exact
#
# BB-norm-18094887.a1
# False
# Word: opossum serum  Prediction: opossum  Real: experimental medium  Type: jaccard  Habitat: opossum
#
# BB-norm-18094887.a1
# False
# Word: dog serum  Prediction: dog  Real: blood serum  Type: jaccard  Habitat: dog
#
# BB-norm-18094887.a1
# False
# Word: horse serum  Prediction: horse  Real: experimental medium  Type: jaccard  Habitat: horse
#
# BB-norm-18694716.a1
# False
# Word: LTQ Orbitrap high resolution mass spectrometer  Prediction: mudpit  Real: laboratory equipment  Type: w2v
#
# BB-norm-18694716.a1
# False
# Word: mixtures of pure compounds and uniformly 13C labeled cell extracts  Prediction: waffle mixture  Real: experimental medium  Type: w2v
#
# BB-norm-18694716.a1
# False
# Word: LTQ Obitrap  Prediction: mudpit  Real: laboratory equipment  Type: w2v
#
# BB-norm-18789156.a1
# False
# Word: monocyte-like THP-1 cell  Prediction: cell  Real: monocyte  Type: jaccard  Habitat: cell
#
# BB-norm-18789156.a1
# False
# Word: human monocyte-like THP-1 cell  Prediction: cell  Real: monocyte  Type: jaccard  Habitat: human cell
#
# BB-norm-18789156.a1
# False
# Word: monocyte-like THP-1 cell  Prediction: cell  Real: cell culture  Type: jaccard  Habitat: cell
#
# BB-norm-18789156.a1
# False
# Word: monocyte-like THP-1 cell  Prediction: cell  Real: monocyte  Type: jaccard  Habitat: cell
#
# BB-norm-18789156.a1
# False
# Word: monocyte-like THP-1 cell  Prediction: cell  Real: cell culture  Type: jaccard  Habitat: cell
#
# BB-norm-18789156.a1
# False
# Word: monocyte-like THP-1 cell  Prediction: cell  Real: cell culture  Type: jaccard  Habitat: cell
#
# BB-norm-19552770.a1
# False
# Word: male bird  Prediction: male animal  Real: livestock  Type: jaccard  Habitat: male
#
# BB-norm-19552770.a1
# False
# Word: female bird  Prediction: bird  Real: partridge  Type: jaccard  Habitat: bird
#
# BB-norm-19552770.a1
# False
# Word: game bird  Prediction: game bird meat  Real: bird  Type: jaccard  Habitat: game bird meat
#
# BB-norm-19552770.a1
# False
# Word: game bird farm  Prediction: game bird meat  Real: animal farm  Type: jaccard  Habitat: game bird meat
#
# BB-norm-19552770.a1
# False
# Word: cloacal swab  Prediction: boot swab  Real: rectal swab  Type: jaccard  Habitat: boot swab
#
# BB-norm-19552770.a1
# False
# Word: younger ones  Prediction: part of living organism  Real: livestock  Type: w2v
#
# BB-norm-19552770.a1
# False
# Word: game bird  Prediction: game bird meat  Real: bird  Type: jaccard  Habitat: game bird meat
#
# BB-norm-19552770.a1
# False
# Word: commercially reared partridge  Prediction: partridge  Real: livestock  Type: jaccard  Habitat: partridge
#
# BB-norm-20174624.a1
# False
# Word: polymorphonuclear leukocyte  Prediction: leukocyte  Real: granulocyte  Type: jaccard  Habitat: leukocyte
#
# BB-norm-20174624.a1
# False
# Word: PMNs  Prediction: neutrophil  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: human monocyte-derived macrophage  Prediction: human  Real: macrophage  Type: jaccard  Habitat: human
#
# BB-norm-20174624.a1
# False
# Word: HMDM  Prediction: breast milk  Real: macrophage  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: human neutrophil  Prediction: human  Real: neutrophil  Type: jaccard  Habitat: human
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: human pmns  Prediction: human  Real: granulocyte  Type: jaccard  Habitat: human
#
# BB-norm-20174624.a1
# False
# Word: cell  Prediction: cell  Real: leukocyte  Type: exact
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: PMN cell  Prediction: cell  Real: granulocyte  Type: jaccard  Habitat: cell
#
# BB-norm-20174624.a1
# False
# Word: human neutrophil  Prediction: human  Real: neutrophil  Type: jaccard  Habitat: human
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: PMN cell  Prediction: cell  Real: granulocyte  Type: jaccard  Habitat: cell
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20174624.a1
# False
# Word: PMN  Prediction: pocosin  Real: granulocyte  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: waste treatment environment  Real: intestine  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stools  Prediction: home-made food  Real: healthy person  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: bottle  Prediction: bottle  Real: fermented milk  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: bottle  Prediction: bottle  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: waste treatment environment  Real: intestine  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stools  Prediction: home-made food  Real: healthy person  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: water content of the stools  Prediction: stomach content  Real: body fluid  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: probiotic group  Prediction: probiotic  Real: adult human  Type: jaccard  Habitat: probiotic
#
# BB-norm-20580604.a1
# False
# Word: placebo group  Prediction: high pressure treated food  Real: adult human  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: probiotic group  Prediction: probiotic  Real: adult human  Type: jaccard  Habitat: probiotic
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: exact
#
# BB-norm-20580604.a1
# False
# Word: placebo groups  Prediction: high pressure treated food  Real: adult human  Type: w2v
#
# BB-norm-20580604.a1
# False
# Word: healthy individuals with soft stool  Prediction: home-made food  Real: healthy person  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perirectal area  Real: anus  Type: jaccard  Habitat: perianal area
#
# BB-norm-21270066.a1
# False
# Word: perianal ulceration  Prediction: perirectal area  Real: ulcer  Type: jaccard  Habitat: perianal area
#
# BB-norm-21270066.a1
# False
# Word: HIV positive men who have sex with men  Prediction: elderly person  Real: man  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: men  Prediction: elderly person  Real: man  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: MSM  Prediction: spirillum  Real: ill person  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: patient  Prediction: patient  Real: patient with infectious disease  Type: exact
#
# BB-norm-21270066.a1
# False
# Word: rectal  Prediction: rectal thermometer  Real: rectum  Type: jaccard  Habitat: rectal thermometer
#
# BB-norm-21270066.a1
# False
# Word: MSM attending sexually transmitted infection clinics  Prediction: urogenital tract part  Real: patient with infectious disease  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: anorectal  Prediction: anus  Real: rectum  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perirectal area  Real: anus  Type: jaccard  Habitat: perianal area
#
# BB-norm-21270066.a1
# False
# Word: rectal  Prediction: rectal thermometer  Real: rectum  Type: jaccard  Habitat: rectal thermometer
#
# BB-norm-21270066.a1
# False
# Word: MSM with proctitis  Prediction: obligate anaerobe  Real: ill person  Type: w2v
#
# BB-norm-21270066.a1
# False
# Word: MSM with perianal ulcer disease  Prediction: animal with disease  Real: ill person  Type: jaccard  Habitat: animal with disease
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perirectal area  Real: anus  Type: jaccard  Habitat: perianal area
#
# BB-norm-21695078.a1
# False
# Word: female mouse model of genital tract chlamydia infection  Prediction: animal with age or sex property  Real: laboratory mouse  Type: w2v
#
# BB-norm-21695078.a1
# False
# Word: oviduct  Prediction: uterus  Real: urogenital tract part  Type: w2v
#
# BB-norm-21695078.a1
# False
# Word: mouse  Prediction: mouse  Real: female animal  Type: exact
#
# BB-norm-21695078.a1
# False
# Word: intranasal  Prediction: aerosol  Real: nose  Type: w2v
#
# BB-norm-21695078.a1
# False
# Word: mouse  Prediction: mouse  Real: laboratory mouse  Type: exact
#
# BB-norm-21695078.a1
# False
# Word: T cells  Prediction: cell  Real: lymphocyte  Type: w2v
#
# BB-norm-21695078.a1
# False
# Word: tlr2-deficient mouse  Prediction: mouse  Real: female animal  Type: jaccard  Habitat: mouse
#
# BB-norm-21894542.a1
# False
# Word: world's ocean  Prediction: ocean trench  Real: marine water  Type: jaccard  Habitat: ocean trench
#
# BB-norm-21894542.a1
# False
# Word: marine organism  Prediction: marine environment  Real: living organism  Type: jaccard  Habitat: marine
#
# BB-norm-23902156.a1
# False
# Word: penicillium-sensitive atopic serum  Prediction: blood serum  Real: experimental medium  Type: jaccard  Habitat: serum
#
# BB-norm-25114119.a1
# False
# Word: mouse  Prediction: mouse  Real: laboratory mouse  Type: exact
#
# BB-norm-25114119.a1
# False
# Word: SCID mouse  Prediction: mouse  Real: laboratory mouse  Type: jaccard  Habitat: mouse
#
# BB-norm-25114119.a1
# False
# Word: mouse  Prediction: mouse  Real: laboratory mouse  Type: exact
#
# BB-norm-25114119.a1
# False
# Word: human macrophage  Prediction: human  Real: macrophage  Type: jaccard  Habitat: human
#
# BB-norm-25204345.a1
# False
# Word: natural fermented koumiss  Prediction: traditional sourdough  Real: kumis  Type: jaccard  Habitat: natural fermented sourdough
#
# BB-norm-351567.a1
# False
# Word: cellophane membrane disk  Prediction: membrane  Real: laboratory equipment  Type: jaccard  Habitat: membrane
#
# BB-norm-3544198.a1
# False
# Word: leprosy patient  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient
#
# BB-norm-3544198.a1
# False
# Word: leprosy patient  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient
#
# BB-norm-3544198.a1
# False
# Word: LL patient  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient
#
# BB-norm-3544198.a1
# False
# Word: nitrocellulose paper  Prediction: paper  Real: experimental medium  Type: jaccard  Habitat: paper
#
# BB-norm-3544198.a1
# False
# Word: LL patient  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient
#
# BB-norm-460951.a1
# False
# Word: child  Prediction: child  Real: patient with infectious disease  Type: exact
#
# BB-norm-9521147.a1
# False
# Word: serum from patient with melioidosis  Prediction: patient  Real: blood serum  Type: jaccard  Habitat: patient with CF
#
# BB-norm-9521147.a1
# False
# Word: patient with melioidosis  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient with CF
#
# BB-norm-9521147.a1
# False
# Word: hyperimmune mouse  Prediction: mouse  Real: laboratory mouse  Type: jaccard  Habitat: mouse
#
# BB-norm-9521147.a1
# False
# Word: hyperimmune mouse serum  Prediction: mouse  Real: blood serum  Type: jaccard  Habitat: mouse
#
# BB-norm-9521147.a1
# False
# Word: microtiter plate  Prediction: dinner plate  Real: laboratory equipment  Type: jaccard  Habitat: dinner plate
#
# BB-norm-9553794.a1
# False
# Word: vacuum  packed cold smoked salmon stored at 5 degrees C  Prediction: vacuum-packed food  Real: salmon meat  Type: w2v
#
# BB-norm-9553794.a1
# False
# Word: modified-atmosphere-packed cold-smoked salmon stored at 5 degrees C  Prediction: salmon  Real: smoked food  Type: headwordexact
#
# BB-norm-9553794.a1
# False
# Word: spoiled cold-smoked salmon  Prediction: salmon  Real: salmon meat  Type: jaccard  Habitat: salmon
#
# BB-norm-9553794.a1
# False
# Word: vacuum-packed cold-smoked salmon  Prediction: salmon  Real: smoked food  Type: jaccard  Habitat: salmon
#
# BB-norm-9553794.a1
# False
# Word: gram-negative flora  Prediction: gram-negative  Real: microflora  Type: jaccard  Habitat: gram-negative
#
# BB-norm-9553794.a1
# False
# Word: vacuum packages  Prediction: tableware  Real: vacuum-packed food  Type: w2v
#
# BB-norm-9553794.a1
# False
# Word: gram-negative flora  Prediction: gram-negative  Real: microflora  Type: jaccard  Habitat: gram-negative
#
# BB-norm-9553794.a1
# False
# Word: vacuum-packed salmon  Prediction: salmon  Real: smoked food  Type: jaccard  Habitat: salmon
#
# BB-norm-9553794.a1
# False
# Word: cold-smoked salmon stored at 5 degrees C  Prediction: salmon  Real: salmon meat  Type: headwordexact
#
# BB-norm-9553794.a1
# False
# Word: salmon  Prediction: salmon  Real: smoked food  Type: exact
#
# BB-norm-9745160.a1
# False
# Word: patient with active duodenal ulcer disease and H pylorus infection  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient with duodenal ulcer
#
# BB-norm-9745160.a1
# False
# Word: ulcer  Prediction: ulcer  Real: duodenal ulcer  Type: exact
#
# BB-norm-9745160.a1
# False
# Word: patient  Prediction: patient  Real: patient with infectious disease  Type: exact
#
# BB-norm-9745160.a1
# False
# Word: patient  Prediction: patient  Real: patient with infectious disease  Type: exact
#
# BB-norm-9745160.a1
# False
# Word: patient  Prediction: patient  Real: patient with infectious disease  Type: exact
#
# BB-norm-9745160.a1
# False
# Word: patient with ppi-based triple therapy  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient with CF
#
# BB-norm-9745160.a1
# False
# Word: patient with bismuth-based triple therapy  Prediction: patient  Real: patient with infectious disease  Type: jaccard  Habitat: patient with CF
#
# BB-norm-9745160.a1
# False
# Word: patient  Prediction: patient  Real: patient with infectious disease  Type: exact
#
# BB-norm-F-14624315-000.a1
# False
# Word: semi-hard cheese  Prediction: cheese  Real: semi soft cheese  Type: jaccard  Habitat: cheese
#
# BB-norm-F-14624315-000.a1
# False
# Word: Maasdammer  Prediction: leerdammer  Real: semi soft cheese  Type: w2v
#
# BB-norm-F-14624315-000.a1
# False
# Word: swiss-type cheese  Prediction: cheese  Real: ripened cheese  Type: jaccard  Habitat: cheese
#
# BB-norm-F-14624315-000.a1
# False
# Word: surface-ripened cheese  Prediction: cheese  Real: ripened cheese  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-003.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-003.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-003.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-003.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-004.a1
# False
# Word: community of staphylococcus and micrococci-corynebacteria groups  Prediction: community  Real: microflora  Type: headwordexact
#
# BB-norm-F-20167385-004.a1
# False
# Word: SB  Prediction: lymphocyte  Real: agar  Type: w2v
#
# BB-norm-F-20167385-004.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-004.a1
# False
# Word: gorgonzola surface  Prediction: gorgonzola  Real: surface of cheese  Type: jaccard  Habitat: gorgonzola
#
# BB-norm-F-20167385-004.a1
# False
# Word: scimudin surface  Prediction: scimudin  Real: surface of cheese  Type: jaccard  Habitat: scimudin
#
# BB-norm-F-20167385-004.a1
# False
# Word: taleggio surface  Prediction: taleggio  Real: surface of cheese  Type: jaccard  Habitat: taleggio
#
# BB-norm-F-20167385-006.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-006.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of taleggio  cheese  Prediction: surface of cheese  Real: microflora  Type: jaccard  Habitat: surface of cheese
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of gorgonzola cheese  Prediction: surface of cheese  Real: microflora  Type: jaccard  Habitat: surface of cheese
#
# BB-norm-F-20167385-007.a1
# False
# Word: surface microbiota of formaggio di fossa cheese  Prediction: formaggio di fossa  Real: microflora  Type: jaccard  Habitat: formaggio di fossa
#
# BB-norm-F-20167385-007.a1
# False
# Word: taleggio  cheese  Prediction: smear ripened cheese  Real: taleggio  Type: jaccard  Habitat: smear soft  cheese
#
# BB-norm-F-20167385-008.a1
# False
# Word: rind  Prediction: food rind  Real: cheese rind  Type: jaccard  Habitat: food rind
#
# BB-norm-F-20167385-009.a1
# False
# Word: casera cheese  Prediction: cheese  Real: valtellina casera  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-010.a1
# False
# Word: gobbeen cheese  Prediction: cheese  Real: gubbeen  Type: jaccard  Habitat: cheese
#
# BB-norm-F-20167385-011.a1
# False
# Word: gorgonzola rind  Prediction: gorgonzola  Real: cheese rind  Type: jaccard  Habitat: gorgonzola
#
# BB-norm-F-20167385-011.a1
# False
# Word: taleggio rind  Prediction: taleggio  Real: cheese rind  Type: jaccard  Habitat: taleggio
#
# BB-norm-F-20167385-011.a1
# False
# Word: scimudin surface  Prediction: scimudin  Real: surface of cheese  Type: jaccard  Habitat: scimudin
#
# BB-norm-F-20167385-011.a1
# False
# Word: gorgonzola surface  Prediction: gorgonzola  Real: surface of cheese  Type: jaccard  Habitat: gorgonzola
#
# BB-norm-F-20167385-011.a1
# False
# Word: fontina rind  Prediction: fontina  Real: cheese rind  Type: jaccard  Habitat: fontina
#
# BB-norm-F-20167385-011.a1
# False
# Word: gorgonzola rind  Prediction: gorgonzola  Real: cheese rind  Type: jaccard  Habitat: gorgonzola
#
# BB-norm-F-20167385-014.a1
# False
# Word: surface of formaggio di  fossa cheese  Prediction: formaggio di fossa  Real: surface of cheese  Type: jaccard  Habitat: formaggio di fossa
#
# BB-norm-F-25036636-000.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: exact
#
# BB-norm-F-25036636-000.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: exact
#
# BB-norm-F-25036636-001.a1
# False
# Word: moist bloomy rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
#
# BB-norm-F-25036636-001.a1
# False
# Word: dry natural rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: exact
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: exact
#
# BB-norm-F-25036636-005.a1
# False
# Word: rind  Prediction: food rind  Real: cheese rind  Type: jaccard  Habitat: food rind
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: exact

# %%
recall = true_pred_count/total_count
recall
# Out:
# 0.5540983606557377

# %%
precision = true_pred_count/(true_pred_count + false_pred_count)
precision
# Out:
# 0.5540983606557377

# %% [markdown]
# # Generate Predictions for Test Set

# %%
annotations_test_2 = {}
for i in range(len(BB_test_txt)):
    a1 = open(test_path + BB_test_a1[i],encoding="utf8").read()
    txt = open(test_path + BB_test_txt[i],encoding="utf8").read()
    pred_file_name = "./test_preds/" + BB_test_a1[i].replace('.a1', '.a2')
    annotations_test_2[BB_test_a1[i]] = predict_habitats(a1, txt, BB_test_a1[i], phrase_reducer, pred_file_name, model)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
import os, re
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import treebank
from nltk.corpus import dependency_treebank
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
import pprint
from nltk.parse.corenlp import CoreNLPDependencyParser

# %%
ps = PorterStemmer()
wnl = WordNetLemmatizer()
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %%
class Habitat:
    oid = -1
    name = ""

# %%
train_path = "./BioNLP-OST-2019_BB-norm_train/"
test_path = "./BioNLP-OST-2019_BB-norm_test/"
dev_path = "./BioNLP-OST-2019_BB-norm_dev/"
BB_train = os.listdir(train_path)
BB_test = os.listdir(test_path)
BB_dev = os.listdir(dev_path)
obp_file = "OntoBiotope_BioNLP-OST-2019.obo"

# %%
ontology = open(obp_file,encoding="utf8").read()

# %%
BB_train_a1 = sorted([name for name in BB_train if name.endswith("a1")])
BB_train_a2 = sorted([name for name in BB_train if name.endswith("a2")])
BB_train_txt = sorted([name for name in BB_train if name.endswith("txt")])

BB_dev_a1 = sorted([name for name in BB_dev if name.endswith("a1")])
BB_dev_a2 = sorted([name for name in BB_dev if name.endswith("a2")])
BB_dev_txt = sorted([name for name in BB_dev if name.endswith("txt")])

BB_test_a1 = sorted([name for name in BB_test if name.endswith("a1")])
BB_test_txt = sorted([name for name in BB_test if name.endswith("txt")])

# %%
def original_phrase(phrase):
    return phrase

# %%
def stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        phrase[i] = ps.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def lemmatize_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        phrase[i] = wnl.lemmatize(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def get_headword(phrase):
    #print(phrase)
    if phrase == phrase.upper():
        return ""
    
    parses = dep_parser.parse(phrase.split())
    triples = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses]
    
    try:
        if(len(triples) > 0 and len(triples[0]) > 0 and len(triples[0][0]) > 0 and len(triples[0][0][0]) > 0 and triples[0][0][0][0] is not None):
            return triples[0][0][0][0]
        else:
            return phrase
    except:
        return phrase

# %%
phrase_reducer = lemmatize_phrase

# %%
def generate_habitat_map(processor):
    habitat_list = ontology.split("\n\n[Term]\n")[1:]
    habitat_map = {}
    habitat_map_originals = {}
    for h in habitat_list:
        #new_habitat = Habitat()
        h = h.split("\n")
        oid = re.findall(r"(?<=id: OBT:)[0-9]+", h[0])[0]
        name = (re.findall(r"(?<=name: ).+", h[1])[0])
        if name != name.upper():
            name = name.lower()
            name = processor(name)
    
        habitat_map[name] = oid
        habitat_map_originals[oid] = name
    
        for h_line in h:
            if "synonym" in h_line:
                synonym_name = (re.findall(r"(?<=synonym: \").+(?=\")", h_line)[0])
                if synonym_name != synonym_name.upper():
                    synonym_name = synonym_name.lower()
                    synonym_name = processor(synonym_name)
                if "EXACT" in h_line and synonym_name not in habitat_map:
                    habitat_map[synonym_name] = oid
    return habitat_map, habitat_map_originals

# %%
habitat_map, habitat_map_originals = generate_habitat_map(phrase_reducer)

# %%
def add_habitats(a1, a2, processor):
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]: 
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = named_entity.lower()
                    named_entity = processor(named_entity)
                if named_entity not in habitat_map:
                    habitat_map[named_entity] = oid
                    #print("Newly added entity:", named_entity, oid)
                    #print("Original entity:", habitat_map_originals[oid])

# %%
for i in range(len(BB_train_txt)):    
    a1 = open(train_path + BB_train_a1[i],encoding="utf8").read()
    a2 = open(train_path + BB_train_a2[i],encoding="utf8").read()
    add_habitats(a1, a2, phrase_reducer)

# %%
def predict_habitats(a1, txt, a1_name, processor, pred_file_name):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    for line in a1:
        found = False
        if "Habitat" in line:
            cands += 1
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = name.lower()
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + "---exact"
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                found = True
            else:
                #print(name)
                pre_named_entity = get_headword(name)
                #print(pre_named_entity)
                named_entity = processor(pre_named_entity)
                if named_entity in habitat_map:
                    matches += 1
                    match = name + " - " + habitat_map[named_entity] + "---headwordexact"
                    print(match)
                    match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                    found = True
        if found:
            pred_file.write("OntoBiotope Annotation:" + line.split("\t")[0] + "\tReferent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
annotations_test = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    pred_file_name = "./dev_preds/" + BB_dev_a2[i]
    annotations_test[BB_dev_a1[i]] = predict_habitats(a1, txt, BB_dev_a1[i], phrase_reducer, pred_file_name)
# Out:
# gastric mucosal-associated lymphoid tissue - 000196---headwordexact
# monoclonal b cells - 000061---headwordexact
# gastric malt - 003215---headwordexact
# patients with atypical lymphoid infiltrates - 003220---headwordexact
# patients with low-grade malt lymphoma - 003220---headwordexact
# patients with helicobacter pylori-chronic active gastritis - 003220---headwordexact
# patients with high-grade primary gastric lymphoma - 003220---headwordexact
# patients with chronic active gastritis - 003220---headwordexact
# cd20-positive cells - 000061---headwordexact
# lymphoepithelial lesions - 000332---headwordexact
# monoclonal b cells - 000061---headwordexact
# gastric malt - 003215---headwordexact
# chicken nugget processing plant - 000393---headwordexact
# chicken nugget - 002729---headwordexact
# chicken nugget - 002729---headwordexact
# chicken nugget processing plant - 000393---headwordexact
# selective agars - 000031---headwordexact
# h. pylori-positive subjects - 002488---headwordexact
# h. pylori-negative subjects - 002488---headwordexact
# h. pylori-infected monkeys - 003107---headwordexact
# control monkeys - 003107---headwordexact
# patients with chronic gastritis - 003220---headwordexact
# patients with gastric cancer - 003220---headwordexact
# young japanese gastric cancer patients - 003220---headwordexact
# young japanese people - 003269---headwordexact
# gastroenteritis patients - 003220---headwordexact
# healthy carriers - 000542---headwordexact
# patients suffering from rickettsial disease of different degrees of severity - 003220---headwordexact
# culicine mosquito - 002142---headwordexact
# productive patients - 003220---headwordexact
# dyspeptic patients - 003220---headwordexact
# patients with chronic dyspepsia - 003220---headwordexact
# patients with h. pylori infection - 003220---headwordexact
# dyspeptic patients - 003220---headwordexact
# placenta of a 38-year-old secondary recurrent aborter - 000811---headwordexact
# children less than five years of age - 003188---headwordexact
# children with diarrhea - 003188---headwordexact
# children with diarrhea - 003188---headwordexact
# children less than two years of age - 003188---headwordexact
# older children - 003188---headwordexact
# children attending the hospitals - 003188---headwordexact
# watery stool - 001102---headwordexact
# mucous stool - 001102---headwordexact
# human blood - 000521---headwordexact
# animal sera - 000524---headwordexact
# human sera - 000524---headwordexact
# opossum sera - 000524---headwordexact
# dog sera - 000524---headwordexact
# horse sera - 000524---headwordexact
# human sera - 000524---headwordexact
# opossum sera - 000524---headwordexact
# dog sera - 000524---headwordexact
# horse sera - 000524---headwordexact
# 13c-labeled cell - 000061---headwordexact
# monocyte-like thp-1 cells - 000061---headwordexact
# human monocyte-like thp-1 cells - 000061---headwordexact
# monocyte-like thp-1 cells - 000061---headwordexact
# monocyte-like thp-1 cells - 000061---headwordexact
# monocyte-like thp-1 cells - 000061---headwordexact
# infected monocytes - 003001---headwordexact
# monocyte-like thp-1 cells - 000061---headwordexact
# commercially reared partridges - 003066---headwordexact
# male birds - 001446---headwordexact
# female birds - 001446---headwordexact
# game bird - 001446---headwordexact
# game bird farm - 000091---headwordexact
# adult partridges - 003066---headwordexact
# game birds - 001446---headwordexact
# human being - 002488---headwordexact
# commercially reared partridges - 003066---headwordexact
# polymorphonuclear leukocytes - 000706---headwordexact
# murine dendritic cells - 000061---headwordexact
# human monocyte-derived macrophages - 002995---headwordexact
# human neutrophils - 003004---headwordexact
# pmn cell - 000061---headwordexact
# human neutrophils - 003004---headwordexact
# pmn cell - 000061---headwordexact
# probiotic fermented milk beverage - 001078---headwordexact
# soft stools - 001102---headwordexact
# fermented milk beverage - 001078---headwordexact
# soft stools - 001102---headwordexact
# healthy adults - 003245---headwordexact
# soft stools - 001102---headwordexact
# probiotic fermented milk beverage - 001078---headwordexact
# soft stool - 001102---headwordexact
# sexually transmitted infection clinics - 002694---headwordexact
# hiv-infected patients presenting with isolated perianal ulcer disease - 003220---headwordexact
# perianal ulcer - 000933---headwordexact
# perianal ulcer - 000933---headwordexact
# tlr2-deficient mice - 002727---headwordexact
# penicillium-sensitive atopic sera - 000524---headwordexact
# scid mice - 002727---headwordexact
# human macrophages - 002995---headwordexact
# natural fermented koumiss - 003210---headwordexact
# urine of leprosy patients - 001367---headwordexact
# leprosy patients - 003220---headwordexact
# urine of leprosy patients - 001367---headwordexact
# leprosy patients - 003220---headwordexact
# urine of ll patients - 001367---headwordexact
# ll patients - 003220---headwordexact
# nitrocellulose paper - 000792---headwordexact
# urine of ll patients - 001367---headwordexact
# ll patients - 003220---headwordexact
# tuberculosis reference laboratory - 001169---headwordexact
# superficial abscesses - 000476---headwordexact
# sera from patients with different clinical spectra and with other infections - 000524---headwordexact
# patients with different clinical spectra and with other infections - 003220---headwordexact
# sera from patients with melioidosis - 000524---headwordexact
# patients with melioidosis - 003220---headwordexact
# hyperimmune mouse - 002727---headwordexact
# hyperimmune mouse sera - 000524---headwordexact
# modified-atmosphere-packed cold-smoked salmon stored at 5 degrees c - 003021---headwordexact
# vacuum-packed cold-smoked salmon - 003021---headwordexact
# vacuum-packed salmon - 003021---headwordexact
# lab microflora - 000113---headwordexact
# cold-smoked salmon stored at 5 degrees c - 003021---headwordexact
# patients with active duodenal ulcer disease and h pylori infection - 003220---headwordexact
# patients with ppi-based triple therapy - 003220---headwordexact
# patients with bismuth-based triple therapy - 003220---headwordexact
# semi-hard cheeses - 001480---headwordexact
# swiss-type cheeses - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# taleggio cheeses - 001480---headwordexact
# formaggio di fossa cheeses - 001480---headwordexact
# soft smear cheeses - 001480---headwordexact
# casera cheese - 001480---headwordexact
# casera cheeses - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# casera cheese - 001480---headwordexact
# formaggio di fossa cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# casera cheese - 001480---headwordexact
# community of staphylococcus and micrococci-corynebacteria groups - 002697---headwordexact
# enterococcus  selective agar - 000031---headwordexact
# casera cheeses - 001480---headwordexact
# taleggio cheeses - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# rogosa agar - 000031---headwordexact
# pseudomonas agar - 000031---headwordexact
# scimudin cheese - 001480---headwordexact
# taleggio cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# gorgonzola cheese - 001480---headwordexact
# taleggio cheeses - 001480---headwordexact
# casera cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# taleggio cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# casera cheeses - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# formaggio di fossa cheeses - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# taleggio  cheeses - 001480---headwordexact
# scimudin cheese - 001480---headwordexact
# casera cheese - 001480---headwordexact
# gorgonzola cheese - 001480---headwordexact
# scimudin cheese - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# gobbeen cheese - 001480---headwordexact
# fontina cheese - 001480---headwordexact
# gorgonzola cheeses - 001480---headwordexact
# scimudin cheeses - 001480---headwordexact
# formaggio di fossa cheese - 001480---headwordexact
# fermented fish - 002793---headwordexact
# greek cheese - 001480---headwordexact
# formaggio di  fossa cheese - 001480---headwordexact
# polar seawater - 003105---headwordexact
# mature cheeses - 001480---headwordexact

# %%
annotations_test
# Out:
# {'BB-norm-10496597.a1': {'T3': ['001792', 'gastric', 'exact'],
#   'T4': ['001577', 'gastric mucosa', 'exact'],
#   'T5': ['000196',
#    'gastric mucosal-associated lymphoid tissue',
#    'headwordexact',
#    'tissue'],
#   'T7': ['001792', 'gastric', 'exact'],
#   'T9': ['000061', 'monoclonal b cells', 'headwordexact', 'cell'],
#   'T11': ['001792', 'gastric', 'exact'],
#   'T12': ['003215', 'gastric malt', 'headwordexact', 'malt'],
#   'T13': ['003220',
#    'patients with atypical lymphoid infiltrates',
#    'headwordexact',
#    'patient'],
#   'T14': ['003220',
#    'patients with low-grade malt lymphoma',
#    'headwordexact',
#    'patient'],
#   'T15': ['003220',
#    'patients with helicobacter pylori-chronic active gastritis',
#    'headwordexact',
#    'patient'],
#   'T16': ['003220',
#    'patients with high-grade primary gastric lymphoma',
#    'headwordexact',
#    'patient'],
#   'T17': ['001792', 'gastric', 'exact'],
#   'T23': ['003220',
#    'patients with chronic active gastritis',
#    'headwordexact',
#    'patient'],
#   'T24': ['000061', 'cd20-positive cells', 'headwordexact', 'cell'],
#   'T26': ['001623', 'b cell', 'exact'],
#   'T27': ['001623', 't cell', 'exact'],
#   'T30': ['000332', 'lymphoepithelial lesions', 'headwordexact', 'lesion'],
#   'T31': ['001792', 'gastric', 'exact'],
#   'T33': ['000061', 'monoclonal b cells', 'headwordexact', 'cell'],
#   'T37': ['003215', 'gastric malt', 'headwordexact', 'malt'],
#   'T38': ['001792', 'gastric', 'exact']},
#  'BB-norm-11989773.a1': {'T5': ['000393',
#    'chicken nugget processing plant',
#    'headwordexact',
#    'plant'],
#   'T6': ['003314', 'chicken', 'exact'],
#   'T7': ['002729', 'chicken nugget', 'headwordexact', 'nugget'],
#   'T12': ['000008', 'food', 'exact'],
#   'T13': ['003314', 'chicken', 'exact'],
#   'T14': ['002729', 'chicken nugget', 'headwordexact', 'nugget'],
#   'T15': ['000393',
#    'chicken nugget processing plant',
#    'headwordexact',
#    'plant'],
#   'T16': ['000031', 'selective agars', 'headwordexact', 'agar'],
#   'T21': ['000008', 'food', 'exact'],
#   'T22': ['000008', 'food', 'exact']},
#  'BB-norm-12109661.a1': {'T4': ['001792', 'gastric', 'exact'],
#   'T5': ['001792', 'gastric', 'exact'],
#   'T8': ['001792', 'gastric', 'exact'],
#   'T10': ['002488', 'h. pylori-positive subjects', 'headwordexact', 'subject'],
#   'T12': ['002488', 'h. pylori-negative subjects', 'headwordexact', 'subject'],
#   'T13': ['001792', 'gastric', 'exact'],
#   'T14': ['001577', 'gastric mucosa', 'exact'],
#   'T16': ['003107', 'h. pylori-infected monkeys', 'headwordexact', 'monkey'],
#   'T17': ['003107', 'control monkeys', 'headwordexact', 'monkey'],
#   'T19': ['003188', 'child', 'exact'],
#   'T20': ['001577', 'gastric mucosa', 'exact'],
#   'T21': ['001792', 'gastric', 'exact'],
#   'T23': ['001792', 'gastric', 'exact'],
#   'T24': ['001792', 'gastric', 'exact'],
#   'T26': ['003220',
#    'patients with chronic gastritis',
#    'headwordexact',
#    'patient'],
#   'T27': ['003220',
#    'patients with gastric cancer',
#    'headwordexact',
#    'patient'],
#   'T28': ['001792', 'gastric', 'exact'],
#   'T30': ['003220',
#    'young japanese gastric cancer patients',
#    'headwordexact',
#    'patient'],
#   'T31': ['001792', 'gastric', 'exact'],
#   'T34': ['001792', 'gastric', 'exact'],
#   'T35': ['003269', 'young japanese people', 'headwordexact', 'people'],
#   'T37': ['001792', 'gastric', 'exact'],
#   'T38': ['001577', 'gastric mucosa', 'exact'],
#   'T39': ['001792', 'gastric', 'exact']},
#  'BB-norm-1214327.a1': {'T4': ['003220', 'clinical', 'exact'],
#   'T6': ['003220', 'clinical', 'exact'],
#   'T7': ['003220', 'gastroenteritis patients', 'headwordexact', 'patient'],
#   'T8': ['000542', 'healthy carriers', 'headwordexact', 'carrier'],
#   'T9': ['000468', 'water', 'exact']},
#  'BB-norm-1356998.a1': {'T3': ['002488', 'human', 'exact'],
#   'T4': ['001821', 'tick', 'exact'],
#   'T9': ['001821', 'tick', 'exact'],
#   'T10': ['002488', 'human', 'exact'],
#   'T11': ['002488', 'human', 'exact'],
#   'T12': ['003220',
#    'patients suffering from rickettsial disease of different degrees of severity',
#    'headwordexact',
#    'patient'],
#   'T17': ['001821', 'tick', 'exact'],
#   'T18': ['002488', 'human', 'exact']},
#  'BB-norm-14633026.a1': {'T21': ['002142',
#    'culicine mosquito',
#    'headwordexact',
#    'mosquito']},
#  'BB-norm-15293611.a1': {'T7': ['003245', 'adult', 'exact'],
#   'T10': ['001335', 'sputum', 'exact'],
#   'T11': ['003220', 'productive patients', 'headwordexact', 'patient'],
#   'T15': ['003245', 'adult', 'exact'],
#   'T18': ['001335', 'sputum', 'exact'],
#   'T19': ['003220', 'patient', 'exact'],
#   'T20': ['002694', 'clinic', 'exact'],
#   'T22': ['003220', 'patient', 'exact'],
#   'T23': ['003220', 'patient', 'exact'],
#   'T24': ['003220', 'patient', 'exact'],
#   'T25': ['003220', 'patient', 'exact'],
#   'T26': ['003220', 'patient', 'exact'],
#   'T27': ['003220', 'patient', 'exact'],
#   'T28': ['000716', 'lung', 'exact'],
#   'T30': ['003220', 'patient', 'exact']},
#  'BB-norm-15618837.a1': {'T8': ['003220',
#    'dyspeptic patients',
#    'headwordexact',
#    'patient'],
#   'T9': ['003220',
#    'patients with chronic dyspepsia',
#    'headwordexact',
#    'patient'],
#   'T10': ['002694', 'clinic', 'exact'],
#   'T12': ['001792', 'gastric', 'exact'],
#   'T14': ['003220',
#    'patients with h. pylori infection',
#    'headwordexact',
#    'patient'],
#   'T21': ['003220', 'dyspeptic patients', 'headwordexact', 'patient']},
#  'BB-norm-16273411.a1': {'T6': ['002488', 'human', 'exact'],
#   'T7': ['000193', 'animal', 'exact'],
#   'T8': ['002488', 'human', 'exact'],
#   'T10': ['000811',
#    'placenta of a 38-year-old secondary recurrent aborter',
#    'headwordexact',
#    'placenta']},
#  'BB-norm-16458564.a1': {'T6': ['003188', 'child', 'exact'],
#   'T7': ['003188',
#    'children less than five years of age',
#    'headwordexact',
#    'child'],
#   'T9': ['003188', 'children with diarrhea', 'headwordexact', 'child'],
#   'T14': ['003188', 'children with diarrhea', 'headwordexact', 'child'],
#   'T26': ['003188',
#    'children less than two years of age',
#    'headwordexact',
#    'child'],
#   'T30': ['003188', 'older children', 'headwordexact', 'child'],
#   'T37': ['003188',
#    'children attending the hospitals',
#    'headwordexact',
#    'child'],
#   'T38': ['002714', 'hospital', 'exact'],
#   'T39': ['001102', 'watery stool', 'headwordexact', 'stool'],
#   'T40': ['001102', 'mucous stool', 'headwordexact', 'stool'],
#   'T42': ['001102', 'stool', 'exact'],
#   'T43': ['002714', 'hospital', 'exact'],
#   'T44': ['003188', 'child', 'exact'],
#   'T45': ['003188', 'child', 'exact'],
#   'T47': ['000702', 'latrine', 'exact'],
#   'T48': ['003491', 'mother', 'exact'],
#   'T49': ['003188', 'child', 'exact'],
#   'T50': ['003491', 'mother', 'exact'],
#   'T57': ['003188', 'child', 'exact'],
#   'T58': ['002455', 'fresh water', 'exact'],
#   'T61': ['003188', 'child', 'exact']},
#  'BB-norm-16514151.a1': {},
#  'BB-norm-18094887.a1': {'T5': ['000193', 'animal', 'exact'],
#   'T6': ['002488', 'human', 'exact'],
#   'T7': ['001821', 'tick', 'exact'],
#   'T8': ['002034', 'flea', 'exact'],
#   'T9': ['002034', 'flea', 'exact'],
#   'T18': ['001821', 'tick', 'exact'],
#   'T23': ['002693', 'rhipicephalus sanguineus', 'exact'],
#   'T24': ['003092', 'dog', 'exact'],
#   'T25': ['003086', 'cat', 'exact'],
#   'T26': ['002161', 'opossum', 'exact'],
#   'T29': ['002034', 'flea', 'exact'],
#   'T31': ['001821', 'tick', 'exact'],
#   'T32': ['001863', 'animal blood', 'exact'],
#   'T33': ['000193', 'animal', 'exact'],
#   'T34': ['000521', 'human blood', 'headwordexact', 'blood'],
#   'T35': ['002488', 'human', 'exact'],
#   'T37': ['000193', 'animal', 'exact'],
#   'T38': ['000524', 'animal sera', 'headwordexact', 'serum'],
#   'T39': ['002488', 'human', 'exact'],
#   'T40': ['000524', 'human sera', 'headwordexact', 'serum'],
#   'T46': ['000524', 'opossum sera', 'headwordexact', 'serum'],
#   'T47': ['002161', 'opossum', 'exact'],
#   'T48': ['000524', 'dog sera', 'headwordexact', 'serum'],
#   'T49': ['003092', 'dog', 'exact'],
#   'T50': ['003320', 'horse', 'exact'],
#   'T51': ['000524', 'horse sera', 'headwordexact', 'serum'],
#   'T52': ['000524', 'human sera', 'headwordexact', 'serum'],
#   'T53': ['002488', 'human', 'exact'],
#   'T56': ['000524', 'serum', 'exact'],
#   'T58': ['000524', 'opossum sera', 'headwordexact', 'serum'],
#   'T59': ['002161', 'opossum', 'exact'],
#   'T60': ['003092', 'dog', 'exact'],
#   'T61': ['000524', 'dog sera', 'headwordexact', 'serum'],
#   'T62': ['003320', 'horse', 'exact'],
#   'T63': ['000524', 'horse sera', 'headwordexact', 'serum'],
#   'T67': ['000193', 'animal', 'exact'],
#   'T68': ['002488', 'human', 'exact']},
#  'BB-norm-18694716.a1': {'T5': ['000061',
#    '13c-labeled cell',
#    'headwordexact',
#    'cell']},
#  'BB-norm-18789156.a1': {'T6': ['000061',
#    'monocyte-like thp-1 cells',
#    'headwordexact',
#    'cell'],
#   'T9': ['002488', 'human', 'exact'],
#   'T11': ['000320', 'immune cell', 'exact'],
#   'T12': ['003001', 'monocyte', 'exact'],
#   'T13': ['002995', 'macrophage', 'exact'],
#   'T15': ['000061', 'cell', 'exact'],
#   'T20': ['002488', 'human', 'exact'],
#   'T21': ['000061',
#    'human monocyte-like thp-1 cells',
#    'headwordexact',
#    'cell'],
#   'T22': ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell'],
#   'T25': ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell'],
#   'T27': ['002530', 'murine', 'exact'],
#   'T31': ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell'],
#   'T32': ['000061', 'cell', 'exact'],
#   'T36': ['000196', 'host tissue', 'exact'],
#   'T38': ['003001', 'infected monocytes', 'headwordexact', 'monocyte'],
#   'T39': ['002488', 'human', 'exact'],
#   'T42': ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']},
#  'BB-norm-19004249.a1': {'T4': ['002488', 'human', 'exact']},
#  'BB-norm-19339076.a1': {'T4': ['000514', 'bile', 'exact'],
#   'T7': ['000514', 'bile', 'exact'],
#   'T10': ['000514', 'bile', 'exact'],
#   'T13': ['000514', 'bile', 'exact'],
#   'T16': ['000514', 'bile', 'exact'],
#   'T20': ['000514', 'bile', 'exact'],
#   'T22': ['000514', 'bile', 'exact'],
#   'T24': ['000514', 'bile', 'exact'],
#   'T28': ['000514', 'bile', 'exact'],
#   'T30': ['000514', 'bile', 'exact'],
#   'T33': ['000514', 'bile', 'exact'],
#   'T35': ['000514', 'bile', 'exact'],
#   'T38': ['000514', 'bile', 'exact'],
#   'T40': ['000514', 'bile', 'exact'],
#   'T43': ['000514', 'bile', 'exact'],
#   'T49': ['000514', 'bile', 'exact'],
#   'T52': ['000514', 'bile', 'exact'],
#   'T54': ['000514', 'bile', 'exact']},
#  'BB-norm-19552770.a1': {'T8': ['003066', 'partridge', 'exact'],
#   'T12': ['003066',
#    'commercially reared partridges',
#    'headwordexact',
#    'partridge'],
#   'T16': ['003066', 'partridge', 'exact'],
#   'T17': ['001446', 'male birds', 'headwordexact', 'bird'],
#   'T18': ['001446', 'female birds', 'headwordexact', 'bird'],
#   'T19': ['001446', 'game bird', 'headwordexact', 'bird'],
#   'T20': ['000091', 'game bird farm', 'headwordexact', 'farm'],
#   'T31': ['003066', 'adult partridges', 'headwordexact', 'partridge'],
#   'T33': ['001446', 'game birds', 'headwordexact', 'bird'],
#   'T35': ['002488', 'human being', 'headwordexact', 'human'],
#   'T38': ['003066',
#    'commercially reared partridges',
#    'headwordexact',
#    'partridge']},
#  'BB-norm-19621381.a1': {},
#  'BB-norm-20174624.a1': {'T5': ['003004', 'neutrophil', 'exact'],
#   'T7': ['000061', 'cell', 'exact'],
#   'T9': ['002488', 'human', 'exact'],
#   'T11': ['002995', 'macrophage', 'exact'],
#   'T12': ['000706',
#    'polymorphonuclear leukocytes',
#    'headwordexact',
#    'leukocyte'],
#   'T13': ['003004', 'neutrophil', 'exact'],
#   'T17': ['002488', 'human', 'exact'],
#   'T22': ['002995', 'murine macrophage', 'exact'],
#   'T23': ['000061', 'murine dendritic cells', 'headwordexact', 'cell'],
#   'T24': ['002530', 'murine', 'exact'],
#   'T26': ['003004', 'neutrophil', 'exact'],
#   'T30': ['002995',
#    'human monocyte-derived macrophages',
#    'headwordexact',
#    'macrophage'],
#   'T31': ['002488', 'human', 'exact'],
#   'T33': ['003004', 'neutrophil', 'exact'],
#   'T35': ['003004', 'human neutrophils', 'headwordexact', 'neutrophil'],
#   'T36': ['002488', 'human', 'exact'],
#   'T42': ['002488', 'human', 'exact'],
#   'T45': ['000061', 'cell', 'exact'],
#   'T50': ['000061', 'pmn cell', 'headwordexact', 'cell'],
#   'T54': ['003004', 'human neutrophils', 'headwordexact', 'neutrophil'],
#   'T55': ['002488', 'human', 'exact'],
#   'T59': ['000061', 'pmn cell', 'headwordexact', 'cell'],
#   'T62': ['002488', 'human', 'exact']},
#  'BB-norm-20580604.a1': {'T3': ['001078',
#    'probiotic fermented milk beverage',
#    'headwordexact',
#    'beverage'],
#   'T5': ['002810', 'intestinal', 'exact'],
#   'T6': ['000113', 'intestinal microbiota', 'exact'],
#   'T9': ['001102', 'soft stools', 'headwordexact', 'stool'],
#   'T10': ['001078', 'fermented milk beverage', 'headwordexact', 'beverage'],
#   'T13': ['001456', 'bottle', 'exact'],
#   'T14': ['000827', 'probiotic', 'exact'],
#   'T15': ['001456', 'bottle', 'exact'],
#   'T16': ['000113', 'intestinal microbiota', 'exact'],
#   'T17': ['002810', 'intestinal', 'exact'],
#   'T20': ['001102', 'soft stools', 'headwordexact', 'stool'],
#   'T21': ['003245', 'healthy adults', 'headwordexact', 'adult'],
#   'T22': ['001102', 'soft stools', 'headwordexact', 'stool'],
#   'T23': ['000827', 'probiotic', 'exact'],
#   'T24': ['000827', 'probiotic', 'exact'],
#   'T25': ['001102', 'stool', 'exact'],
#   'T27': ['001102', 'stool', 'exact'],
#   'T28': ['000827', 'probiotic', 'exact'],
#   'T32': ['001102', 'stool', 'exact'],
#   'T33': ['000827', 'probiotic', 'exact'],
#   'T35': ['001102', 'stool', 'exact'],
#   'T36': ['000827', 'probiotic', 'exact'],
#   'T38': ['000827', 'probiotic', 'exact'],
#   'T40': ['001078',
#    'probiotic fermented milk beverage',
#    'headwordexact',
#    'beverage'],
#   'T41': ['002810', 'intestine', 'exact'],
#   'T42': ['001102', 'stool', 'exact'],
#   'T45': ['001102', 'soft stool', 'headwordexact', 'stool']},
#  'BB-norm-21270066.a1': {'T9': ['003220', 'patient', 'exact'],
#   'T12': ['002694',
#    'sexually transmitted infection clinics',
#    'headwordexact',
#    'clinic'],
#   'T14': ['003220',
#    'hiv-infected patients presenting with isolated perianal ulcer disease',
#    'headwordexact',
#    'patient'],
#   'T16': ['000933', 'perianal ulcer', 'headwordexact', 'ulcer'],
#   'T24': ['000933', 'perianal ulcer', 'headwordexact', 'ulcer']},
#  'BB-norm-21543877.a1': {},
#  'BB-norm-21695078.a1': {'T5': ['000407', 'respiratory', 'exact'],
#   'T8': ['003263', 'infant', 'exact'],
#   'T10': ['000643', 'genital tract', 'exact'],
#   'T14': ['002727', 'mouse', 'exact'],
#   'T17': ['002727', 'mouse', 'exact'],
#   'T18': ['000716', 'lung', 'exact'],
#   'T19': ['003004', 'neutrophil', 'exact'],
#   'T21': ['000716', 'lung', 'exact'],
#   'T22': ['002727', 'tlr2-deficient mice', 'headwordexact', 'mouse'],
#   'T23': ['000716', 'lung', 'exact'],
#   'T26': ['001654', 'mucosal surface', 'exact']},
#  'BB-norm-21894542.a1': {'T10': ['000338', 'marine environment', 'exact'],
#   'T12': ['000338', 'marine', 'exact']},
#  'BB-norm-23902156.a1': {'T9': ['000524',
#    'penicillium-sensitive atopic sera',
#    'headwordexact',
#    'serum']},
#  'BB-norm-25114119.a1': {'T8': ['002727', 'mouse', 'exact'],
#   'T10': ['002727', 'scid mice', 'headwordexact', 'mouse'],
#   'T12': ['000030', 'aerosol', 'exact'],
#   'T17': ['002530', 'murine', 'exact'],
#   'T20': ['002727', 'mouse', 'exact'],
#   'T24': ['002995', 'macrophage', 'exact'],
#   'T27': ['002488', 'human', 'exact'],
#   'T28': ['002995', 'human macrophages', 'headwordexact', 'macrophage']},
#  'BB-norm-25204345.a1': {'T9': ['003210',
#    'natural fermented koumiss',
#    'headwordexact',
#    'koumiss'],
#   'T10': ['003241', 'yoghurt', 'exact']},
#  'BB-norm-351567.a1': {},
#  'BB-norm-3544198.a1': {'T4': ['001367',
#    'urine of leprosy patients',
#    'headwordexact',
#    'urine'],
#   'T5': ['003220', 'leprosy patients', 'headwordexact', 'patient'],
#   'T7': ['001367', 'urine of leprosy patients', 'headwordexact', 'urine'],
#   'T8': ['003220', 'leprosy patients', 'headwordexact', 'patient'],
#   'T9': ['001367', 'urine', 'exact'],
#   'T10': ['001367', 'urine of ll patients', 'headwordexact', 'urine'],
#   'T11': ['003220', 'll patients', 'headwordexact', 'patient'],
#   'T12': ['000792', 'nitrocellulose paper', 'headwordexact', 'paper'],
#   'T13': ['001367', 'urine of ll patients', 'headwordexact', 'urine'],
#   'T14': ['003220', 'll patients', 'headwordexact', 'patient']},
#  'BB-norm-460951.a1': {'T6': ['001169',
#    'tuberculosis reference laboratory',
#    'headwordexact',
#    'laboratory'],
#   'T10': ['000718', 'lymph node', 'exact'],
#   'T11': ['000717', 'lymph', 'exact'],
#   'T12': ['003188', 'child', 'exact'],
#   'T14': ['000476', 'superficial abscesses', 'headwordexact', 'abscess']},
#  'BB-norm-47483.a1': {'T7': ['003220', 'clinical', 'exact']},
#  'BB-norm-5526468.a1': {'T3': ['002488', 'human', 'exact']},
#  'BB-norm-8559802.a1': {},
#  'BB-norm-9521147.a1': {'T7': ['003220', 'clinical', 'exact'],
#   'T9': ['003220', 'clinical', 'exact'],
#   'T12': ['000524',
#    'sera from patients with different clinical spectra and with other infections',
#    'headwordexact',
#    'serum'],
#   'T13': ['003220',
#    'patients with different clinical spectra and with other infections',
#    'headwordexact',
#    'patient'],
#   'T16': ['003220', 'clinical', 'exact'],
#   'T18': ['000427', 'soil', 'exact'],
#   'T20': ['000427', 'soil', 'exact'],
#   'T21': ['000524',
#    'sera from patients with melioidosis',
#    'headwordexact',
#    'serum'],
#   'T22': ['003220', 'patients with melioidosis', 'headwordexact', 'patient'],
#   'T23': ['002727', 'hyperimmune mouse', 'headwordexact', 'mouse'],
#   'T24': ['000524', 'hyperimmune mouse sera', 'headwordexact', 'serum']},
#  'BB-norm-9553794.a1': {'T5': ['003021',
#    'modified-atmosphere-packed cold-smoked salmon stored at 5 degrees c',
#    'headwordexact',
#    'salmon'],
#   'T6': ['000113', 'microflora', 'exact'],
#   'T11': ['003021',
#    'vacuum-packed cold-smoked salmon',
#    'headwordexact',
#    'salmon'],
#   'T12': ['000113', 'microflora', 'exact'],
#   'T21': ['003021', 'vacuum-packed salmon', 'headwordexact', 'salmon'],
#   'T29': ['000113', 'lab microflora', 'headwordexact', 'microflora'],
#   'T35': ['003021',
#    'cold-smoked salmon stored at 5 degrees c',
#    'headwordexact',
#    'salmon'],
#   'T36': ['003021', 'salmon', 'exact']},
#  'BB-norm-9745160.a1': {'T6': ['001534', 'duodenal', 'exact'],
#   'T7': ['001533', 'duodenal ulcer', 'exact'],
#   'T9': ['001533', 'duodenal ulcer', 'exact'],
#   'T10': ['001534', 'duodenal', 'exact'],
#   'T13': ['003220', 'patient', 'exact'],
#   'T14': ['003220',
#    'patients with active duodenal ulcer disease and h pylori infection',
#    'headwordexact',
#    'patient'],
#   'T15': ['001533', 'duodenal ulcer', 'exact'],
#   'T16': ['001534', 'duodenal', 'exact'],
#   'T21': ['000933', 'ulcer', 'exact'],
#   'T22': ['003220', 'patient', 'exact'],
#   'T23': ['003220', 'patient', 'exact'],
#   'T26': ['000933', 'ulcer', 'exact'],
#   'T27': ['003220', 'patient', 'exact'],
#   'T28': ['003220',
#    'patients with ppi-based triple therapy',
#    'headwordexact',
#    'patient'],
#   'T29': ['003220',
#    'patients with bismuth-based triple therapy',
#    'headwordexact',
#    'patient'],
#   'T30': ['003220', 'patient', 'exact'],
#   'T32': ['001534', 'duodenal', 'exact'],
#   'T33': ['001533', 'duodenal ulcer', 'exact']},
#  'BB-norm-F-14624315-000.a1': {'T1': ['001480',
#    'semi-hard cheeses',
#    'headwordexact',
#    'cheese'],
#   'T2': ['003474', 'gouda', 'exact'],
#   'T3': ['003469', 'cheddar', 'exact'],
#   'T6': ['001208', 'dairy product', 'exact'],
#   'T9': ['001480', 'swiss-type cheeses', 'headwordexact', 'cheese'],
#   'T13': ['003241', 'yoghurt', 'exact'],
#   'T17': ['003428', 'surface-ripened cheese', 'exact']},
#  'BB-norm-F-14624315-001.a1': {},
#  'BB-norm-F-14624315-002.a1': {},
#  'BB-norm-F-14624315-003.a1': {},
#  'BB-norm-F-14624315-004.a1': {},
#  'BB-norm-F-14624315-005.a1': {},
#  'BB-norm-F-14624315-006.a1': {},
#  'BB-norm-F-14624315-007.a1': {'T3': ['001988', 'dairy industry', 'exact']},
#  'BB-norm-F-20167385-000.a1': {'T6': ['001341', 'surface of cheese', 'exact'],
#   'T7': ['001480', 'cheese', 'exact'],
#   'T8': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T9': ['001480', 'taleggio cheeses', 'headwordexact', 'cheese'],
#   'T10': ['001480', 'formaggio di fossa cheeses', 'headwordexact', 'cheese'],
#   'T11': ['003522', 'scimudin', 'exact']},
#  'BB-norm-F-20167385-001.a1': {},
#  'BB-norm-F-20167385-002.a1': {'T1': ['001480',
#    'soft smear cheeses',
#    'headwordexact',
#    'cheese']},
#  'BB-norm-F-20167385-003.a1': {'T2': ['003473', 'formaggio di fossa', 'exact'],
#   'T3': ['003504', 'gorgonzola', 'exact'],
#   'T4': ['003525', 'taleggio', 'exact'],
#   'T5': ['003522', 'scimudin', 'exact'],
#   'T7': ['001480', 'cheese', 'exact'],
#   'T10': ['001480', 'casera cheese', 'headwordexact', 'cheese'],
#   'T12': ['003522', 'scimudin', 'exact'],
#   'T14': ['001480', 'casera cheeses', 'headwordexact', 'cheese'],
#   'T15': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T18': ['003473', 'formaggio di fossa', 'exact'],
#   'T20': ['001480', 'casera cheese', 'headwordexact', 'cheese'],
#   'T21': ['001480', 'formaggio di fossa cheeses', 'headwordexact', 'cheese'],
#   'T22': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T25': ['001480', 'casera cheese', 'headwordexact', 'cheese']},
#  'BB-norm-F-20167385-004.a1': {'T1': ['002697',
#    'community of staphylococcus and micrococci-corynebacteria groups',
#    'headwordexact',
#    'community'],
#   'T5': ['001480', 'cheese', 'exact'],
#   'T6': ['001341', 'cheese surface', 'exact'],
#   'T8': ['003473', 'formaggio di fossa', 'exact'],
#   'T10': ['000031', 'enterococcus  selective agar', 'headwordexact', 'agar'],
#   'T13': ['001480', 'casera cheeses', 'headwordexact', 'cheese'],
#   'T14': ['001480', 'taleggio cheeses', 'headwordexact', 'cheese'],
#   'T15': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T16': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T18': ['000031', 'rogosa agar', 'headwordexact', 'agar'],
#   'T19': ['001480', 'cheese', 'exact'],
#   'T20': ['001341', 'cheese surface', 'exact'],
#   'T21': ['000031', 'pseudomonas agar', 'headwordexact', 'agar'],
#   'T24': ['003504', 'gorgonzola', 'exact'],
#   'T26': ['003522', 'scimudin', 'exact'],
#   'T27': ['003525', 'taleggio', 'exact'],
#   'T31': ['003473', 'formaggio di fossa', 'exact'],
#   'T32': ['001480', 'cheese', 'exact'],
#   'T33': ['001341', 'cheese surface', 'exact']},
#  'BB-norm-F-20167385-005.a1': {'T11': ['001480',
#    'scimudin cheese',
#    'headwordexact',
#    'cheese']},
#  'BB-norm-F-20167385-006.a1': {'T2': ['001480',
#    'taleggio cheeses',
#    'headwordexact',
#    'cheese'],
#   'T3': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T4': ['001480', 'gorgonzola cheese', 'headwordexact', 'cheese'],
#   'T5': ['001480', 'taleggio cheeses', 'headwordexact', 'cheese'],
#   'T6': ['001480', 'casera cheeses', 'headwordexact', 'cheese'],
#   'T7': ['003522', 'scimudin', 'exact'],
#   'T8': ['003504', 'gorgonzola', 'exact'],
#   'T9': ['003525', 'taleggio', 'exact'],
#   'T10': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T12': ['001480', 'taleggio cheeses', 'headwordexact', 'cheese'],
#   'T13': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T14': ['001480', 'casera cheeses', 'headwordexact', 'cheese'],
#   'T15': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T16': ['003504', 'gorgonzola', 'exact'],
#   'T17': ['003522', 'scimudin', 'exact'],
#   'T18': ['003525', 'taleggio', 'exact']},
#  'BB-norm-F-20167385-007.a1': {'T4': ['001480',
#    'formaggio di fossa cheeses',
#    'headwordexact',
#    'cheese'],
#   'T5': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T6': ['001480', 'taleggio  cheeses', 'headwordexact', 'cheese']},
#  'BB-norm-F-20167385-008.a1': {'T2': ['001480',
#    'scimudin cheese',
#    'headwordexact',
#    'cheese'],
#   'T7': ['001480', 'cheese', 'exact']},
#  'BB-norm-F-20167385-009.a1': {'T2': ['001480',
#    'casera cheese',
#    'headwordexact',
#    'cheese'],
#   'T5': ['001480', 'gorgonzola cheese', 'headwordexact', 'cheese'],
#   'T6': ['001480', 'scimudin cheese', 'headwordexact', 'cheese'],
#   'T8': ['003494', 'smear cheese', 'exact']},
#  'BB-norm-F-20167385-010.a1': {'T4': ['001481', 'cheese rind', 'exact'],
#   'T5': ['001480', 'cheese', 'exact'],
#   'T9': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T10': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T12': ['001480', 'gobbeen cheese', 'headwordexact', 'cheese'],
#   'T18': ['001208', 'dairy', 'exact']},
#  'BB-norm-F-20167385-011.a1': {'T4': ['001480', 'cheese', 'exact'],
#   'T5': ['001341', 'cheese surface', 'exact'],
#   'T8': ['001480', 'fontina cheese', 'headwordexact', 'cheese'],
#   'T11': ['003504', 'gorgonzola', 'exact'],
#   'T14': ['003525', 'taleggio', 'exact'],
#   'T19': ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese'],
#   'T20': ['001480', 'scimudin cheeses', 'headwordexact', 'cheese'],
#   'T21': ['001480', 'formaggio di fossa cheese', 'headwordexact', 'cheese'],
#   'T26': ['002793', 'fermented fish', 'headwordexact', 'fish'],
#   'T27': ['001480', 'greek cheese', 'headwordexact', 'cheese'],
#   'T30': ['003522', 'scimudin', 'exact'],
#   'T31': ['003504', 'gorgonzola', 'exact'],
#   'T33': ['003472', 'fontina', 'exact'],
#   'T36': ['003504', 'gorgonzola', 'exact']},
#  'BB-norm-F-20167385-012.a1': {},
#  'BB-norm-F-20167385-013.a1': {'T5': ['001341', 'cheese surface', 'exact'],
#   'T6': ['001480', 'cheese', 'exact']},
#  'BB-norm-F-20167385-014.a1': {'T3': ['001480',
#    'formaggio di  fossa cheese',
#    'headwordexact',
#    'cheese']},
#  'BB-norm-F-20167385-015.a1': {'T3': ['001480', 'cheese', 'exact']},
#  'BB-norm-F-25036636-000.a1': {'T1': ['002697', 'community', 'exact'],
#   'T2': ['001480', 'cheese', 'exact'],
#   'T5': ['000008', 'food', 'exact'],
#   'T11': ['000338', 'marine environment', 'exact'],
#   'T12': ['001480', 'cheese', 'exact'],
#   'T13': ['000113', 'cheese community', 'exact']},
#  'BB-norm-F-25036636-001.a1': {},
#  'BB-norm-F-25036636-002.a1': {'T1': ['000338', 'marine', 'exact'],
#   'T3': ['001480', 'cheese', 'exact']},
#  'BB-norm-F-25036636-003.a1': {'T1': ['001480', 'cheese', 'exact'],
#   'T4': ['001480', 'cheese', 'exact'],
#   'T6': ['001480', 'cheese', 'exact'],
#   'T11': ['003105', 'polar seawater', 'headwordexact', 'seawater']},
#  'BB-norm-F-25036636-004.a1': {'T2': ['001480', 'cheese', 'exact'],
#   'T4': ['001480', 'cheese', 'exact'],
#   'T5': ['001481', 'cheese rind', 'exact']},
#  'BB-norm-F-25036636-005.a1': {'T1': ['001480', 'cheese', 'exact'],
#   'T2': ['002697', 'community', 'exact'],
#   'T6': ['001276', 'raw milk', 'exact'],
#   'T8': ['002697', 'community', 'exact'],
#   'T16': ['002697', 'community', 'exact'],
#   'T17': ['001480', 'mature cheeses', 'headwordexact', 'cheese']}}

# %%
def test_habitats(a1, a2, processor):
    
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    match_list = {}
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]:
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = named_entity.lower()
                    named_entity = processor(named_entity)
                match_list[t] = [oid, named_entity]
    return match_list

# %%
dev_a2 = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    a2 = open(dev_path + BB_dev_a2[i],encoding="utf8").read()
    dev_a2[BB_dev_a1[i]] = test_habitats(a1,a2, phrase_reducer)

# %%
true_pred_count = 0
false_pred_count = 0
total_count = 0
for key in dev_a2:
    """print()
    print(key)
    print(dev_a2[key])
    print("**************")"""
    total_count += len(dev_a2[key])
    if key in annotations_test:
        for pred in annotations_test[key]:            
            if annotations_test[key][pred][0] == dev_a2[key][pred][0]:
                true_pred_count += 1
            else:
                print(key)
                print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred])
                print("Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]])
                false_pred_count += 1
# Out:
# BB-norm-10496597.a1
# Prediction: ['000196', 'gastric mucosal-associated lymphoid tissue', 'headwordexact', 'tissue']  Real: ['000334', 'gastric mucosal-associated lymphoid tissue']
# Prediction: animal tissue  Real: lymphatic system part
# BB-norm-10496597.a1
# Prediction: ['000061', 'monoclonal b cells', 'headwordexact', 'cell']  Real: ['001623', 'monoclonal b cell']
# Prediction: cell  Real: lymphocyte
# BB-norm-10496597.a1
# Prediction: ['003215', 'gastric malt', 'headwordexact', 'malt']  Real: ['000334', 'gastric malt']
# Prediction: malt  Real: lymphatic system part
# BB-norm-10496597.a1
# Prediction: ['003220', 'patients with helicobacter pylori-chronic active gastritis', 'headwordexact', 'patient']  Real: ['003269', 'patient with helicobacter pylori-chronic active gastritis']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-10496597.a1
# Prediction: ['000061', 'cd20-positive cells', 'headwordexact', 'cell']  Real: ['001623', 'cd20-positive cell']
# Prediction: cell  Real: lymphocyte
# BB-norm-10496597.a1
# Prediction: ['000061', 'monoclonal b cells', 'headwordexact', 'cell']  Real: ['001623', 'monoclonal b cell']
# Prediction: cell  Real: lymphocyte
# BB-norm-10496597.a1
# Prediction: ['003215', 'gastric malt', 'headwordexact', 'malt']  Real: ['000334', 'gastric malt']
# Prediction: malt  Real: lymphatic system part
# BB-norm-11989773.a1
# Prediction: ['000393', 'chicken nugget processing plant', 'headwordexact', 'plant']  Real: ['002129', 'chicken nugget processing plant']
# Prediction: plant  Real: meat industry
# BB-norm-11989773.a1
# Prediction: ['003314', 'chicken', 'exact']  Real: ['002394', 'chicken']
# Prediction: chicken  Real: chicken meat
# BB-norm-11989773.a1
# Prediction: ['000008', 'food', 'exact']  Real: ['000094', 'food']
# Prediction: food  Real: food for human
# BB-norm-11989773.a1
# Prediction: ['003314', 'chicken', 'exact']  Real: ['002394', 'chicken']
# Prediction: chicken  Real: chicken meat
# BB-norm-11989773.a1
# Prediction: ['000393', 'chicken nugget processing plant', 'headwordexact', 'plant']  Real: ['002129', 'chicken nugget processing plant']
# Prediction: plant  Real: meat industry
# BB-norm-11989773.a1
# Prediction: ['000008', 'food', 'exact']  Real: ['000094', 'food']
# Prediction: food  Real: food for human
# BB-norm-11989773.a1
# Prediction: ['000008', 'food', 'exact']  Real: ['000094', 'food']
# Prediction: food  Real: food for human
# BB-norm-12109661.a1
# Prediction: ['002488', 'h. pylori-positive subjects', 'headwordexact', 'subject']  Real: ['003269', 'h. pylori-positive subject']
# Prediction: human  Real: patient with infectious disease
# BB-norm-12109661.a1
# Prediction: ['002488', 'h. pylori-negative subjects', 'headwordexact', 'subject']  Real: ['002712', 'h. pylori-negative subject']
# Prediction: human  Real: healthy person
# BB-norm-12109661.a1
# Prediction: ['003107', 'h. pylori-infected monkeys', 'headwordexact', 'monkey']  Real: ['000700', 'h. pylori-infected monkey']
# Prediction: monkey  Real: laboratory animal
# BB-norm-12109661.a1
# Prediction: ['003107', 'control monkeys', 'headwordexact', 'monkey']  Real: ['000700', 'control monkey']
# Prediction: monkey  Real: laboratory animal
# BB-norm-12109661.a1
# Prediction: ['003269', 'young japanese people', 'headwordexact', 'people']  Real: ['003188', 'young japanese people']
# Prediction: patient with infectious disease  Real: child
# BB-norm-1214327.a1
# Prediction: ['003220', 'gastroenteritis patients', 'headwordexact', 'patient']  Real: ['003269', 'gastroenteritis patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-1214327.a1
# Prediction: ['000542', 'healthy carriers', 'headwordexact', 'carrier']  Real: ['002712', 'healthy carrier']
# Prediction: carrier  Real: healthy person
# BB-norm-1356998.a1
# Prediction: ['002488', 'human', 'exact']  Real: ['003269', 'human']
# Prediction: human  Real: patient with infectious disease
# BB-norm-1356998.a1
# Prediction: ['003220', 'patients suffering from rickettsial disease of different degrees of severity', 'headwordexact', 'patient']  Real: ['003269', 'patient suffering from rickettsial disease of different degree of severity']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-1356998.a1
# Prediction: ['002488', 'human', 'exact']  Real: ['003269', 'human']
# Prediction: human  Real: patient with infectious disease
# BB-norm-15618837.a1
# Prediction: ['003220', 'patients with h. pylori infection', 'headwordexact', 'patient']  Real: ['003269', 'patient with h. pylorus infection']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-16273411.a1
# Prediction: ['002488', 'human', 'exact']  Real: ['003493', 'human']
# Prediction: human  Real: pregnant woman
# BB-norm-16273411.a1
# Prediction: ['000193', 'animal', 'exact']  Real: ['001103', 'animal']
# Prediction: animal  Real: female animal
# BB-norm-16458564.a1
# Prediction: ['003188', 'children with diarrhea', 'headwordexact', 'child']  Real: ['003156', 'child with diarrhea']
# Prediction: child  Real: ill person
# BB-norm-16458564.a1
# Prediction: ['003188', 'children with diarrhea', 'headwordexact', 'child']  Real: ['003156', 'child with diarrhea']
# Prediction: child  Real: ill person
# BB-norm-16458564.a1
# Prediction: ['003188', 'children less than two years of age', 'headwordexact', 'child']  Real: ['003184', 'child le than two year of age']
# Prediction: child  Real: baby
# BB-norm-16458564.a1
# Prediction: ['003188', 'child', 'exact']  Real: ['003269', 'child']
# Prediction: child  Real: patient with infectious disease
# BB-norm-16458564.a1
# Prediction: ['003188', 'child', 'exact']  Real: ['003269', 'child']
# Prediction: child  Real: patient with infectious disease
# BB-norm-16458564.a1
# Prediction: ['003188', 'child', 'exact']  Real: ['003269', 'child']
# Prediction: child  Real: patient with infectious disease
# BB-norm-18094887.a1
# Prediction: ['001863', 'animal blood', 'exact']  Real: ['000521', 'animal blood']
# Prediction: animal blood  Real: blood
# BB-norm-18094887.a1
# Prediction: ['000524', 'human sera', 'headwordexact', 'serum']  Real: ['000007', 'human serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'opossum sera', 'headwordexact', 'serum']  Real: ['000007', 'opossum serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'dog sera', 'headwordexact', 'serum']  Real: ['000007', 'dog serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'horse sera', 'headwordexact', 'serum']  Real: ['000007', 'horse serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'serum', 'exact']  Real: ['000007', 'serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'opossum sera', 'headwordexact', 'serum']  Real: ['000007', 'opossum serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18094887.a1
# Prediction: ['000524', 'horse sera', 'headwordexact', 'serum']  Real: ['000007', 'horse serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-18789156.a1
# Prediction: ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['003001', 'monocyte-like thp-1 cell']
# Prediction: cell  Real: monocyte
# BB-norm-18789156.a1
# Prediction: ['000061', 'human monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['003001', 'human monocyte-like thp-1 cell']
# Prediction: cell  Real: monocyte
# BB-norm-18789156.a1
# Prediction: ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['000062', 'monocyte-like thp-1 cell']
# Prediction: cell  Real: cell culture
# BB-norm-18789156.a1
# Prediction: ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['003001', 'monocyte-like thp-1 cell']
# Prediction: cell  Real: monocyte
# BB-norm-18789156.a1
# Prediction: ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['000062', 'monocyte-like thp-1 cell']
# Prediction: cell  Real: cell culture
# BB-norm-18789156.a1
# Prediction: ['000061', 'monocyte-like thp-1 cells', 'headwordexact', 'cell']  Real: ['000062', 'monocyte-like thp-1 cell']
# Prediction: cell  Real: cell culture
# BB-norm-19552770.a1
# Prediction: ['001446', 'male birds', 'headwordexact', 'bird']  Real: ['002726', 'male bird']
# Prediction: bird  Real: livestock
# BB-norm-19552770.a1
# Prediction: ['001446', 'female birds', 'headwordexact', 'bird']  Real: ['003066', 'female bird']
# Prediction: bird  Real: partridge
# BB-norm-19552770.a1
# Prediction: ['000091', 'game bird farm', 'headwordexact', 'farm']  Real: ['000194', 'game bird farm']
# Prediction: farm  Real: animal farm
# BB-norm-19552770.a1
# Prediction: ['003066', 'commercially reared partridges', 'headwordexact', 'partridge']  Real: ['002726', 'commercially reared partridge']
# Prediction: partridge  Real: livestock
# BB-norm-20174624.a1
# Prediction: ['000706', 'polymorphonuclear leukocytes', 'headwordexact', 'leukocyte']  Real: ['001134', 'polymorphonuclear leukocyte']
# Prediction: leukocyte  Real: granulocyte
# BB-norm-20174624.a1
# Prediction: ['000061', 'murine dendritic cells', 'headwordexact', 'cell']  Real: ['002785', 'murine dendritic cell']
# Prediction: cell  Real: dendritic cell
# BB-norm-20174624.a1
# Prediction: ['000061', 'cell', 'exact']  Real: ['000706', 'cell']
# Prediction: cell  Real: leukocyte
# BB-norm-20174624.a1
# Prediction: ['000061', 'pmn cell', 'headwordexact', 'cell']  Real: ['001134', 'pmn cell']
# Prediction: cell  Real: granulocyte
# BB-norm-20174624.a1
# Prediction: ['000061', 'pmn cell', 'headwordexact', 'cell']  Real: ['001134', 'pmn cell']
# Prediction: cell  Real: granulocyte
# BB-norm-20580604.a1
# Prediction: ['001078', 'probiotic fermented milk beverage', 'headwordexact', 'beverage']  Real: ['003343', 'probiotic fermented milk beverage']
# Prediction: drink  Real: fermented beverage
# BB-norm-20580604.a1
# Prediction: ['001078', 'fermented milk beverage', 'headwordexact', 'beverage']  Real: ['003343', 'fermented milk beverage']
# Prediction: drink  Real: fermented beverage
# BB-norm-20580604.a1
# Prediction: ['001456', 'bottle', 'exact']  Real: ['003146', 'bottle']
# Prediction: bottle  Real: fermented milk
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['001456', 'bottle', 'exact']  Real: ['001269', 'bottle']
# Prediction: bottle  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['000827', 'probiotic', 'exact']  Real: ['001269', 'probiotic']
# Prediction: probiotic  Real: probiotic food
# BB-norm-20580604.a1
# Prediction: ['001078', 'probiotic fermented milk beverage', 'headwordexact', 'beverage']  Real: ['003343', 'probiotic fermented milk beverage']
# Prediction: drink  Real: fermented beverage
# BB-norm-21270066.a1
# Prediction: ['003220', 'patient', 'exact']  Real: ['003269', 'patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-21270066.a1
# Prediction: ['003220', 'hiv-infected patients presenting with isolated perianal ulcer disease', 'headwordexact', 'patient']  Real: ['003269', 'hiv-infected patient presenting with isolated perianal ulcer disease']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-21695078.a1
# Prediction: ['002727', 'mouse', 'exact']  Real: ['001103', 'mouse']
# Prediction: mouse  Real: female animal
# BB-norm-21695078.a1
# Prediction: ['002727', 'mouse', 'exact']  Real: ['003211', 'mouse']
# Prediction: mouse  Real: laboratory mouse
# BB-norm-21695078.a1
# Prediction: ['002727', 'tlr2-deficient mice', 'headwordexact', 'mouse']  Real: ['001103', 'tlr2-deficient mouse']
# Prediction: mouse  Real: female animal
# BB-norm-23902156.a1
# Prediction: ['000524', 'penicillium-sensitive atopic sera', 'headwordexact', 'serum']  Real: ['000007', 'penicillium-sensitive atopic serum']
# Prediction: blood serum  Real: experimental medium
# BB-norm-25114119.a1
# Prediction: ['002727', 'mouse', 'exact']  Real: ['003211', 'mouse']
# Prediction: mouse  Real: laboratory mouse
# BB-norm-25114119.a1
# Prediction: ['002727', 'scid mice', 'headwordexact', 'mouse']  Real: ['003211', 'scid mouse']
# Prediction: mouse  Real: laboratory mouse
# BB-norm-25114119.a1
# Prediction: ['002727', 'mouse', 'exact']  Real: ['003211', 'mouse']
# Prediction: mouse  Real: laboratory mouse
# BB-norm-3544198.a1
# Prediction: ['003220', 'leprosy patients', 'headwordexact', 'patient']  Real: ['003269', 'leprosy patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-3544198.a1
# Prediction: ['003220', 'leprosy patients', 'headwordexact', 'patient']  Real: ['003269', 'leprosy patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-3544198.a1
# Prediction: ['003220', 'll patients', 'headwordexact', 'patient']  Real: ['003269', 'll patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-3544198.a1
# Prediction: ['000792', 'nitrocellulose paper', 'headwordexact', 'paper']  Real: ['000007', 'nitrocellulose paper']
# Prediction: paper  Real: experimental medium
# BB-norm-3544198.a1
# Prediction: ['003220', 'll patients', 'headwordexact', 'patient']  Real: ['003269', 'll patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-460951.a1
# Prediction: ['003188', 'child', 'exact']  Real: ['003269', 'child']
# Prediction: child  Real: patient with infectious disease
# BB-norm-9521147.a1
# Prediction: ['003220', 'patients with different clinical spectra and with other infections', 'headwordexact', 'patient']  Real: ['003269', 'patient with different clinical spectrum and with other infection']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9521147.a1
# Prediction: ['003220', 'patients with melioidosis', 'headwordexact', 'patient']  Real: ['003269', 'patient with melioidosis']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9521147.a1
# Prediction: ['002727', 'hyperimmune mouse', 'headwordexact', 'mouse']  Real: ['003211', 'hyperimmune mouse']
# Prediction: mouse  Real: laboratory mouse
# BB-norm-9553794.a1
# Prediction: ['003021', 'modified-atmosphere-packed cold-smoked salmon stored at 5 degrees c', 'headwordexact', 'salmon']  Real: ['001774', 'modified-atmosphere-packed cold-smoked salmon stored at 5 degree c']
# Prediction: salmon  Real: smoked food
# BB-norm-9553794.a1
# Prediction: ['003021', 'vacuum-packed cold-smoked salmon', 'headwordexact', 'salmon']  Real: ['001774', 'vacuum-packed cold-smoked salmon']
# Prediction: salmon  Real: smoked food
# BB-norm-9553794.a1
# Prediction: ['003021', 'vacuum-packed salmon', 'headwordexact', 'salmon']  Real: ['001774', 'vacuum-packed salmon']
# Prediction: salmon  Real: smoked food
# BB-norm-9553794.a1
# Prediction: ['003021', 'cold-smoked salmon stored at 5 degrees c', 'headwordexact', 'salmon']  Real: ['002593', 'cold-smoked salmon stored at 5 degree c']
# Prediction: salmon  Real: salmon meat
# BB-norm-9553794.a1
# Prediction: ['003021', 'salmon', 'exact']  Real: ['001774', 'salmon']
# Prediction: salmon  Real: smoked food
# BB-norm-9745160.a1
# Prediction: ['003220', 'patients with active duodenal ulcer disease and h pylori infection', 'headwordexact', 'patient']  Real: ['003269', 'patient with active duodenal ulcer disease and h pylorus infection']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['000933', 'ulcer', 'exact']  Real: ['001533', 'ulcer']
# Prediction: ulcer  Real: duodenal ulcer
# BB-norm-9745160.a1
# Prediction: ['003220', 'patient', 'exact']  Real: ['003269', 'patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['003220', 'patient', 'exact']  Real: ['003269', 'patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['003220', 'patient', 'exact']  Real: ['003269', 'patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['003220', 'patients with ppi-based triple therapy', 'headwordexact', 'patient']  Real: ['003269', 'patient with ppi-based triple therapy']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['003220', 'patients with bismuth-based triple therapy', 'headwordexact', 'patient']  Real: ['003269', 'patient with bismuth-based triple therapy']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-9745160.a1
# Prediction: ['003220', 'patient', 'exact']  Real: ['003269', 'patient']
# Prediction: patient  Real: patient with infectious disease
# BB-norm-F-14624315-000.a1
# Prediction: ['001480', 'semi-hard cheeses', 'headwordexact', 'cheese']  Real: ['003458', 'semi-hard cheese']
# Prediction: cheese  Real: semi soft cheese
# BB-norm-F-14624315-000.a1
# Prediction: ['001480', 'swiss-type cheeses', 'headwordexact', 'cheese']  Real: ['003428', 'swiss-type cheese']
# Prediction: cheese  Real: ripened cheese
# BB-norm-F-20167385-000.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-000.a1
# Prediction: ['001480', 'taleggio cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-000.a1
# Prediction: ['001480', 'formaggio di fossa cheeses', 'headwordexact', 'cheese']  Real: ['003473', 'formaggio di fossa cheese']
# Prediction: cheese  Real: formaggio di fossa
# BB-norm-F-20167385-002.a1
# Prediction: ['001480', 'soft smear cheeses', 'headwordexact', 'cheese']  Real: ['003494', 'soft smear cheese']
# Prediction: cheese  Real: smear ripened cheese
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'casera cheese', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'casera cheeses', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'casera cheese', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'formaggio di fossa cheeses', 'headwordexact', 'cheese']  Real: ['003473', 'formaggio di fossa cheese']
# Prediction: cheese  Real: formaggio di fossa
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-003.a1
# Prediction: ['001480', 'casera cheese', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-004.a1
# Prediction: ['002697', 'community of staphylococcus and micrococci-corynebacteria groups', 'headwordexact', 'community']  Real: ['000113', 'community of staphylococcus and micrococci-corynebacteria group']
# Prediction: community  Real: microflora
# BB-norm-F-20167385-004.a1
# Prediction: ['001480', 'casera cheeses', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-004.a1
# Prediction: ['001480', 'taleggio cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-004.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-004.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-005.a1
# Prediction: ['001480', 'scimudin cheese', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'taleggio cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'gorgonzola cheese', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'taleggio cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'casera cheeses', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'taleggio cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'casera cheeses', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-006.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-007.a1
# Prediction: ['001480', 'formaggio di fossa cheeses', 'headwordexact', 'cheese']  Real: ['003473', 'formaggio di fossa cheese']
# Prediction: cheese  Real: formaggio di fossa
# BB-norm-F-20167385-007.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-007.a1
# Prediction: ['001480', 'taleggio  cheeses', 'headwordexact', 'cheese']  Real: ['003525', 'taleggio  cheese']
# Prediction: cheese  Real: taleggio
# BB-norm-F-20167385-008.a1
# Prediction: ['001480', 'scimudin cheese', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-009.a1
# Prediction: ['001480', 'casera cheese', 'headwordexact', 'cheese']  Real: ['003483', 'casera cheese']
# Prediction: cheese  Real: valtellina casera
# BB-norm-F-20167385-009.a1
# Prediction: ['001480', 'gorgonzola cheese', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-009.a1
# Prediction: ['001480', 'scimudin cheese', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-010.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-010.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-010.a1
# Prediction: ['001480', 'gobbeen cheese', 'headwordexact', 'cheese']  Real: ['003505', 'gobbeen cheese']
# Prediction: cheese  Real: gubbeen
# BB-norm-F-20167385-011.a1
# Prediction: ['001480', 'fontina cheese', 'headwordexact', 'cheese']  Real: ['003472', 'fontina cheese']
# Prediction: cheese  Real: fontina
# BB-norm-F-20167385-011.a1
# Prediction: ['001480', 'gorgonzola cheeses', 'headwordexact', 'cheese']  Real: ['003504', 'gorgonzola cheese']
# Prediction: cheese  Real: gorgonzola
# BB-norm-F-20167385-011.a1
# Prediction: ['001480', 'scimudin cheeses', 'headwordexact', 'cheese']  Real: ['003522', 'scimudin cheese']
# Prediction: cheese  Real: scimudin
# BB-norm-F-20167385-011.a1
# Prediction: ['001480', 'formaggio di fossa cheese', 'headwordexact', 'cheese']  Real: ['003473', 'formaggio di fossa cheese']
# Prediction: cheese  Real: formaggio di fossa
# BB-norm-F-20167385-011.a1
# Prediction: ['002793', 'fermented fish', 'headwordexact', 'fish']  Real: ['003145', 'fermented fish']
# Prediction: fish  Real: fermented fish product
# BB-norm-F-20167385-014.a1
# Prediction: ['001480', 'formaggio di  fossa cheese', 'headwordexact', 'cheese']  Real: ['003473', 'formaggio di  fossa cheese']
# Prediction: cheese  Real: formaggio di fossa
# BB-norm-F-25036636-000.a1
# Prediction: ['002697', 'community', 'exact']  Real: ['000113', 'community']
# Prediction: community  Real: microflora
# BB-norm-F-25036636-000.a1
# Prediction: ['000008', 'food', 'exact']  Real: ['000094', 'food']
# Prediction: food  Real: food for human
# BB-norm-F-25036636-005.a1
# Prediction: ['002697', 'community', 'exact']  Real: ['000113', 'community']
# Prediction: community  Real: microflora
# BB-norm-F-25036636-005.a1
# Prediction: ['002697', 'community', 'exact']  Real: ['000113', 'community']
# Prediction: community  Real: microflora
# BB-norm-F-25036636-005.a1
# Prediction: ['002697', 'community', 'exact']  Real: ['000113', 'community']
# Prediction: community  Real: microflora

# %%
recall = true_pred_count/total_count
recall
# Out:
# 0.4967213114754098

# %%
precision = true_pred_count/(true_pred_count + false_pred_count)
precision
# Out:
# 0.6703539823008849

# %% [markdown]
# ## Denemeler

# %%
len(treebank.parsed_sents())
# Out:
# 3914

# %%
tb_prod = set([production for parsed_sent in treebank.parsed_sents() for production in parsed_sent.productions()])

# %%
tb_prod
# Out:
# {SBAR -> WHADVP-3 S,
#  NP-SBJ -> NNP NNP NNP NNP NNP NNP,
#  VBZ -> 'factors',
#  JJ -> 'sweeping',
#  NN -> 'lesson',
#  VP -> VBG PP-CLR , SBAR-PRP,
#  VP -> VBZ SBAR , S-ADV,
#  ADJP -> JJ RB,
#  NN -> 'information',
#  NN -> 'subsidiary',
#  NP-PRD -> NP CC NP,
#  CD -> '3.80',
#  NNS -> 'Bonds',
#  VP -> VB ADVP-MNR NP,
#  NP -> DT NNP CD NNP,
#  JJ -> 'Washington-based',
#  VB -> 'say',
#  VBZ -> 'reports',
#  NN -> 'month',
#  -NONE- -> '*-94',
#  NNP -> 'Roosevelt',
#  VBN -> 'rationed',
#  VBD -> 'hired',
#  S-1 -> NP-SBJ PRN VP . '',
#  NNP -> 'Hartford',
#  CD -> '170,000',
#  JJ -> 'larger-than-normal',
#  PP-DIR -> IN NP-TMP,
#  CD -> '1920s',
#  NN -> 'cardboard',
#  PP-CLR -> IN `` ADJP,
#  NNS -> 'clothes',
#  NP-SBJ-2 -> NP , VP ,,
#  NN -> 'commodity',
#  VB -> 'Put',
#  JJ -> 'secondary',
#  JJ -> 'enlarged',
#  VBN -> 'UPHELD',
#  -NONE- -> '*T*-13',
#  -NONE- -> '*-111',
#  CD -> '149',
#  -NONE- -> '*-130',
#  VP -> VBD PP-DIR PP,
#  JJ -> 'six-bottle',
#  VBD -> 'included',
#  NNP -> 'N.J.',
#  VP -> VBP NP-2 PP,
#  CD -> '77.70',
#  VB -> 'write',
#  VB -> 'touch',
#  QP -> JJR IN $ CD CD,
#  VP -> VBN PP-CLR PP,
#  VBG -> 'placing',
#  VP -> VB S SBAR-PRP,
#  VBP -> 'voice',
#  VBN -> 'shut',
#  NNP -> 'Tower',
#  NP-SBJ-1 -> NP CC NP,
#  VBP -> 'hang',
#  FRAG -> NP-SBJ-3 VP,
#  S -> SBAR-TMP , NP-SBJ-64 VP,
#  -NONE- -> '*T*-151',
#  VP -> VBD SBAR-PRD,
#  UH -> 'no',
#  VP -> VB NP PP-DTV , PP,
#  NN -> 'milestone',
#  WHNP-5 -> WP,
#  NP-SBJ-117 -> -NONE-,
#  VB -> 'agree',
#  VB -> 'attract',
#  VP -> VBZ NP-PRD ADVP-LOC,
#  S -> S : S . '',
#  JJ -> 'homosexual',
#  VBN -> 'designated',
#  ADVP-MNR -> RBR,
#  JJS -> 'least',
#  RB -> 'overseas',
#  VP -> VB NP PP-CLR SBAR-ADV,
#  NNP -> 'Kuhns',
#  NN -> 'leadership',
#  NN -> 'Volatility',
#  -NONE- -> '*-42',
#  JJ -> 'bell-ringing',
#  JJ -> 'unspecified',
#  NN -> 'economics',
#  VP -> VBN NP PP-DTV PP-CLR SBAR-TMP,
#  CD -> '18.3',
#  CD -> '109.73',
#  NNP -> 'Abbey',
#  NNS -> 'borrowings',
#  VBD -> 'knocked',
#  JJ -> 'unlabeled',
#  JJ -> 'junk-bond',
#  CD -> '7.15',
#  NP -> NP PP-LOC ADVP-TMP SBAR,
#  NNS -> 'Gilts',
#  NP -> DT NN NNS,
#  VBD -> 'resigned',
#  NNPS -> 'Soviets',
#  NP-TMP -> IN NN,
#  NNP -> 'ChemPlus',
#  NNP -> 'E.W.',
#  NP-SBJ-3 -> EX,
#  NNS -> 'referrals',
#  NN -> 'discussion',
#  NNP -> 'Hara',
#  JJ -> '45-a-share',
#  -NONE- -> '*-93',
#  S -> SBAR-ADV PRN , NP-SBJ VP .,
#  NNS -> 'observers',
#  S -> NP-SBJ-128 VP,
#  JJ -> 'golden',
#  JJ -> 'tricky',
#  VBD -> 'admitted',
#  JJ -> 'unfunded',
#  VBN -> 'priced',
#  VP -> VB ADJP-PRD SBAR-PRP,
#  NNP -> 'W.R.',
#  VBN -> 'guaranteed',
#  VBZ -> 'promises',
#  JJ -> 'preclinical',
#  NP -> NP : S .,
#  VP -> VB NP PP-BNF,
#  JJ -> 'phony',
#  -NONE- -> '*T*-220',
#  JJ -> 'American-made',
#  NNP -> 'Northy',
#  VBN -> 'proven',
#  NNP -> 'Home',
#  VBP -> "'m",
#  VP -> VBD PP-MNR S-ADV,
#  NP -> DT ADJP QP -NONE-,
#  VB -> 'expect',
#  NP-SBJ -> JJ NNS NNS,
#  VBD -> 'cited',
#  NN -> 'implementation',
#  NNP -> 'Business',
#  INTJ -> RB JJ,
#  S -> S , IN S .,
#  NNP -> 'Garry',
#  NN -> 'checkbook',
#  VB -> 'boost',
#  PP -> RB RB IN NP,
#  NNP -> 'C.J.B.',
#  VP -> VBP ADVP,
#  VBG -> 'researching',
#  NNP -> 'Mona',
#  JJ -> 'food-shop',
#  NNPS -> 'Yorkers',
#  NNP -> 'Purina',
#  NN -> 'coffee',
#  VP -> VBZ NP : `` SBARQ-NOM '',
#  VBD -> 'filed',
#  NP-SBJ -> PRP$ NNP NNP NN,
#  S-TPC-1 -> S-NOM-SBJ VP,
#  NNS -> 'reds',
#  SBAR -> WHNP-171 S,
#  VBZ -> 'doubts',
#  VBN -> 'retained',
#  VP -> VB ADVP-MNR SBAR,
#  S -> NP-SBJ-2 VP . '',
#  NNP -> 'Florida',
#  NN -> 'jury',
#  NNP -> 'Natural',
#  CD -> '195',
#  VP -> VB,
#  NNP -> 'Three',
#  NNS -> 'tickets',
#  -NONE- -> '*-2',
#  VBD -> 'reported',
#  NN -> 'examination',
#  VBP -> 'let',
#  NNP -> 'Gates-Warren',
#  NN -> 'mortgage',
#  VP -> VB NP PP-TMP : PP-1,
#  RB -> 'apart',
#  FRAG -> ADJP-PRD,
#  NP -> DT JJ NN NNS,
#  RB -> 'modestly',
#  NP -> DT VBN QP -NONE-,
#  NN -> 'pretext',
#  ADJP -> NNS CC NNS,
#  NNS -> 'Champagnes',
#  NNS -> 'amps',
#  VB -> 'enter',
#  NN -> 'junk-bond',
#  VBD -> 'ran',
#  NNP -> 'Griffin',
#  PP-LOC-1 -> PP , CC ADVP PP,
#  NP-SBJ -> NP NN JJ NN,
#  NNP -> 'California',
#  VBG -> 'appealing',
#  PP -> IN NP-TTL,
#  NN -> 'backing',
#  NP-SBJ -> NP PP PP PP,
#  VP -> VB ADVP-PRP,
#  VP -> VBZ NP ADVP-TMP PP-CLR PP-2,
#  VP -> ADVP VBD S,
#  UH -> 'Oh',
#  NP-SBJ -> DT JJS NNS,
#  S-TPC-1 -> S CC S,
#  VP -> IN S,
#  VBD -> 'contained',
#  NN -> 'panel',
#  NNP -> 'Coleco',
#  JJ -> 'supercilious',
#  NN -> 'payoff',
#  NNP -> 'MONEY',
#  S -> NP-SBJ-52 VP,
#  NP -> PRP$ RB VBN VBG NN,
#  VP -> VBD NP PP S-CLR ADVP-LOC,
#  NN -> 'investment',
#  NP -> NP : CC NP :,
#  NN -> 'System',
#  VBZ -> 'Fails',
#  VBN -> 'held',
#  VBN -> 'obsessed',
#  NN -> 'facade',
#  S -> NP-TMP NP-SBJ ADVP VP,
#  NNP -> 'IBM',
#  NN -> 'friend',
#  VB -> 'launch',
#  VBG -> 'lessening',
#  NNS -> 'worms',
#  S-2 -> CC NP-SBJ-1 VP . '',
#  NP-SBJ -> DT ADJP NN NN,
#  VBP -> 'face',
#  NP-SBJ-1 -> JJ JJ NNS,
#  VP -> VBN NP PP-PRP,
#  SBAR -> WHNP-129 S,
#  VBD -> 'blamed',
#  VB -> 'matter',
#  NNP -> 'Morrison',
#  VB -> 'reach',
#  S-2 -> ADVP-TMP PRN NP-SBJ VP .,
#  CD -> '275',
#  NAC-LOC -> NNP , NNP,
#  WHNP-54 -> WP$ JJ NNS,
#  VB -> 'oppose',
#  NN -> 'appetite',
#  NN -> 'appointment',
#  NP-SBJ-107 -> -NONE-,
#  NN -> 'crookery',
#  VP -> VB ADVP-DIR PP-DIR,
#  VBN -> 'permitted',
#  DT -> 'The',
#  NP-SBJ -> JJ JJ JJ NNS,
#  VBG -> 'sticking',
#  RB -> 'earlier',
#  RB -> 'properly',
#  NNP -> 'Richard',
#  VBG -> 'doing',
#  NN -> 'trader',
#  S -> S-ADV , NP-SBJ-1 VP .,
#  VB -> 'attack',
#  NNP -> 'Sandifer',
#  VB -> 'break',
#  NNS -> 'articles',
#  NP -> NP NNP NNPS NNP,
#  VP -> VBG SBAR-ADV,
#  VBN -> 'scrambled',
#  NNP -> 'Fulbright',
#  NP -> DT NNP NNP NNP NNP NNP NNP,
#  VP -> VBG NP PP-MNR PP-DIR,
#  SBAR-TMP -> RB WHADVP-1 S,
#  S -> `` S-TPC-3 , '' NP-SBJ VP .,
#  NNP -> 'Wohlstetter',
#  VBG -> 'improving',
#  VBD -> 'deemed',
#  VB -> 'remove',
#  NP -> PRP$ CD NN,
#  VBD -> 'pledged',
#  NNP -> 'Theodore',
#  VBD -> 'wanted',
#  NP -> NNP `` NN '',
#  NP-LGS -> NP PRN,
#  NP-LGS -> NP , NP ,,
#  VP -> VBD PP-LOC , SBAR-ADV,
#  NN -> 'export',
#  VP -> VBD : `` S,
#  VP -> VBP PP-PRD,
#  NNP -> 'FT',
#  NNP -> 'Xerox',
#  NP -> NP-TMP : NP,
#  WHNP-193 -> WDT,
#  NNP -> 'Laser',
#  S-1 -> NP-SBJ , PRN , VP,
#  NN -> 'domination',
#  NNP -> 'Warsaw',
#  CD -> '730',
#  NNP -> 'Baltimore',
#  JJ -> 'outright',
#  VP -> ADVP-MNR VB PP ADVP-TMP,
#  ADJP-PRD -> JJ SBAR,
#  PRP -> 'himself',
#  RB -> 'regardless',
#  CD -> '341.20',
#  NNP -> 'WPP',
#  VB -> 'disclose',
#  NNS -> 'heebie-jeebies',
#  VBG -> 'leaving',
#  VP -> VBP NP-CLR PP-CLR,
#  VBN -> 'welcomed',
#  ADVP -> JJR,
#  NN -> 'perspective',
#  JJ -> 'sprawling',
#  NNS -> 'centers',
#  JJ -> 'peaked',
#  NN -> 'content',
#  NNP -> 'Earle',
#  WHNP-219 -> WDT,
#  S -> NP-SBJ , '' ADVP VP,
#  CD -> '107.9',
#  RB -> 'Only',
#  NNP -> 'Hazell',
#  JJ -> 'unanticipated',
#  S -> NP-SBJ `` VP .,
#  S -> `` RB NP-SBJ VP . '',
#  VBG -> 'surrounding',
#  NP -> PDT DT NN,
#  NP-SBJ-1 -> JJ NNP NNP,
#  NN -> 'name',
#  NP-SBJ-2 -> NP , CC NP ,,
#  SBAR -> WHNP-208 S,
#  NN -> 'assembly-line',
#  VP -> VBZ RB ADJP-PRD SBAR-2,
#  PP-MNR-CLR -> IN NP,
#  NNS -> 'nominees',
#  NNP -> 'Norman',
#  NN -> 'Insurance',
#  CD -> '38',
#  RB -> 'smartly',
#  NP -> NP PP : NP,
#  VBG -> 'struggling',
#  VBD -> 'trailed',
#  VP -> VBN PRT,
#  NN -> 'forecast',
#  ADVP-TMP -> ADVP SBAR,
#  NNS -> 'opinions',
#  NNP -> 'Bar',
#  SBAR -> WHNP-175 S,
#  NP-SBJ -> NP PP-LOC , VP ,,
#  JJ -> 'favorite',
#  S-ADV -> ADVP NP-SBJ VP,
#  NN -> 'technology',
#  NNP -> 'Drobnick',
#  RB -> 'Just',
#  VB -> 'increase',
#  JJ -> 'low-cost',
#  NNS -> 'anti-programmers',
#  ADJP-PRD -> NP-ADV JJ,
#  VBN -> 'milked',
#  VP -> VBD NP PP-CLR , S-ADV,
#  NN -> 'disadvantage',
#  CD -> '116.9',
#  NN -> 'unpopularity',
#  VBG -> 'walking',
#  NP -> DT JJ JJ NNS CC NNS,
#  NNS -> 'highs',
#  VBG -> 'accounting',
#  NNP -> 'Calif',
#  JJ -> 'ancient',
#  NP-SBJ-41 -> DT NN,
#  NNS -> 'ways',
#  NP-PRD -> DT CD NNS,
#  VP -> VBN NP PP-LOC PP-TMP,
#  CD -> '273.5',
#  NP-SBJ-37 -> NN NNS,
#  NNS -> 'planes',
#  NP-PRD -> DT,
#  CD -> '45.2',
#  NNP -> 'Nobel',
#  -NONE- -> '*T*-132',
#  VB -> 'believe',
#  VP -> VBN NP-4 SBAR-CLR,
#  VP -> VBZ PP-MNR-CLR SBAR-PRP,
#  CD -> '350',
#  NP -> NNP VBG NNS,
#  NNP -> 'Photograph',
#  VBZ -> 'cites',
#  NP -> DT NNP NN NN NN,
#  JJ -> 'immediate',
#  CD -> '13,056',
#  VBD -> 'traveled',
#  NP -> NNP NNP NNP NNP NNP .,
#  VB -> 'please',
#  NN -> 'deterioration',
#  NN -> 'downside',
#  PRN -> , PP-MNR ,,
#  VBD -> 'collapsed',
#  RB -> 'Much',
#  NNS -> 'cars',
#  -NONE- -> '*T*-93',
#  WHNP-22 -> WDT,
#  S -> NP-SBJ-1 PRN VP,
#  PP-PRD -> RB IN NP,
#  JJ -> 'four-foot-high',
#  S -> -LRB- PP-TMP , NP-SBJ VP . -RRB-,
#  VP -> ADVP-MNR VBG PP-CLR,
#  NNP -> 'Nissho-Iwai',
#  NNP -> 'Savings',
#  VP -> VBN ADVP S,
#  JJ -> '51-year-old',
#  VBG -> 'aiming',
#  RB -> 'free',
#  VB -> 'allow',
#  PP-PRD-LOC -> IN NP,
#  VBN -> 'planned',
#  NNP -> 'Braidwood',
#  VBN -> 'incurred',
#  NP-SBJ-3 -> PRP,
#  NP-SBJ-1 -> NNP NNP NNP NNP,
#  NNS -> 'parallels',
#  VP -> VB SBAR PP-LOC,
#  NN -> 'can',
#  NN -> 'start',
#  RB -> 'originally',
#  SBAR-PRP -> WHADVP-1 S,
#  WHNP -> WP$ NNS,
#  NN -> 'temperature',
#  NN -> 'anyone',
#  VBZ -> 'perceives',
#  NNS -> 'solutions',
#  NN -> 'achievement-test',
#  NNS -> 'payments',
#  NNP -> 'Commonwealth',
#  QP -> JJR IN DT,
#  NN -> 'raising',
#  JJ -> '29year',
#  VBN -> 'charged',
#  NN -> 'taxpayer',
#  NP-SBJ-1 -> JJR JJ NN NNS,
#  UCP-PRD -> PP , CC RB ADJP,
#  VBN -> 'compiled',
#  VB -> 'waive',
#  VP -> ADVP VBP NP,
#  VP -> VBP NP-PRD , PP,
#  VBG -> 'reflecting',
#  NN -> 'winter',
#  VP -> VBP PRT NP,
#  S -> PP , NP-SBJ-2 VP .,
#  S -> CC PP , NP-SBJ ADVP-TMP VP .,
#  NN -> 'interference',
#  VBG -> 'lagging',
#  VBN -> 'pushed',
#  VB -> 'administer',
#  NP -> DT JJ JJ NNP NN,
#  JJ -> 'COMMERCIAL',
#  NN -> 'lens',
#  NNP -> 'Boone',
#  NN -> 'plunge',
#  VP -> VBG PP-CLR ADVP-PRP,
#  NNP -> 'Dunkin',
#  NN -> 'cease-fire',
#  SBAR-TMP -> WHADVP-4 S,
#  NNS -> 'bullets',
#  NNP -> 'Class',
#  NNP -> 'Carolina',
#  JJ -> 'implicit',
#  CD -> '93.9',
#  VBG -> 'noticing',
#  JJ -> 'several-year',
#  S -> PP-LOC PP-LOC , NP-SBJ VP .,
#  NP-SBJ -> JJ NNP NNP NNP NNP,
#  JJ -> 'fundamentalist',
#  NNS -> 'studies',
#  NNP -> 'Elisabeth',
#  NNS -> 'markdowns',
#  VBG -> 'increasing',
#  VBN -> 'crossed',
#  S-TPC-4 -> S , CC S,
#  JJ -> 'progressive',
#  NN -> 'ovation',
#  CD -> '75-year-old',
#  VBZ -> 'threatens',
#  JJ -> 'entertaining',
#  VP -> MD VP,
#  VP -> VBN NP PP-DTV PP-CLR,
#  S -> NP-SBJ-59 VP,
#  NP -> DT NNP POS,
#  VBD -> 'obligated',
#  FRAG -> NP : S,
#  JJ -> 'hard-charging',
#  NP-SBJ-2 -> DT JJ NN,
#  VP -> VBD PP-PRD PP-LOC,
#  FRAG -> NP-SBJ-1 VP,
#  NNP -> 'PRODUCTS',
#  VBZ -> 'manages',
#  VP -> VBN NP PP-TMP PP-CLR,
#  NNP -> 'Jihad',
#  NNP -> 'Pasadena',
#  NN -> 'merchant',
#  JJ -> 'touchy',
#  VBG -> 'following',
#  NNP -> 'Team',
#  VP -> VB NP-2 S,
#  NP -> RB DT NN NN,
#  JJ -> 'intelligent',
#  NP -> VBN NNS NNS,
#  NP -> PRP$ NNP CD NN NN,
#  NN -> 'dominance',
#  NN -> 'projector',
#  VBD -> 'registered',
#  -NONE- -> '*PPA*-2',
#  NNP -> 'Act',
#  NP-SBJ -> NNP NN NNS,
#  NNS -> 'posters',
#  WHNP-25 -> WDT,
#  NP-SBJ-50 -> NP PP,
#  CD -> '15,000',
#  NNP -> 'Genetics',
#  VP -> VBP PP-MNR,
#  NNP -> 'Community',
#  NP-SBJ -> NP PP '' VP,
#  NN -> 'network',
#  S-TPC-4 -> SBAR-TMP , NP-SBJ VP,
#  NNP -> 'America',
#  NNP -> 'Glenn',
#  VBG -> 'According',
#  NNS -> 'bundles',
#  NNP -> 'Genel',
#  NNS -> 'accomplishments',
#  VP -> VBZ RB ADVP ADJP-PRD ADVP,
#  RB -> 'actively',
#  VBZ -> 'lapses',
#  VBD -> 'replaced',
#  NNP -> 'Colo.',
#  NP-SBJ -> PDT DT JJ NN,
#  S-1 -> `` ADVP-TMP , '' PRN `` NP-SBJ VP . '',
#  IN -> 'because',
#  VBN -> 'finalized',
#  NP-1 -> NP NNS,
#  NNS -> 'conferees',
#  JJ -> 'anti-China',
#  ADJP -> NP-ADV JJ,
#  NP-SBJ-1 -> NNP NNP NNPS NN NNP NNP,
#  JJ -> 'verbatim',
#  JJ -> 'erroneous',
#  VBN -> 'shown',
#  NN -> 'depository',
#  NNS -> 'investors',
#  VP -> VB NP , PP-PRP,
#  S -> NP-SBJ , ADVP , VP .,
#  NNS -> 'sub-markets',
#  NN -> 'recession',
#  NNP -> 'Intermec',
#  CD -> '8.5',
#  PP-3 -> RB IN NP,
#  VBZ -> 'asks',
#  VBN -> 'topped',
#  VB -> 'halve',
#  ADJP-PRD -> JJ CC JJ PP,
#  NNS -> 'economics',
#  NN -> 'pie',
#  S -> S , CC S . '',
#  NP -> DT JJ CD NN,
#  NNP -> 'Protection',
#  NN -> 'coupon',
#  NNS -> 'citizens',
#  VP -> VBN NP , PP-MNR , ADVP-TMP , PP,
#  NNP -> 'Foundation',
#  VP -> VB ADJP-CLR,
#  RB -> 'prior',
#  VBG -> 'backing',
#  NNPS -> 'Centers',
#  NN -> 'tower',
#  VBP -> 'convey',
#  VP -> VBN X PRT NP X,
#  JJ -> 'unfair',
#  NN -> 'rate',
#  VBZ -> 'mandates',
#  NNP -> 'Andrew',
#  NN -> 'programmer',
#  NN -> 'solicitor',
#  NNP -> 'Atlantic',
#  -NONE- -> '*-95',
#  NP-SBJ -> DT JJ NNS CC NN NN,
#  PRP$ -> 'Your',
#  VP -> VBZ NP-PRD SBAR,
#  NNP -> 'Mayor',
#  NNS -> 'droughts',
#  RB -> 'presumably',
#  NNP -> 'Gov.',
#  NP -> NNP NNP NNP NNP NNP NNP,
#  UCP -> NN CC JJ,
#  VP -> VB NP PP-DIR-CLR,
#  VP -> PRN VBN NP,
#  VP -> VBD PP-DIR ADVP-TMP,
#  NP-SBJ-161 -> NP PP,
#  VP -> VB ADVP ADVP-TMP,
#  NNP -> 'Council',
#  CD -> '71',
#  NNP -> 'G.',
#  NN -> 'litigation',
#  NNPS -> 'Dolphins',
#  NN -> 'anger',
#  SBAR -> WHNP-60 S,
#  NP-PRD -> CD JJ CD,
#  NP -> DT JJ JJ NN NN,
#  SBAR-TMP -> WHADVP-1 PP S,
#  NP -> NN NN SBAR,
#  NNS -> 'Scientists',
#  NN -> 'handling',
#  CD -> '25.50',
#  VBG -> 'stacking',
#  NNS -> 'railings',
#  JJ -> 'vitriolic',
#  VP -> VB `` NP-PRD,
#  NNS -> 'careers',
#  NNS -> 'weddings',
#  VBN -> 'released',
#  VBG -> 'buying',
#  VBN -> 'faded',
#  JJ -> 'directionless',
#  S -> SBAR-PRP , NP-SBJ-1 VP,
#  NP -> JJR NN NNS,
#  S -> NP-SBJ-1 , S-ADV , VP . '',
#  ADJP-PRD -> VBN NP PP,
#  NP-SBJ -> DT JJ NNP NNP NN,
#  NP -> NN NN NN NNS,
#  NN -> 'halt',
#  RB -> 'longer',
#  NNP -> 'Freshbake',
#  NN -> 'foundation',
#  NP -> NP '' ADVP,
#  NP -> DT JJ NNS NN,
#  NN -> 'load',
#  VP -> VBP NP NP-ADV,
#  JJ -> 'anemic',
#  NNP -> 'Reliance',
#  VBN -> 'stoked',
#  NP-SBJ -> DT JJ NX,
#  VP -> VBP NP-PRD PP-LOC,
#  VP -> VBN NP PP-3,
#  VP -> VBP NP ADVP-MNR ADVP-MNR,
#  NNS -> 'heads',
#  S-1 -> CC PP-LOC PRN `` NP-SBJ VP . '',
#  NNS -> 'uncertainties',
#  VP -> VBZ ADVP-PRD PP-TMP PP , PP,
#  VP -> VBN S , S-ADV,
#  NN -> 'dean',
#  NN -> 'career',
#  NNP -> 'Toledo',
#  VBN -> 'met',
#  NNP -> 'Sol',
#  NP-SBJ-81 -> RB DT JJ NN,
#  NP -> NP PP ADJP , VP .,
#  VBN -> 'treated',
#  JJ -> 'antitrust',
#  VBN -> 'harmed',
#  SBAR-1 -> DT S,
#  RB -> 'politically',
#  VP -> VBD PP-LOC ADJP PP-CLR S-CLR,
#  VBN -> 'invented',
#  SINV -> S-TPC-2 VP NP-SBJ .,
#  NNPS -> 'Republicans',
#  VB -> 'swing',
#  VBG -> 'making',
#  -NONE- -> '*-136',
#  VBD -> 'lacked',
#  NNP -> 'Macheski',
#  VBN -> 'worked',
#  NN -> 'cereal',
#  JJ -> 'fresh',
#  NP-SBJ -> JJ JJ NN,
#  VBG -> 'offsetting',
#  VP -> VBD NP S-CLR SBAR-PRP,
#  NNP -> 'Mariotta',
#  VBP -> 'feel',
#  NNP -> 'Yang',
#  VB -> 'view',
#  NNP -> 'Platt',
#  RB -> 'Here',
#  VP -> VBD NP-EXT NP-TMP SBAR-TMP,
#  NNP -> 'Watanabe',
#  -NONE- -> '*-120',
#  VP -> VBG NP PP-CLR S-PRP,
#  NNP -> 'Ray',
#  NN -> 'disappointment',
#  RB -> 'Shortly',
#  NNP -> 'Tulane',
#  S -> NP-SBJ-1 , S-ADV , VP .,
#  -NONE- -> '*T*-143',
#  CD -> '108',
#  -NONE- -> '*T*-182',
#  NN -> 'reporter',
#  VB -> 'modify',
#  VBZ -> 'picks',
#  NNP -> 'PAP',
#  NNP -> 'Bankruptcy',
#  NP -> DT NN PP-DIR PP-DIR NX-1,
#  VBN -> 'Stung',
#  NNP -> 'Showa',
#  JJ -> 'over',
#  RB -> 'quarterly',
#  JJ -> 'top-level',
#  JJ -> 'modern',
#  NNP -> 'Poland',
#  NP -> NP , NP-LOC SBAR,
#  VP -> VBG NP NP-EXT,
#  CD -> '8.35',
#  WHNP-10 -> WP,
#  NP-SBJ-54 -> PRP,
#  SBAR -> WHNP-157 S,
#  NP-SBJ-149 -> -NONE-,
#  VBD -> 'vowed',
#  NNP -> 'Reed',
#  NNS -> 'leaders',
#  NNP -> 'Rudolph',
#  NN -> 'nameplate',
#  NNP -> 'HOME',
#  NN -> 'image',
#  NN -> 'chauffeur',
#  VBG -> 'emerging',
#  VB -> 'exist',
#  NNS -> 'Citizens',
#  NNP -> 'Crew',
#  NNP -> 'Artist',
#  JJ -> 'eight-month',
#  NNS -> 'graders',
#  -NONE- -> '*T*-217',
#  NNP -> 'Jan.',
#  NP -> NP .,
#  JJ -> 'single-lot',
#  NNP -> 'USA',
#  NN -> 'self',
#  NN -> 'sound',
#  PRN -> -LRB- NP , PP -RRB-,
#  ADVP-PRD -> JJ NP PP,
#  JJ -> 'a',
#  NP -> DT CD NN NN,
#  JJ -> '84-year-old',
#  NNP -> 'Federal',
#  ADVP-TMP -> NP RB PP,
#  NNS -> 'blacks',
#  CD -> '7.2',
#  NNS -> 'felonies',
#  NNP -> 'Development',
#  VBD -> 'cleared',
#  VBD -> 'overvalued',
#  NNS -> 'forecasts',
#  JJ -> 'resigned',
#  ADJP -> CD CD NN,
#  PP-LOC -> NNP NP,
#  JJ -> 'unsettling',
#  VBZ -> 'publishes',
#  NNP -> 'Treble',
#  PP -> IN PP-LOC,
#  S -> SBAR-TMP , NP-SBJ-4 VP . '',
#  NP-SBJ -> NN NNS,
#  VP -> ADVP-TMP ADVP-MNR VB NP,
#  NN -> 'asbestosis',
#  VP -> VB NP NP-TMP-CLR,
#  NNS -> 'households',
#  VBP -> 'fly',
#  VBZ -> 'illustrates',
#  VP -> VBD NP PP-DIR PP-DIR,
#  NN -> 'audit',
#  CD -> '5.92',
#  NNP -> 'Kendrick',
#  MD -> 'Could',
#  NNS -> 'scientists',
#  VBP -> 'exhaust',
#  JJ -> 'senior',
#  CD -> 'THREE',
#  NNS -> 'Policies',
#  VP -> VBG NP NP-TMP,
#  NN -> 'court',
#  NN -> 'twindam',
#  NP-PRD -> NP PP-LOC PP,
#  JJ -> 'generous',
#  NP -> DT QP -NONE-,
#  VP -> VBN NP PP-LOC ADVP-TMP,
#  JJ -> 'big-ticket',
#  NNP -> 'Byron',
#  NP -> NP NN PP,
#  JJ -> 'Long-term',
#  NN -> 'figure',
#  NP-SBJ-59 -> NNS,
#  NN -> 'choosing',
#  CD -> '126,000',
#  VB -> 'resubmit',
#  NP-SBJ -> RBR,
#  NN -> 'compensation',
#  NNP -> 'DiLoreto',
#  S -> NP-SBJ-30 VP .,
#  CD -> '9.9',
#  NN -> 'spectrum',
#  VBN -> 'sought',
#  JJ -> '120-a-share',
#  NP -> QP DT NN,
#  CD -> 'Fifteen',
#  S -> `` S-TPC-4 , '' NP-SBJ VP .,
#  VB -> 'represent',
#  WHNP-62 -> WDT,
#  ADJP -> JJR,
#  NN -> '1\\/10th',
#  JJ -> 'strong-willed',
#  S -> `` S-2 , '' NP-SBJ VP .,
#  VB -> 'want',
#  NN -> 'reaction',
#  NN -> 'electric-utility',
#  -NONE- -> '*-48',
#  JJ -> 'other',
#  NNP -> 'N.H.',
#  WHNP-80 -> WDT,
#  NN -> 'low',
#  NP-SBJ-4 -> NNP NNP,
#  ADVP -> RB NP PP-TMP,
#  PRP -> 'It',
#  NP-SBJ-1 -> DT ADJP NN,
#  VP -> VBG NP-EXT PP-DIR-CLR,
#  RB -> 'ahead',
#  NN -> 'deck',
#  VP -> VBD PP-CLR SBAR-PRP,
#  WP -> 'who',
#  NP -> PRP$ JJ CC JJ NNS,
#  CD -> '1.8415',
#  NP-PRD -> $ CD -NONE-,
#  NN -> 'intoxication',
#  NP -> NNP NNP NNPS NNP POS,
#  NP -> NP RRC,
#  JJ -> 'full-year',
#  NNP -> 'Wis.',
#  VP -> ADVP VB NP,
#  NNS -> 'airports',
#  WHNP-230 -> WDT,
#  CD -> '133.8',
#  NN -> 'competitor',
#  VP -> NNS NP PP-CLR,
#  NP-1 -> JJ NNS,
#  NP-TTL-SBJ -> PRP NNP NNP NNP,
#  VP -> VBN NP-2 PP-CLR S-CLR PP,
#  WDT -> 'That',
#  JJ -> 'plaintive',
#  VP -> VBD NP PP-CLR SBAR-TMP,
#  NN -> 'heavy-truck',
#  NNS -> 'telephones',
#  NNP -> 'University',
#  NNS -> 'posts',
#  JJR -> 'earlier',
#  S -> NP-SBJ-109 VP,
#  NNS -> 'yen',
#  NN -> 'tissue',
#  CD -> '415.6',
#  NP-SBJ -> UCP NNS,
#  NP-TTL -> DT NNP NNP,
#  NP-SBJ-1 -> DT NNP CD JJ NNS NN,
#  ADJP -> `` RB VBN,
#  RB -> 'deliberately',
#  CD -> '143.93',
#  VBN -> 'damaged',
#  NN -> 'psychology',
#  NN -> 'premises',
#  NN -> 'amendment',
#  NNP -> 'Equity',
#  NN -> 'sell',
#  VP -> JJ,
#  NP-PRD -> DT `` JJ NN '',
#  NNP -> 'East',
#  JJ -> 'nominal',
#  JJ -> 'bottom-line',
#  SBAR -> WHNP-250 S,
#  NNS -> 'lesions',
#  CD -> '434.4',
#  VP -> VBG SBAR-PRP,
#  -NONE- -> '*-22',
#  S-TPC-1 -> PP-TMP , S CC S,
#  NP-SBJ-1 -> DT,
#  JJ -> 'chief',
#  VBN -> 'appropriated',
#  SBAR -> -NONE- S-CLF,
#  NP -> NP RB NN,
#  CD -> '6.1',
#  VP -> VB ADVP-DIR ADVP-TMP SBAR-TMP '' PP-PRP,
#  NP-SBJ-114 -> NP NN,
#  JJ -> 'light-truck',
#  VP -> VB NP ADVP-PRP,
#  NP -> -NONE-,
#  CD -> '644',
#  VBP -> 'belong',
#  VBD -> 'retired',
#  S -> NP-SBJ-4 VP,
#  NNP -> 'Hill',
#  VP -> VBN NP PP-EXT PP-DIR PP,
#  NN -> 'restructure',
#  JJ -> 'human',
#  VP -> VBD NP-EXT PP-DIR PP-LOC NP-TMP PP-LOC,
#  NP-SBJ-5 -> NP , NP-LOC ,,
#  NX -> NNP NNP,
#  -NONE- -> '*-147',
#  VBD -> 'eliminated',
#  NNP -> 'Angelo',
#  NN -> 'plant',
#  WHNP-108 -> WDT,
#  NP -> DT NNP NNP NNP NN NN,
#  JJ -> 'conventional',
#  NN -> 'downfall',
#  NNP -> 'Clive',
#  CD -> 'mid-1970s',
#  NNP -> 'Erbamont',
#  NN -> 'intensity',
#  VBG -> 'planning',
#  CD -> '13.15',
#  NP -> NP CC NP , CONJP NP,
#  PP-DIR-2 -> IN NP,
#  VBN -> 'collapsed',
#  JJ -> 'Arbitrage-related',
#  NN -> 'rest',
#  NN -> 'kidney',
#  WHNP-162 -> WDT,
#  NNS -> 'wages',
#  NP-SBJ-1 -> NP , VP ,,
#  NNP -> 'Citizen',
#  NN -> 'barrel',
#  VP -> VBD PP,
#  NNS -> 'riders',
#  NP-SBJ -> RB CD,
#  SBAR -> WHNP-35 S,
#  NN -> 'tone',
#  NP -> NP SBAR SBAR,
#  NNP -> 'Markey',
#  NP-VOC -> NNP,
#  NNS -> 'mistrials',
#  ADJP-PRD -> JJ PP-LOC,
#  VP -> VB PP-PRD-LOC PP-TMP S-PRP,
#  VP -> VBD PP-CLR PP-CLR,
#  S -> S : JJ , S,
#  VBP -> 'cause',
#  JJ -> 'language-housekeeper',
#  NNS -> 'players',
#  RB -> 'manually',
#  NNP -> 'Middlesex',
#  VB -> 'renew',
#  -NONE- -> '*T*-25',
#  CD -> '1.56',
#  NN -> 'defeat',
#  S -> PP , NP-SBJ ADVP VP .,
#  NN -> 'powerhouse',
#  VBD -> 'returned',
#  NP -> NP PP POS,
#  NP -> NN,
#  NP -> NP NN CC JJ NN NN,
#  JJ -> 'multi-crystal',
#  NNPS -> 'Builders',
#  NNS -> 'loans',
#  NP -> CD , CD CC CD,
#  CD -> '11.10',
#  -NONE- -> '*T*-114',
#  NNP -> 'Wakui',
#  NN -> 'overcapacity',
#  NNP -> 'Center',
#  NN -> 'procurement',
#  S -> CC PP , NP-SBJ VP .,
#  NP-SBJ -> DT CD NN NN,
#  NN -> 'planting',
#  NNP -> 'Lefcourt',
#  NNS -> 'ushers',
#  NN -> 'banker',
#  S -> NP-SBJ-108 VP,
#  NP -> JJS NNS,
#  VBP -> 'total',
#  VP -> VBZ S ADVP,
#  VB -> 'cite',
#  CC -> 'Either',
#  VP -> ADVP-MNR VBD NP,
#  VBD -> 'rolled',
#  -NONE- -> '*T*-63',
#  NNS -> 'champions',
#  NN -> 'pillow',
#  CD -> '0.25',
#  NP -> DT VBN NN NN,
#  NNS -> 'conversations',
#  VP -> VBG PRT PP PP-TMP,
#  NP-SBJ-27 -> NN,
#  SBAR -> WHNP-194 S,
#  S -> S , S CC S,
#  NNP -> 'Phillips',
#  NP -> CD ADJP NNS,
#  NNP -> 'Gates',
#  VBD -> 'outnumbered',
#  NP -> JJ CC DT NN,
#  VBG -> 'insinuating',
#  NN -> 'Test',
#  VBG -> 'investigating',
#  NP -> PRP$ VBG JJ NNS,
#  NN -> 'player',
#  VBG -> 'facing',
#  VB -> 'appear',
#  NN -> 'platinum',
#  NNS -> 'sights',
#  NNS -> 'memories',
#  NNP -> 'College',
#  VP -> VBN S ADVP-TMP,
#  NNPS -> 'Brothers',
#  NP-SBJ-166 -> NNP NNP NNP,
#  VBN -> 'robbed',
#  VB -> 'find',
#  NN -> 'memo',
#  NP-SBJ-7 -> NP , NP-LOC ,,
#  ...}

# %%
bb = dependency_treebank.parsed_sents()[1].to_conll(3)
print(bb)
# Out:
# Mr.	NNP	2
# Vinken	NNP	3
# is	VBZ	0
# chairman	NN	3
# of	IN	4
# Elsevier	NNP	7
# N.V.	NNP	12
# ,	,	12
# the	DT	12
# Dutch	NNP	12
# publishing	VBG	12
# group	NN	5
# .	.	3

# %%
dg = DependencyGraph(bb)
dg.tree().pprint()
# Out:
# (is
#   (Vinken Mr.)
#   (chairman (of (group (N.V. Elsevier) , the Dutch publishing)))
#   .)

# %%
from nltk.parse import CoreNLPParser

# %%
parser = CoreNLPParser(url='http://localhost:9000')

# %%
list(parser.parse('What is the airspeed of an unladen swallow ?'.split()))
# Out:
# [Tree('ROOT', [Tree('SBARQ', [Tree('WHNP', [Tree('WP', ['What'])]), Tree('SQ', [Tree('VBZ', ['is']), Tree('NP', [Tree('NP', [Tree('DT', ['the']), Tree('NN', ['airspeed'])]), Tree('PP', [Tree('IN', ['of']), Tree('NP', [Tree('DT', ['an']), Tree('JJ', ['unladen'])])]), Tree('S', [Tree('VP', [Tree('VB', ['swallow'])])])])]), Tree('.', ['?'])])])]

# %%
from nltk.parse.corenlp import CoreNLPDependencyParser

# %%
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %%
sentence1 = "birds supplemented with the n-hexane extract"

# %%
parses1 = dep_parser.parse(sentence1.split())

# %%
aaaa1 = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses1]

# %%
aaaa1[0]
# Out:
# [(('birds', 'NNS'), 'acl', ('supplemented', 'VBN')),
#  (('supplemented', 'VBN'), 'nmod', ('extract', 'NN')),
#  (('extract', 'NN'), 'case', ('with', 'IN')),
#  (('extract', 'NN'), 'det', ('the', 'DT')),
#  (('extract', 'NN'), 'compound', ('n-hexane', 'NN'))]

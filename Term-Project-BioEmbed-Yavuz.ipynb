# %%
import os, re
from nltk.stem import PorterStemmer 
from nltk.stem import WordNetLemmatizer
from nltk.corpus import treebank
from nltk.corpus import dependency_treebank
from nltk.grammar import DependencyGrammar
from nltk.parse import DependencyGraph
import pprint
from nltk.parse.corenlp import CoreNLPDependencyParser
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize, word_tokenize
from gensim.models import Word2Vec, FastText
import numpy as np
import re
from numpy.linalg import norm
from nltk.stem import LancasterStemmer
from nltk.stem.snowball import SnowballStemmer
from string import punctuation
from scipy.spatial import distance

# %%
ps = PorterStemmer()
wnl = WordNetLemmatizer()
lancaster=LancasterStemmer()
sb = SnowballStemmer("english")
dep_parser = CoreNLPDependencyParser(url='http://localhost:9000')

# %%
os.listdir('..')
# Out:
# ['Machine-Learning-Kmeans-PCA',
#  'docker-folder',
#  'Machine-Learning-SVM',
#  '.DS_Store',
#  '.localized',
#  'IMG_0068.jpeg',
#  'CMPE 462',
#  'ev',
#  'data.zip',
#  'folder',
#  'Resumes',
#  'information-retrieval-term-project',
#  'Yavuz_Demir_CV.pdf',
#  'Cmpe493_Task_1',
#  'gerekliler',
#  'deliverables',
#  'Cmpe480 hw3',
#  'IE8 - Win7',
#  'size-recommendation',
#  'BioWordVec_PubMed_MIMICIII_d200.bin',
#  'pp.jpeg',
#  'CV_and_Transcript.zip',
#  'Self Service Portal.app',
#  '.ipynb_checkpoints',
#  'Screen Shot 2020-06-17 at 13.14.06.png',
#  'RegressionTree.ipynb',
#  'MVIMG_20200414_164122.jpg',
#  'size_offering.ipynb',
#  'Cracking the Coding Interview 189 Programming Questions and Solutions.pdf',
#  'data',
#  'cmpe4XX',
#  'BOUN',
#  'Yavuz_Demir_Transcript.pdf',
#  'Taslak_Proje_Kartı.docx',
#  'Cmpe493_Task_2',
#  'senior project',
#  'Trendyol_12-2019_01-2020.json',
#  'progit.pdf',
#  'Machine-Learning-Digit-Classifier']

# %%
import fasttext

# %%
model_path = '../BioWordVec_PubMed_MIMICIII_d200.bin'

# %%
model = FastText.load_fasttext_format(model_path)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `load_fasttext_format` (use load_facebook_vectors (to use pretrained embeddings) or load_facebook_model (to continue training with the loaded full model, more RAM) instead).
#   """Entry point for launching an IPython kernel.

# %%
model['tissu']
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#   """Entry point for launching an IPython kernel.
# array([ 5.31710327e-01, -3.77059318e-02,  3.41162592e-01,  1.30785510e-01,
#        -3.24835479e-01,  2.01382905e-01, -1.58458814e-01,  4.62670326e-01,
#         5.57236113e-02,  3.51219803e-01, -2.62746185e-01, -2.92433411e-01,
#         4.73509878e-02,  4.57055598e-01, -2.39069209e-01, -2.30160400e-01,
#        -2.07246840e-01, -1.44334629e-01, -4.01046202e-02, -3.00321370e-01,
#         5.53370178e-01,  5.17582335e-02, -2.45898768e-01,  1.81035340e-01,
#        -1.08711213e-01,  2.44223043e-01,  1.40539274e-01,  2.33177438e-01,
#         2.81401366e-01,  3.42572093e-01,  8.12903464e-01, -3.78166556e-01,
#        -7.11274147e-01, -3.64127845e-01, -9.40698311e-02, -1.77061036e-01,
#         5.26139319e-01, -1.32803097e-01,  4.55091655e-01,  3.31587851e-01,
#         4.92070287e-01, -3.98441613e-01,  1.57674272e-02,  3.11904579e-01,
#         1.19641133e-01,  1.10997581e+00,  2.76450932e-01,  1.49310559e-01,
#        -8.19315761e-02,  6.49495363e-01,  2.89486777e-02,  1.59328468e-02,
#        -1.65873110e-01, -3.41677487e-01, -3.57180438e-03,  1.38417140e-01,
#        -2.28198245e-01,  4.83235031e-01,  2.55796075e-01,  2.94885069e-01,
#        -6.35940015e-01,  9.83898520e-01,  8.12271178e-01,  4.27300096e-01,
#        -1.21498205e-01, -1.67904615e-01,  6.76435292e-01,  1.39513716e-01,
#         5.69246590e-01,  5.02631724e-01, -7.47117475e-02, -2.91314740e-02,
#        -5.28406322e-01, -5.76677203e-01, -8.94944131e-01, -4.76547062e-01,
#         3.85145366e-01,  2.97126949e-01, -2.52663523e-01,  2.50877231e-01,
#         1.47742271e-01, -9.82489705e-01,  3.87770653e-01, -1.22860700e-01,
#        -4.41606134e-01, -4.55621704e-02,  4.12910432e-02, -4.81228173e-01,
#         1.15708046e-01, -7.31784821e-01,  9.80361248e-04,  1.95225105e-01,
#         5.41066051e-01, -5.12253523e-01, -3.46800163e-02, -4.25317496e-01,
#        -5.83851486e-02,  8.24074328e-01,  7.79003501e-01,  1.79377854e-01,
#        -4.00115192e-01, -5.43762267e-01, -5.30477911e-02, -5.93534820e-02,
#        -4.64463115e-01, -1.24995403e-01, -1.41455472e+00,  3.62339169e-01,
#         7.05107093e-01, -2.69304395e-01,  1.40461370e-01,  6.03883386e-01,
#        -7.78667092e-01,  2.30162814e-01,  2.54486531e-01,  2.00799644e-01,
#        -4.52327728e-01, -1.59950092e-01, -1.04603803e+00,  3.97047698e-01,
#         2.09746137e-01,  4.86800253e-01, -1.24732956e-01,  8.03829730e-02,
#         8.24821368e-03, -3.37617785e-01,  9.28046763e-01,  4.42202061e-01,
#        -3.14686716e-01,  2.15791449e-01, -4.84361023e-01, -2.45788917e-01,
#         3.16031724e-01, -1.50116840e-02, -3.68763536e-01,  3.94781858e-01,
#        -4.89999652e-01,  2.59528995e-01,  4.02652055e-01,  3.76147240e-01,
#        -1.42622635e-01,  5.85488737e-01,  4.55975831e-01,  3.69197011e-01,
#        -4.66595083e-01, -2.06237391e-01,  2.79072315e-01, -5.30673087e-01,
#        -2.55340457e-01, -5.42771637e-01,  9.19979334e-01,  4.16774213e-01,
#        -1.37739003e-01,  3.76050860e-01, -1.37001365e-01,  6.42457724e-01,
#        -3.32135260e-01, -7.82600269e-02,  3.51020217e-01, -1.10326372e-02,
#         1.54222563e-01,  8.03351402e-02,  4.44652617e-01, -4.95550841e-01,
#        -5.90941489e-01, -2.96296239e-01, -1.87561959e-01, -6.56449646e-02,
#        -6.17054701e-01, -3.34784508e-01,  7.99908787e-02,  9.03876275e-02,
#        -6.58277094e-01,  2.66453683e-01, -3.68930399e-01,  4.70727861e-01,
#        -2.43249442e-02, -3.65113281e-02,  3.97032082e-01, -8.81049037e-01,
#        -2.05558345e-01,  2.72785097e-01, -3.80211949e-01,  3.50129306e-01,
#        -5.61509073e-01, -4.07384962e-01,  8.88510197e-02,  3.25576991e-01,
#        -9.08637404e-01,  4.24181551e-01, -3.21657777e-01, -1.66025653e-01,
#         5.02134740e-01,  9.57985580e-01, -1.46846592e-01, -2.12919205e-01,
#         8.71530771e-02,  1.78070396e-01,  1.98318467e-01, -8.51515353e-01],
#       dtype=float32)

# %%
class Habitat:
    oid = -1
    name = ""

# %%
train_path = "./BioNLP-OST-2019_BB-norm_train/"
test_path = "./BioNLP-OST-2019_BB-norm_test/"
dev_path = "./BioNLP-OST-2019_BB-norm_dev/"
BB_train = os.listdir(train_path)
BB_test = os.listdir(test_path)
BB_dev = os.listdir(dev_path)
obp_file = "OntoBiotope_BioNLP-OST-2019.obo"

# %%
ontology = open(obp_file,encoding="utf8").read()

# %%
BB_train_a1 = sorted([name for name in BB_train if name.endswith("a1")])
BB_train_a2 = sorted([name for name in BB_train if name.endswith("a2")])
BB_train_txt = sorted([name for name in BB_train if name.endswith("txt")])

BB_dev_a1 = sorted([name for name in BB_dev if name.endswith("a1")])
BB_dev_a2 = sorted([name for name in BB_dev if name.endswith("a2")])
BB_dev_txt = sorted([name for name in BB_dev if name.endswith("txt")])

BB_test_a1 = sorted([name for name in BB_test if name.endswith("a1")])
BB_test_txt = sorted([name for name in BB_test if name.endswith("txt")])

# %%
def l_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = lancaster.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def s_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = sb.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def original_phrase(phrase):
    return phrase

# %%
def p_stem_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = ps.stem(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def lemmatize_phrase(phrase):
    #print(type(phrase))
    #print(phrase)
    
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = wnl.lemmatize(phrase[i])
    phrase = " ".join(phrase)
    return phrase

# %%
def switch_to_lower(phrase):
    phrase = phrase.split(" ")
    for i in range(len(phrase)):
        if phrase[i] != phrase[i].upper():
            phrase[i] = phrase[i].lower()
    phrase = " ".join(phrase)
    return phrase

# %%
def get_jaccard_sim(p1, p2, processor):
    p1 = processor(switch_to_lower(p1))
    p2 = processor(switch_to_lower(p2))
    p1, p2= p1.split(" "), p2.split(" ")
    union = set(p1+p2)
    intersection = [word for word in set(p1) if word in set(p2)]
    return len(intersection)/len(union)

# %%
phrase_reducer = lemmatize_phrase

# %%
def get_headword(phrase):
    #print(phrase)
    if phrase == phrase.upper():
        return ""
    
    parses = dep_parser.parse(phrase.split())
    triples = [[(governor, dep, dependent) for governor, dep, dependent in parse.triples()] for parse in parses]
    
    try:
        if(len(triples) > 0 and len(triples[0]) > 0 and len(triples[0][0]) > 0 and len(triples[0][0][0]) > 0 and triples[0][0][0][0] is not None):
            return triples[0][0][0][0]
        else:
            return phrase
    except:
        return phrase

# %%
def add_documents(txt, processor):
    document = []
    #txt = processor(txt)
    sentence_list = sent_tokenize(txt)
    
    for sentence in sentence_list:
        sentence = sentence.replace('-', ' ')
        
        word_list = word_tokenize(sentence)
        word_list = [word for word in word_list if word not in stopwords.words("english") and word.isalnum()]
        for i in range(len(word_list)):
            if word_list[i].isnumeric():
                word_list[i] = "##number##"
            if word_list[i] != word_list[i].upper():
                word_list[i] = processor(word_list[i].lower())
             
        document.append(word_list)
    #print(document)
    return document

# %%
documents = []
for i in range(len(BB_train_txt)):
    txt = open(train_path + BB_train_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_dev_txt)):
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)
for i in range(len(BB_test_txt)):
    txt = open(test_path + BB_test_txt[i],encoding="utf8").read()
    documents += add_documents(txt, phrase_reducer)

# %%
#model = Word2Vec(documents, min_count=1)

# %%
def get_phrase_embedding(phrase, model, processor):
    original_phrase = phrase
    phrase = phrase.replace('-', ' ')
    hyphenless_phrase = phrase
    phrase = nltk.word_tokenize(phrase)
    phrase = [word for word in phrase if word.lower() not in stopwords.words("english") and word.isalnum()]
    for i in range(len(phrase)):
        if phrase[i].isnumeric():
            phrase[i] = "##number##"
        if phrase[i] != phrase[i].upper():
            phrase[i] = processor(phrase[i].lower())
    #print(phrase)
    phrase_size = len(phrase)
    vec_size = len(model[list(model.wv.vocab)[0]])
    embedded_sum = np.zeros(vec_size)
    if(phrase_size == 0):
        return -1
    for word in phrase:
        try:
            embedded_sum = embedded_sum + np.array(model[word])
        except:
            return -1
    embedded_sum = embedded_sum / phrase_size
    
    ####
    hw = get_headword(hyphenless_phrase)
    if hw == "":
        pass
        #print(hyphenless_phrase)
    else:
        hw_emb = np.array(model[processor(switch_to_lower(hw))])
        embedded_sum = (embedded_sum + hw_emb)/2
    ####
    return embedded_sum

# %%
def generate_habitat_map(processor, model):
    habitat_list = ontology.split("\n\n[Term]\n")[1:]
    habitat_map = {}
    habitat_map_originals = {}
    habitat_embeddings = {}
    for h in habitat_list:
        #new_habitat = Habitat()
        h = h.split("\n")
        oid = re.findall(r"(?<=id: OBT:)[0-9]+", h[0])[0]
        name = (re.findall(r"(?<=name: ).+", h[1])[0])
        original_name = name
        if name != name.upper():
            name = switch_to_lower(name)
            name = processor(name)
    
        habitat_map[name] = oid
        habitat_map_originals[oid] = name
        embedding = get_phrase_embedding(name, model, processor)
        if type(embedding) == type(np.array([1])):
            habitat_embeddings[name] = embedding
    
        # word2vec buraya eklenmeli 
        for h_line in h:
            if "synonym" in h_line:
                synonym_name = (re.findall(r"(?<=synonym: \").+(?=\")", h_line)[0])
                if synonym_name != synonym_name.upper():
                    synonym_name = switch_to_lower(synonym_name)
                    synonym_name = processor(synonym_name)
                if "EXACT" in h_line and synonym_name not in habitat_map:
                    habitat_map[synonym_name] = oid
                    if type(embedding) == type(np.array([1])):
                        habitat_embeddings[synonym_name] = embedding
                    
    return habitat_map, habitat_map_originals, habitat_embeddings

# %%
habitat_map, habitat_map_originals, habitat_embeddings = generate_habitat_map(phrase_reducer, model)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def add_habitats(a1, a2, processor, model):
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    
    
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]: 
                named_entity = (a1[a1_line].split("\t")[2])
                named_entity = named_entity.replace('-', ' ')
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                if named_entity not in habitat_map:
                    habitat_map[named_entity] = oid
                
                if habitat_map_originals[oid] not in habitat_embeddings:
                    habitat_embeddings[habitat_map_originals[oid]] = []
                
                if type(habitat_embeddings[habitat_map_originals[oid]]) == list:
                    emb = get_phrase_embedding(named_entity, model, processor)
                    if type(emb) == int:
                        print("no embedding for", named_entity)
                    habitat_embeddings[habitat_map_originals[oid]].append(emb)

# %%
for i in range(len(BB_train_txt)):    
    a1 = open(train_path + BB_train_a1[i],encoding="utf8").read()
    a2 = open(train_path + BB_train_a2[i],encoding="utf8").read()
    add_habitats(a1, a2, phrase_reducer, model)

# %%
for key in habitat_embeddings:
    if type(habitat_embeddings[key]) == list:
        vec_size = len(habitat_embeddings[key][0])
        temp_vec = np.zeros(vec_size)
        for vec in habitat_embeddings[key]:
            temp_vec += vec
        temp_vec /= len(habitat_embeddings[key])
        habitat_embeddings[key] = temp_vec

# %%
def predict_habitats_exact_matching(a1, txt, a1_name, processor, pred_file_name):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            cands += 1
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + "---exact"
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                found = True
            else:
                #print(name)
                pre_named_entity = get_headword(name)
                #print(pre_named_entity)
                named_entity = processor(pre_named_entity)
                if named_entity in habitat_map:
                    matches += 1
                    match = name + " - " + habitat_map[named_entity] + "---headwordexact"
                    print(match)
                    match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                    found = True
        if found:
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
            count += 1
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def predict_habitats(a1, txt, a1_name, processor, pred_file_name, model):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] + " ---exact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
             
            #print(name)
            pre_named_entity = get_headword(name)
            #print(pre_named_entity)
            named_entity = processor(pre_named_entity)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] +" ---headwordexact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                found = True
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
            
            cands += 1
            name = (line.split("\t")[2])
            name = name.replace("-", " ")
            named_entity = name
            entity_vec = get_phrase_embedding(named_entity, model, processor)
            match_id = ""
            largest_prod = 0
            if type(entity_vec) != int:
                largest_prod = np.dot(entity_vec, habitat_embeddings[list(habitat_embeddings)[0]])/(norm(entity_vec)*norm(habitat_embeddings[list(habitat_embeddings)[0]]))
                match_id = habitat_map[list(habitat_embeddings)[0]]
                for habitat in habitat_embeddings:
                    prod = np.dot(entity_vec,habitat_embeddings[habitat])/(norm(entity_vec)*norm(habitat_embeddings[habitat]))
                    if prod > largest_prod:
                        largest_prod = prod
                        match_id = habitat_map[habitat]
            else:
                print("Doc:", a1_name," no embedding for:", named_entity)
                continue
                
            match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
            match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
            #print(line.split("\t")[0], "matched with w2v")
            #print(match_list)
            #print(match)
            
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
            count += 1
            
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
def predict_habitats_threshold(a1, txt, a1_name, processor, pred_file_name, model, threshold):
    pred_file = open(pred_file_name, "w")
    cands = 0
    matches = 0
    match_list = {}
    a1 = a1.split("\n")
    count = 1
    for line in a1:
        found = False
        if "Habitat" in line:
            
            
            cands += 1
            name = (line.split("\t")[2])
            name = name.replace("-", " ")
            named_entity = name
            entity_vec = get_phrase_embedding(named_entity, model, processor)
            match_id = ""
            largest_prod = 0
            if type(entity_vec) != int:
                largest_prod = np.dot(entity_vec, habitat_embeddings[list(habitat_embeddings)[0]])/(norm(entity_vec)*norm(habitat_embeddings[list(habitat_embeddings)[0]]))
                match_id = habitat_map[list(habitat_embeddings)[0]]
                for habitat in habitat_embeddings:
                    prod = np.dot(entity_vec,habitat_embeddings[habitat])/(norm(entity_vec)*norm(habitat_embeddings[habitat]))
                    if prod > largest_prod:
                        largest_prod = prod
                        match_id = habitat_map[habitat]
            
            if largest_prod > threshold:
                match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
                match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
                #print(line.split("\t")[0], "matched with w2v")
                #print(match_list)
                #print(match)
                
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
                count += 1
                continue

            
            name = (line.split("\t")[2])
            named_entity = name
            if name != name.upper():
                name = switch_to_lower(name)
                named_entity = processor(name)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] + " ---exact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], named_entity, "exact"]
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
             
            #print(name)
            pre_named_entity = get_headword(name)
            #print(pre_named_entity)
            named_entity = processor(pre_named_entity)
            if named_entity in habitat_map:
                matches += 1
                match = name + " - " + habitat_map[named_entity] + " - " + habitat_map_originals[habitat_map[named_entity]] +" ---headwordexact"
                #print(match)
                match_list[line.split("\t")[0]] = [habitat_map[named_entity], name, "headwordexact", named_entity]
                found = True
                pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_list[line.split("\t")[0]][0] + "\n")
                count += 1
                continue
            
            
            match_list[line.split("\t")[0]] = [match_id, named_entity, "w2v", largest_prod]
            match = name + " - " + match_id + " - " + habitat_map_originals[match_id] + " ---w2v"
            #print(line.split("\t")[0], "matched with w2v")
            #print(match_list)
            #print(match)
            
            pred_file.write("N" + str(count) +"\tOntoBiotope Annotation:" + line.split("\t")[0] + " Referent:OBT:" + match_id + "\n")
            count += 1
            
    #print(a1_name)
    #print("Out of", cands, "candidates,", matches, "matches found")
    #print()
    pred_file.close()
    return match_list

# %%
annotations_test = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    txt = open(dev_path + BB_dev_txt[i],encoding="utf8").read()
    pred_file_name = "./dev_preds/" + BB_dev_a2[i]
    annotations_test[BB_dev_a1[i]] = predict_habitats_threshold(a1, txt, BB_dev_a1[i], phrase_reducer, pred_file_name, model, 0.9)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:20: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:31: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).

# %%
def test_habitats(a1, a2, processor):
    
    a2 = a2.split("\n")
    a1 = a1.split("\n")
    match_list = {}
    for annotation in a2:
        a1_line = 0
        t = ""
        oid = ""
        #print(annotation)
        if "OntoBiotope" in annotation:
            t = re.findall(r"(?<=Annotation:)T[0-9]+", annotation)[0]
            oid = re.findall(r"(?<=Referent:OBT:)[0-9]+", annotation)[0]
            named_entity = ""
            while t not in a1[a1_line] and a1_line < len(a1)-1:
                a1_line += 1
            if "Habitat" in a1[a1_line]:
                named_entity = (a1[a1_line].split("\t")[2])
                if named_entity != named_entity.upper():
                    named_entity = switch_to_lower(named_entity)
                    named_entity = processor(named_entity)
                match_list[t] = [oid, named_entity]
    return match_list

# %%
dev_a2 = {}
for i in range(len(BB_dev_txt)):
    a1 = open(dev_path + BB_dev_a1[i],encoding="utf8").read()
    a2 = open(dev_path + BB_dev_a2[i],encoding="utf8").read()
    dev_a2[BB_dev_a1[i]] = test_habitats(a1,a2, phrase_reducer)

# %%
true_pred_count = 0
false_pred_count = 0
total_count = 0
for key in dev_a2:
    """print()
    print(key)
    print(dev_a2[key])
    print("**************")"""
    total_count += len(dev_a2[key])
    if key in annotations_test:
        for pred in annotations_test[key]:            
            if annotations_test[key][pred][0] == dev_a2[key][pred][0]:
                true_pred_count += 1
                if annotations_test[key][pred][2] == "w2v":
                    print(key)
                    print(True)
                    #print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred], " Type:", annotations_test[key][pred][2])
                    print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                    print("Cosine Similarity:", annotations_test[key][pred][3])
                    print()
            else:
                if annotations_test[key][pred][2] == "w2v":
                    print(key)
                    print(False)
                    #print("Prediction:", annotations_test[key][pred]," Real:", dev_a2[key][pred], " Type:", annotations_test[key][pred][2])
                    print("Word:", annotations_test[key][pred][1]," Prediction:", habitat_map_originals[annotations_test[key][pred][0]], " Real:", habitat_map_originals[dev_a2[key][pred][0]], " Type:", annotations_test[key][pred][2])
                    print("Cosine Similarity:", annotations_test[key][pred][3])
                    print()
                false_pred_count += 1
# Out:
# BB-norm-10496597.a1
# True
# Word: gastric mucosa  Prediction: gastric mucosa  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-10496597.a1
# False
# Word: gastric mucosal associated lymphoid tissue  Prediction: mucosal tissue  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.9792634180281846
#
# BB-norm-10496597.a1
# True
# Word: gastric mucosal  Prediction: gastric mucosa  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 0.9144898135365639
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: murine  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.3690408687491676
#
# BB-norm-10496597.a1
# False
# Word: monoclonal B cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.9560523414533005
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: gastric acid  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.5152599688971322
#
# BB-norm-10496597.a1
# False
# Word: patients with atypical lymphoid infiltrates  Prediction: patient with infectious disease  Real: patient  Type: w2v
# Cosine Similarity: 0.9330118706110199
#
# BB-norm-10496597.a1
# True
# Word: patients with low grade MALT lymphoma  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9486913417202328
#
# BB-norm-10496597.a1
# True
# Word: patients with Helicobacter pylori chronic active gastritis  Prediction: patient with infectious disease  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9199113449375699
#
# BB-norm-10496597.a1
# True
# Word: patients with high grade primary gastric lymphoma  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9394190478052696
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: murine  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.3690408687491676
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: oil-water separator  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.4338575649964063
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: rice chip  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.29434767371846315
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: murine  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.3690408687491676
#
# BB-norm-10496597.a1
# False
# Word: patients with chronic active gastritis  Prediction: patient with infectious disease  Real: patient  Type: w2v
# Cosine Similarity: 0.9430608242315819
#
# BB-norm-10496597.a1
# False
# Word: CD20 positive cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.9606120426419299
#
# BB-norm-10496597.a1
# True
# Word: lymphocytic  Prediction: lymphocyte  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.6806662619659938
#
# BB-norm-10496597.a1
# False
# Word: B cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.9688289826534627
#
# BB-norm-10496597.a1
# False
# Word: T cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-10496597.a1
# True
# Word: lymphocytic  Prediction: lymphocyte  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.6806662619659938
#
# BB-norm-10496597.a1
# False
# Word: lymphoepithelial  Prediction: pleomorphic  Real: epithelium  Type: w2v
# Cosine Similarity: 0.6608622410246592
#
# BB-norm-10496597.a1
# True
# Word: Lymphoepithelial lesions  Prediction: lesion  Real: lesion  Type: w2v
# Cosine Similarity: 0.9610659183915263
#
# BB-norm-10496597.a1
# False
# Word: biopsy  Prediction: needle  Real: medical sample  Type: w2v
# Cosine Similarity: 0.6863024363673946
#
# BB-norm-10496597.a1
# False
# Word: monoclonal B cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.9560523414533005
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: oil-water separator  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.4338575649964063
#
# BB-norm-10496597.a1
# False
# Word:   Prediction: rice chip  Real: lymphocyte  Type: w2v
# Cosine Similarity: 0.29434767371846315
#
# BB-norm-10496597.a1
# False
# Word: MALT  Prediction: gastric acid  Real: lymphatic system part  Type: w2v
# Cosine Similarity: 0.5152599688971322
#
# BB-norm-11989773.a1
# False
# Word: chicken nugget processing plant  Prediction: rice plant  Real: meat industry  Type: w2v
# Cosine Similarity: 0.960434053696836
#
# BB-norm-11989773.a1
# False
# Word: chicken  Prediction: chicken  Real: chicken meat  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-11989773.a1
# True
# Word: chicken nugget  Prediction: nugget  Real: nugget  Type: w2v
# Cosine Similarity: 0.9599203417522947
#
# BB-norm-11989773.a1
# False
# Word: handler  Prediction: food slicing machine  Real: worker  Type: w2v
# Cosine Similarity: 0.7787293412360764
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-11989773.a1
# False
# Word: chicken  Prediction: chicken  Real: chicken meat  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-11989773.a1
# True
# Word: chicken nugget  Prediction: nugget  Real: nugget  Type: w2v
# Cosine Similarity: 0.9599203417522947
#
# BB-norm-11989773.a1
# False
# Word: chicken nugget processing plant  Prediction: rice plant  Real: meat industry  Type: w2v
# Cosine Similarity: 0.960434053696836
#
# BB-norm-11989773.a1
# True
# Word: selective agars  Prediction: agar  Real: agar  Type: w2v
# Cosine Similarity: 0.9755007166203126
#
# BB-norm-11989773.a1
# False
# Word:   Prediction: bovine serum  Real: agar  Type: w2v
# Cosine Similarity: 0.21775196268645372
#
# BB-norm-11989773.a1
# False
# Word:   Prediction: turbot  Real: agar  Type: w2v
# Cosine Similarity: 0.2666716293111334
#
# BB-norm-11989773.a1
# False
# Word:   Prediction: rocket  Real: agar  Type: w2v
# Cosine Similarity: 0.2238849309839914
#
# BB-norm-11989773.a1
# False
# Word: handler  Prediction: food slicing machine  Real: worker  Type: w2v
# Cosine Similarity: 0.7787293412360764
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-11989773.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-11989773.a1
# False
# Word: handler  Prediction: food slicing machine  Real: worker  Type: w2v
# Cosine Similarity: 0.7787293412360764
#
# BB-norm-12109661.a1
# True
# Word: gastric mucosa  Prediction: gastric mucosa  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-12109661.a1
# False
# Word: control monkeys  Prediction: monkey  Real: laboratory animal  Type: w2v
# Cosine Similarity: 0.9652185745419625
#
# BB-norm-12109661.a1
# True
# Word: children  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-12109661.a1
# True
# Word: gastric mucosa  Prediction: gastric mucosa  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-12109661.a1
# False
# Word: patients with chronic gastritis  Prediction: patient with infectious disease  Real: patient  Type: w2v
# Cosine Similarity: 0.9417696183358991
#
# BB-norm-12109661.a1
# True
# Word: patients with gastric cancer  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9355410273095379
#
# BB-norm-12109661.a1
# True
# Word: young Japanese gastric cancer patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9425413241399472
#
# BB-norm-12109661.a1
# False
# Word: group  Prediction: high pressure treated food  Real: child  Type: w2v
# Cosine Similarity: 0.6125361673310845
#
# BB-norm-12109661.a1
# True
# Word: gastric mucosa  Prediction: gastric mucosa  Real: gastric mucosa  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1214327.a1
# True
# Word: gastroenteritis patients  Prediction: patient with infectious disease  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9517039294876374
#
# BB-norm-1214327.a1
# False
# Word: healthy carriers  Prediction: carrier  Real: healthy person  Type: w2v
# Cosine Similarity: 0.969994683502717
#
# BB-norm-1214327.a1
# True
# Word: water  Prediction: water  Real: water  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-1214327.a1
# False
# Word: fish samples  Prediction: medical sample  Real: fish  Type: w2v
# Cosine Similarity: 0.9167187710636673
#
# BB-norm-1356998.a1
# True
# Word: Human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# True
# Word: tick  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# True
# Word: ticks  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# True
# Word: humans  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# False
# Word: human  Prediction: human  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# True
# Word: patients suffering from rickettsial disease of different degrees of severity  Prediction: patient with infectious disease  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9701156625317949
#
# BB-norm-1356998.a1
# True
# Word: ticks  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-1356998.a1
# False
# Word: humans  Prediction: human  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-14633026.a1
# False
# Word: molestus  Prediction: glossina  Real: mosquito  Type: w2v
# Cosine Similarity: 0.7554664387288976
#
# BB-norm-14633026.a1
# True
# Word: culicine mosquito  Prediction: mosquito  Real: mosquito  Type: w2v
# Cosine Similarity: 0.9854906905167783
#
# BB-norm-15293611.a1
# False
# Word: paediatric cystic fibrosis units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9375775713183518
#
# BB-norm-15293611.a1
# True
# Word: paediatric  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 0.658492021283435
#
# BB-norm-15293611.a1
# False
# Word: adult cystic fibrosis units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9337147226247214
#
# BB-norm-15293611.a1
# False
# Word: adult  Prediction: young adult  Real: adult human  Type: w2v
# Cosine Similarity: 0.9862518130416087
#
# BB-norm-15293611.a1
# False
# Word: cystic fibrosis (CF) units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9252365675638987
#
# BB-norm-15293611.a1
# True
# Word: Sputum  Prediction: sputum  Real: sputum  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-15293611.a1
# True
# Word: productive patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9544175159464219
#
# BB-norm-15293611.a1
# False
# Word: regional adult CF units  Prediction: air treatment unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9395884029821208
#
# BB-norm-15293611.a1
# False
# Word: regional paediatric CF units  Prediction: intensive care unit  Real: hospital environment  Type: w2v
# Cosine Similarity: 0.9441346841136133
#
# BB-norm-15293611.a1
# True
# Word: paediatric  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 0.658492021283435
#
# BB-norm-15293611.a1
# False
# Word: adult  Prediction: young adult  Real: adult human  Type: w2v
# Cosine Similarity: 0.9862518130416087
#
# BB-norm-15293611.a1
# True
# Word: sputum  Prediction: sputum  Real: sputum  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: clinic  Prediction: clinic  Real: clinic  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: patient  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15293611.a1
# True
# Word: lung  Prediction: lung  Real: lung  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-15293611.a1
# True
# Word: patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-15618837.a1
# True
# Word: dyspeptic patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9482376129068779
#
# BB-norm-15618837.a1
# True
# Word: patients with chronic dyspepsia  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9395838399725734
#
# BB-norm-15618837.a1
# True
# Word: clinic  Prediction: clinic  Real: clinic  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-15618837.a1
# False
# Word: biopsy  Prediction: needle  Real: medical sample  Type: w2v
# Cosine Similarity: 0.6863024363673946
#
# BB-norm-15618837.a1
# True
# Word: Patients with H. pylori infection  Prediction: patient with infectious disease  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9449130900089417
#
# BB-norm-15618837.a1
# True
# Word: dyspeptic patients  Prediction: patient  Real: patient  Type: w2v
# Cosine Similarity: 0.9482376129068779
#
# BB-norm-16273411.a1
# True
# Word: neonatal  Prediction: newborn infant  Real: newborn infant  Type: w2v
# Cosine Similarity: 0.7318273100378676
#
# BB-norm-16273411.a1
# False
# Word: humans  Prediction: human  Real: pregnant woman  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-16273411.a1
# False
# Word: animals  Prediction: animal  Real: female animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16273411.a1
# True
# Word: humans  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-16273411.a1
# True
# Word: placenta of a 38 year old secondary recurrent aborter  Prediction: placenta  Real: placenta  Type: w2v
# Cosine Similarity: 0.9472392188175551
#
# BB-norm-16273411.a1
# True
# Word: aborter  Prediction: pregnant woman  Real: pregnant woman  Type: w2v
# Cosine Similarity: 0.6333453276537729
#
# BB-norm-16458564.a1
# True
# Word: children  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# True
# Word: children less than five years of age  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 0.9481217720543201
#
# BB-norm-16458564.a1
# False
# Word: population  Prediction: medical sample  Real: child  Type: w2v
# Cosine Similarity: 0.6480722546971184
#
# BB-norm-16458564.a1
# False
# Word: children with diarrhea  Prediction: child  Real: ill person  Type: w2v
# Cosine Similarity: 0.9548420132533069
#
# BB-norm-16458564.a1
# False
# Word: control  Prediction: stratified marine water column  Real: healthy person  Type: w2v
# Cosine Similarity: 0.6521227324129188
#
# BB-norm-16458564.a1
# False
# Word: children with diarrhea  Prediction: child  Real: ill person  Type: w2v
# Cosine Similarity: 0.9548420132533069
#
# BB-norm-16458564.a1
# False
# Word: children less than two years of age  Prediction: child  Real: baby  Type: w2v
# Cosine Similarity: 0.9483627511162926
#
# BB-norm-16458564.a1
# True
# Word: older children  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 0.9762295465843737
#
# BB-norm-16458564.a1
# True
# Word: Children attending the hospitals  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 0.9547867498532981
#
# BB-norm-16458564.a1
# True
# Word: hospitals  Prediction: hospital  Real: hospital  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-16458564.a1
# False
# Word: Watery stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9690781961733796
#
# BB-norm-16458564.a1
# False
# Word: mucous stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9669739461284691
#
# BB-norm-16458564.a1
# True
# Word: mucous  Prediction: mucus  Real: mucus  Type: w2v
# Cosine Similarity: 0.8211679556202406
#
# BB-norm-16458564.a1
# False
# Word: stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-16458564.a1
# True
# Word: hospitals  Prediction: hospital  Real: hospital  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-16458564.a1
# False
# Word: children  Prediction: child  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# False
# Word: children  Prediction: child  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# False
# Word: piped  Prediction: mine waste water  Real: drinking water  Type: w2v
# Cosine Similarity: 0.8158766791938132
#
# BB-norm-16458564.a1
# True
# Word: latrine  Prediction: latrine  Real: latrine  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# True
# Word: mothers  Prediction: mother  Real: mother  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# False
# Word: children  Prediction: child  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# True
# Word: mothers  Prediction: mother  Real: mother  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# True
# Word: children  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16458564.a1
# False
# Word: fresh water  Prediction: water  Real: freshwater  Type: w2v
# Cosine Similarity: 0.9759183348670281
#
# BB-norm-16458564.a1
# True
# Word: fresh water supply  Prediction: drinking water supply  Real: drinking water supply  Type: w2v
# Cosine Similarity: 0.9750816042751587
#
# BB-norm-16458564.a1
# True
# Word: unhygienic septic tank  Prediction: septic tank  Real: septic tank  Type: w2v
# Cosine Similarity: 0.9835855802513864
#
# BB-norm-16458564.a1
# True
# Word: children  Prediction: child  Real: child  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-16514151.a1
# True
# Word: rich medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9557014726599407
#
# BB-norm-18094887.a1
# True
# Word: animals  Prediction: animal  Real: animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: humans  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# True
# Word: ticks  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# True
# Word: fleas  Prediction: flea  Real: flea  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: flea  Prediction: flea  Real: flea  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# False
# Word: antiquorum  Prediction: osmitopsis asteriscoides  Real: flea  Type: w2v
# Cosine Similarity: 0.7035821390892559
#
# BB-norm-18094887.a1
# False
# Word: felis  Prediction: rat flea  Real: flea  Type: w2v
# Cosine Similarity: 0.7616596165638362
#
# BB-norm-18094887.a1
# False
# Word: atopus  Prediction: osmitopsis asteriscoides  Real: flea  Type: w2v
# Cosine Similarity: 0.7735880501129841
#
# BB-norm-18094887.a1
# False
# Word: rimatus  Prediction: ornithodoros moubata  Real: flea  Type: w2v
# Cosine Similarity: 0.7189988132684231
#
# BB-norm-18094887.a1
# False
# Word: roberti  Prediction: schabziger  Real: flea  Type: w2v
# Cosine Similarity: 0.7411176491533868
#
# BB-norm-18094887.a1
# False
# Word: tripus  Prediction: antelope  Real: flea  Type: w2v
# Cosine Similarity: 0.6244441162638656
#
# BB-norm-18094887.a1
# False
# Word: lugubris  Prediction: ornithodoros moubata  Real: flea  Type: w2v
# Cosine Similarity: 0.7673693310720711
#
# BB-norm-18094887.a1
# False
# Word: lutzi  Prediction: ornithodoros moubata  Real: flea  Type: w2v
# Cosine Similarity: 0.7306189438244111
#
# BB-norm-18094887.a1
# True
# Word: tick  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# False
# Word: aureolatum  Prediction: osmitopsis asteriscoides  Real: tick  Type: w2v
# Cosine Similarity: 0.7606687071986888
#
# BB-norm-18094887.a1
# False
# Word: cajennense  Prediction: ornithodoros moubata  Real: tick  Type: w2v
# Cosine Similarity: 0.7917204752838154
#
# BB-norm-18094887.a1
# False
# Word: dubitatum  Prediction: ornithodoros moubata  Real: tick  Type: w2v
# Cosine Similarity: 0.7582775496183451
#
# BB-norm-18094887.a1
# False
# Word: loricatus  Prediction: ornithodoros moubata  Real: tick  Type: w2v
# Cosine Similarity: 0.7668845015726576
#
# BB-norm-18094887.a1
# True
# Word: dogs  Prediction: dog  Real: dog  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# True
# Word: cats  Prediction: cat  Real: cat  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: opossums  Prediction: opossum  Real: opossum  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: fleas  Prediction: flea  Real: flea  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: ticks  Prediction: tick  Real: tick  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# False
# Word: animal blood  Prediction: animal blood  Real: blood  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# True
# Word: animal  Prediction: animal  Real: animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# False
# Word: human blood  Prediction: animal blood  Real: blood  Type: w2v
# Cosine Similarity: 0.9735626386800745
#
# BB-norm-18094887.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# True
# Word: animal  Prediction: animal  Real: animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# False
# Word: animal sera  Prediction: bovine serum  Real: blood serum  Type: w2v
# Cosine Similarity: 0.9572027738814164
#
# BB-norm-18094887.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# False
# Word: human sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9743639542459154
#
# BB-norm-18094887.a1
# False
# Word: opossum sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9546761051097313
#
# BB-norm-18094887.a1
# True
# Word: opossum  Prediction: opossum  Real: opossum  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# False
# Word: dog sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9644833575102851
#
# BB-norm-18094887.a1
# True
# Word: dog  Prediction: dog  Real: dog  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# True
# Word: horse  Prediction: horse  Real: horse  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# False
# Word: horse sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9694045953814181
#
# BB-norm-18094887.a1
# False
# Word: human sera  Prediction: bovine serum  Real: blood serum  Type: w2v
# Cosine Similarity: 0.9743639542459154
#
# BB-norm-18094887.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18094887.a1
# False
# Word: sera  Prediction: blood serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9654871823637456
#
# BB-norm-18094887.a1
# False
# Word: opossum sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9546761051097313
#
# BB-norm-18094887.a1
# True
# Word: opossum  Prediction: opossum  Real: opossum  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: dog  Prediction: dog  Real: dog  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# False
# Word: dog sera  Prediction: bovine serum  Real: blood serum  Type: w2v
# Cosine Similarity: 0.9644833575102851
#
# BB-norm-18094887.a1
# True
# Word: horse  Prediction: horse  Real: horse  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18094887.a1
# False
# Word: horse sera  Prediction: bovine serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9694045953814181
#
# BB-norm-18094887.a1
# True
# Word: animals  Prediction: animal  Real: animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18094887.a1
# True
# Word: humans  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18694716.a1
# False
# Word: spectrometer  Prediction: mudpit  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.6162458456402332
#
# BB-norm-18694716.a1
# False
# Word: mixtures of pure compounds and uniformly 13C labeled cell extracts  Prediction: waffle mixture  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9092951322891096
#
# BB-norm-18694716.a1
# True
# Word: 13C labeled cell  Prediction: cell  Real: cell  Type: w2v
# Cosine Similarity: 0.9392977184032971
#
# BB-norm-18694716.a1
# False
# Word: obitrap  Prediction: mudpit  Real: laboratory equipment  Type: w2v
# Cosine Similarity: 0.6558633472408458
#
# BB-norm-18789156.a1
# True
# Word: monocyte like THP 1 cells  Prediction: monocyte  Real: monocyte  Type: w2v
# Cosine Similarity: 0.979689626269067
#
# BB-norm-18789156.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18789156.a1
# True
# Word: immune cells  Prediction: immune cell  Real: immune cell  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-18789156.a1
# True
# Word: monocytes  Prediction: monocyte  Real: monocyte  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18789156.a1
# True
# Word: macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18789156.a1
# True
# Word: cell  Prediction: cell  Real: cell  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18789156.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18789156.a1
# True
# Word: human monocyte like THP 1 cells  Prediction: monocyte  Real: monocyte  Type: w2v
# Cosine Similarity: 0.9758841947534588
#
# BB-norm-18789156.a1
# False
# Word: monocyte like THP 1 cells  Prediction: monocyte  Real: cell culture  Type: w2v
# Cosine Similarity: 0.979689626269067
#
# BB-norm-18789156.a1
# True
# Word: monocyte like THP 1 cells  Prediction: monocyte  Real: monocyte  Type: w2v
# Cosine Similarity: 0.979689626269067
#
# BB-norm-18789156.a1
# True
# Word: murine  Prediction: murine  Real: murine  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18789156.a1
# False
# Word: monocyte like THP 1 cells  Prediction: monocyte  Real: cell culture  Type: w2v
# Cosine Similarity: 0.979689626269067
#
# BB-norm-18789156.a1
# True
# Word: cell  Prediction: cell  Real: cell  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-18789156.a1
# True
# Word: host tissues  Prediction: animal tissue  Real: animal tissue  Type: w2v
# Cosine Similarity: 0.958411521435702
#
# BB-norm-18789156.a1
# True
# Word: infected monocytes  Prediction: monocyte  Real: monocyte  Type: w2v
# Cosine Similarity: 0.9706145027786538
#
# BB-norm-18789156.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-18789156.a1
# False
# Word: monocyte like THP 1 cells  Prediction: monocyte  Real: cell culture  Type: w2v
# Cosine Similarity: 0.979689626269067
#
# BB-norm-19004249.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-19339076.a1
# True
# Word: Bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: Bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: lactose free M17 medium supplemented with glucose only (GM17)  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9480689582217074
#
# BB-norm-19339076.a1
# True
# Word: lactose free M17 medium supplemented with lactose only (LM17)  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9437512924179032
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9613376856929348
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9605151153508801
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9613376856929348
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9605151153508801
#
# BB-norm-19339076.a1
# True
# Word: GM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9613376856929348
#
# BB-norm-19339076.a1
# True
# Word: LM17 medium  Prediction: experimental medium  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9605151153508801
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19339076.a1
# True
# Word: bile  Prediction: bile  Real: bile  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-19552770.a1
# True
# Word: partridges  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-19552770.a1
# True
# Word: perdix  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.7480326242600588
#
# BB-norm-19552770.a1
# True
# Word: commercially reared partridges  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.953727633597148
#
# BB-norm-19552770.a1
# True
# Word: perdix  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.7480326242600588
#
# BB-norm-19552770.a1
# True
# Word: Cloacal swabs of partridges  Prediction: rectal swab  Real: rectal swab  Type: w2v
# Cosine Similarity: 0.952414983868979
#
# BB-norm-19552770.a1
# True
# Word: cloacal  Prediction: cloaca  Real: cloaca  Type: w2v
# Cosine Similarity: 0.8993378836664611
#
# BB-norm-19552770.a1
# True
# Word: partridges  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-19552770.a1
# False
# Word: male birds  Prediction: bird  Real: livestock  Type: w2v
# Cosine Similarity: 0.9630517001524614
#
# BB-norm-19552770.a1
# False
# Word: female birds  Prediction: bird  Real: partridge  Type: w2v
# Cosine Similarity: 0.9657266007521281
#
# BB-norm-19552770.a1
# True
# Word: game bird  Prediction: bird  Real: bird  Type: w2v
# Cosine Similarity: 0.9671631914463547
#
# BB-norm-19552770.a1
# False
# Word: game bird farm  Prediction: farm  Real: animal farm  Type: w2v
# Cosine Similarity: 0.9677094898245627
#
# BB-norm-19552770.a1
# False
# Word: cloacal swabs  Prediction: vaginal swab  Real: rectal swab  Type: w2v
# Cosine Similarity: 0.9692522158653497
#
# BB-norm-19552770.a1
# True
# Word: Adult partridges  Prediction: partridge  Real: partridge  Type: w2v
# Cosine Similarity: 0.9734581255494213
#
# BB-norm-19552770.a1
# False
# Word: one  Prediction: part of living organism  Real: livestock  Type: w2v
# Cosine Similarity: 0.6189224461295046
#
# BB-norm-19552770.a1
# True
# Word: game birds  Prediction: bird  Real: bird  Type: w2v
# Cosine Similarity: 0.9671631914463547
#
# BB-norm-19552770.a1
# True
# Word: human being  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-19552770.a1
# False
# Word: animal species  Prediction: invertebrate specie  Real: animal  Type: w2v
# Cosine Similarity: 0.9662597878861326
#
# BB-norm-19552770.a1
# False
# Word: commercially reared partridges  Prediction: partridge  Real: livestock  Type: w2v
# Cosine Similarity: 0.953727633597148
#
# BB-norm-20174624.a1
# True
# Word: Neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# True
# Word: cell  Prediction: cell  Real: cell  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# True
# Word: human innate immune system  Prediction: innate immune system  Real: innate immune system  Type: w2v
# Cosine Similarity: 0.9904506167150061
#
# BB-norm-20174624.a1
# True
# Word: macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20174624.a1
# False
# Word: polymorphonuclear leukocytes  Prediction: leukocyte  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9839922438843607
#
# BB-norm-20174624.a1
# True
# Word: neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word: pmns  Prediction: neutrophil  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.7733121151127524
#
# BB-norm-20174624.a1
# True
# Word: humans  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# True
# Word: murine macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 0.9784141314192732
#
# BB-norm-20174624.a1
# True
# Word: murine dendritic cells  Prediction: dendritic cell  Real: dendritic cell  Type: w2v
# Cosine Similarity: 0.98493557374008
#
# BB-norm-20174624.a1
# True
# Word: murine  Prediction: murine  Real: murine  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20174624.a1
# True
# Word: neutrophil  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# True
# Word: human monocyte derived macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 0.9743974039244071
#
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: breast milk  Real: macrophage  Type: w2v
# Cosine Similarity: 0.23260611375125098
#
# BB-norm-20174624.a1
# True
# Word: neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# True
# Word: hmdms  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 0.6433488112143037
#
# BB-norm-20174624.a1
# True
# Word: human neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 0.9713175679089459
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# False
# Word: pmns  Prediction: neutrophil  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.7668162214201035
#
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word: cell  Prediction: cell  Real: leukocyte  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# False
# Word: PMN cell  Prediction: cell  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9401098699777052
#
# BB-norm-20174624.a1
# True
# Word: human neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 0.9713175679089459
#
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# False
# Word: PMN cell  Prediction: cell  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.9401098699777052
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20174624.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-20174624.a1
# False
# Word:   Prediction: pocosin  Real: granulocyte  Type: w2v
# Cosine Similarity: 0.29624818556937205
#
# BB-norm-20580604.a1
# True
# Word: probiotic fermented milk beverage  Prediction: fermented beverage  Real: fermented beverage  Type: w2v
# Cosine Similarity: 0.9887037766328799
#
# BB-norm-20580604.a1
# False
# Word: intestinal  Prediction: extra-intestinal  Real: intestine  Type: w2v
# Cosine Similarity: 0.9664274150302425
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: waste treatment environment  Real: intestine  Type: w2v
# Cosine Similarity: 0.9218120704450875
#
# BB-norm-20580604.a1
# False
# Word: individual  Prediction: home-made food  Real: healthy person  Type: w2v
# Cosine Similarity: 0.699843831294453
#
# BB-norm-20580604.a1
# False
# Word: soft stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9632486302267214
#
# BB-norm-20580604.a1
# True
# Word: fermented milk beverage  Prediction: fermented beverage  Real: fermented beverage  Type: w2v
# Cosine Similarity: 0.9907735611830224
#
# BB-norm-20580604.a1
# False
# Word: bottle  Prediction: bottle  Real: fermented milk  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: probiotics  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: bottle  Prediction: bottle  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: intestinal  Prediction: extra-intestinal  Real: intestine  Type: w2v
# Cosine Similarity: 0.9664274150302425
#
# BB-norm-20580604.a1
# False
# Word: intestinal environment of healthy individuals with soft stools  Prediction: waste treatment environment  Real: intestine  Type: w2v
# Cosine Similarity: 0.9218120704450875
#
# BB-norm-20580604.a1
# False
# Word: individual  Prediction: home-made food  Real: healthy person  Type: w2v
# Cosine Similarity: 0.699843831294453
#
# BB-norm-20580604.a1
# False
# Word: soft stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9632486302267214
#
# BB-norm-20580604.a1
# False
# Word: healthy adults  Prediction: young adult  Real: adult human  Type: w2v
# Cosine Similarity: 0.9769039500567931
#
# BB-norm-20580604.a1
# False
# Word: soft stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9632486302267214
#
# BB-norm-20580604.a1
# False
# Word: probiotics  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-20580604.a1
# False
# Word: water content of the stools  Prediction: stomach content  Real: body fluid  Type: w2v
# Cosine Similarity: 0.9383322161093829
#
# BB-norm-20580604.a1
# False
# Word: stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: group  Prediction: high pressure treated food  Real: adult human  Type: w2v
# Cosine Similarity: 0.5901761226034099
#
# BB-norm-20580604.a1
# False
# Word: group  Prediction: high pressure treated food  Real: adult human  Type: w2v
# Cosine Similarity: 0.5940797200453599
#
# BB-norm-20580604.a1
# False
# Word: stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: stools  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-20580604.a1
# False
# Word: probiotics  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: group  Prediction: high pressure treated food  Real: adult human  Type: w2v
# Cosine Similarity: 0.5901761226034099
#
# BB-norm-20580604.a1
# False
# Word: probiotic  Prediction: probiotic  Real: probiotic food  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-20580604.a1
# False
# Word: group  Prediction: high pressure treated food  Real: adult human  Type: w2v
# Cosine Similarity: 0.5940797200453599
#
# BB-norm-20580604.a1
# True
# Word: probiotic fermented milk beverage  Prediction: fermented beverage  Real: fermented beverage  Type: w2v
# Cosine Similarity: 0.9887037766328799
#
# BB-norm-20580604.a1
# True
# Word: intestine  Prediction: intestine  Real: intestine  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-20580604.a1
# False
# Word: stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9760345989938791
#
# BB-norm-20580604.a1
# False
# Word: individual  Prediction: home-made food  Real: healthy person  Type: w2v
# Cosine Similarity: 0.699843831294453
#
# BB-norm-20580604.a1
# False
# Word: soft stool  Prediction: stool a furniture  Real: feces  Type: w2v
# Cosine Similarity: 0.9632486302267214
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perineum  Real: anus  Type: w2v
# Cosine Similarity: 0.8403470453697187
#
# BB-norm-21270066.a1
# False
# Word: ulceration  Prediction: skin ulcer  Real: ulcer  Type: w2v
# Cosine Similarity: 0.8748300830140687
#
# BB-norm-21270066.a1
# False
# Word: men  Prediction: elderly person  Real: man  Type: w2v
# Cosine Similarity: 0.6214993825272315
#
# BB-norm-21270066.a1
# False
# Word: men  Prediction: elderly person  Real: man  Type: w2v
# Cosine Similarity: 0.5900037908345536
#
# BB-norm-21270066.a1
# False
# Word:   Prediction: spirillum  Real: ill person  Type: w2v
# Cosine Similarity: 0.1359532579681842
#
# BB-norm-21270066.a1
# False
# Word: Patients  Prediction: patient  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-21270066.a1
# True
# Word: rectal  Prediction: rectum  Real: rectum  Type: w2v
# Cosine Similarity: 0.8313349958131394
#
# BB-norm-21270066.a1
# False
# Word: MSM  Prediction: urogenital tract part  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.41353276679824585
#
# BB-norm-21270066.a1
# True
# Word: sexually transmitted infection clinics  Prediction: clinic  Real: clinic  Type: w2v
# Cosine Similarity: 0.9316760310107014
#
# BB-norm-21270066.a1
# False
# Word: anorectal  Prediction: anus  Real: rectum  Type: w2v
# Cosine Similarity: 0.7513739984438642
#
# BB-norm-21270066.a1
# True
# Word: HIV infected patients presenting with isolated perianal ulcer disease  Prediction: patient with infectious disease  Real: patient with infectious disease  Type: w2v
# Cosine Similarity: 0.9642683066920414
#
# BB-norm-21270066.a1
# False
# Word: perianal ulcer  Prediction: skin ulcer  Real: ulcer  Type: w2v
# Cosine Similarity: 0.9741883424898813
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perineum  Real: anus  Type: w2v
# Cosine Similarity: 0.8403470453697187
#
# BB-norm-21270066.a1
# True
# Word: rectal  Prediction: rectum  Real: rectum  Type: w2v
# Cosine Similarity: 0.8313349958131394
#
# BB-norm-21270066.a1
# False
# Word: MSM  Prediction: obligate anaerobe  Real: ill person  Type: w2v
# Cosine Similarity: 0.26552007218714857
#
# BB-norm-21270066.a1
# False
# Word: MSM  Prediction: nasal passage abscess  Real: ill person  Type: w2v
# Cosine Similarity: 0.4046261599510861
#
# BB-norm-21270066.a1
# False
# Word: perianal  Prediction: perineum  Real: anus  Type: w2v
# Cosine Similarity: 0.8403470453697187
#
# BB-norm-21270066.a1
# False
# Word: perianal ulcer  Prediction: skin ulcer  Real: ulcer  Type: w2v
# Cosine Similarity: 0.9741883424898813
#
# BB-norm-21543877.a1
# False
# Word: population  Prediction: adult human  Real: human  Type: w2v
# Cosine Similarity: 0.6615626696562569
#
# BB-norm-21695078.a1
# True
# Word: infant  Prediction: infant  Real: infant  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# False
# Word: model  Prediction: animal with age or sex property  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 0.7420995864652806
#
# BB-norm-21695078.a1
# True
# Word: genital tract  Prediction: genital tract  Real: genital tract  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# False
# Word: oviduct  Prediction: uterus  Real: urogenital tract part  Type: w2v
# Cosine Similarity: 0.7421052166026868
#
# BB-norm-21695078.a1
# False
# Word: mucosal  Prediction: intestinal mucosa  Real: mucosal tissue  Type: w2v
# Cosine Similarity: 0.8846663736023412
#
# BB-norm-21695078.a1
# False
# Word: mice  Prediction: mouse  Real: female animal  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# False
# Word: intranasal  Prediction: aerosol  Real: nose  Type: w2v
# Cosine Similarity: 0.5715300211802832
#
# BB-norm-21695078.a1
# False
# Word: mice  Prediction: mouse  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# True
# Word: lung  Prediction: lung  Real: lung  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# True
# Word: neutrophils  Prediction: neutrophil  Real: neutrophil  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-21695078.a1
# False
# Word: T cells  Prediction: cell  Real: lymphocyte  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# True
# Word: lungs  Prediction: lung  Real: lung  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# False
# Word: TLR2 deficient mice  Prediction: mouse  Real: female animal  Type: w2v
# Cosine Similarity: 0.9722531034629665
#
# BB-norm-21695078.a1
# True
# Word: lung  Prediction: lung  Real: lung  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-21695078.a1
# False
# Word: mucosal  Prediction: intestinal mucosa  Real: mucosal tissue  Type: w2v
# Cosine Similarity: 0.8846663736023412
#
# BB-norm-21695078.a1
# True
# Word: mucosal surfaces  Prediction: mucosal surface  Real: mucosal surface  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-21894542.a1
# False
# Word: world's oceans  Prediction: open-ocean  Real: marine water  Type: w2v
# Cosine Similarity: 0.9503959557631596
#
# BB-norm-21894542.a1
# True
# Word: marine environments  Prediction: marine environment  Real: marine environment  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-21894542.a1
# True
# Word: bacterial flora  Prediction: microflora  Real: microflora  Type: w2v
# Cosine Similarity: 0.9030760327846273
#
# BB-norm-21894542.a1
# True
# Word: marine organisms  Prediction: living organism  Real: living organism  Type: w2v
# Cosine Similarity: 0.9445164406949242
#
# BB-norm-23902156.a1
# False
# Word: Penicillium sensitive atopic sera  Prediction: non-immune serum  Real: experimental medium  Type: w2v
# Cosine Similarity: 0.9362796980787571
#
# BB-norm-25114119.a1
# False
# Word: mice  Prediction: mouse  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-25114119.a1
# False
# Word: SCID mice  Prediction: mouse  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 0.9777746590892246
#
# BB-norm-25114119.a1
# True
# Word: aerosol  Prediction: aerosol  Real: aerosol  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-25114119.a1
# True
# Word: aerosolized  Prediction: aerosol  Real: aerosol  Type: w2v
# Cosine Similarity: 0.7757260405601937
#
# BB-norm-25114119.a1
# True
# Word: murine  Prediction: murine  Real: murine  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-25114119.a1
# False
# Word: mice  Prediction: mouse  Real: laboratory mouse  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-25114119.a1
# True
# Word: macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-25114119.a1
# True
# Word: human  Prediction: human  Real: human  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-25114119.a1
# True
# Word: human macrophages  Prediction: macrophage  Real: macrophage  Type: w2v
# Cosine Similarity: 0.9725161437076708
#
# ...
# Cosine Similarity: 0.3052505019322027
#
# BB-norm-F-20167385-004.a1
# False
# Word: Casera cheeses  Prediction: cheese  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9759205848192153
#
# BB-norm-F-20167385-004.a1
# False
# Word: Taleggio cheeses  Prediction: cheese  Real: taleggio  Type: w2v
# Cosine Similarity: 0.976766374173662
#
# BB-norm-F-20167385-004.a1
# False
# Word: Gorgonzola cheeses  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-004.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-004.a1
# True
# Word: Rogosa agar  Prediction: agar  Real: agar  Type: w2v
# Cosine Similarity: 0.9774999329751263
#
# BB-norm-F-20167385-004.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-004.a1
# True
# Word: cheese surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-004.a1
# True
# Word: Pseudomonas agar  Prediction: agar  Real: agar  Type: w2v
# Cosine Similarity: 0.9645367010553095
#
# BB-norm-F-20167385-004.a1
# True
# Word: Gorgonzola surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9601732061670537
#
# BB-norm-F-20167385-004.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-004.a1
# True
# Word: Scimudin surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9415840728757642
#
# BB-norm-F-20167385-004.a1
# True
# Word: Scimudin  Prediction: scimudin  Real: scimudin  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-20167385-004.a1
# True
# Word: Taleggio  Prediction: taleggio  Real: taleggio  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-004.a1
# True
# Word: Taleggio surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9495367236250214
#
# BB-norm-F-20167385-004.a1
# True
# Word: Casera  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9729921943268589
#
# BB-norm-F-20167385-004.a1
# True
# Word: Formaggio di Fossa  Prediction: formaggio di fossa  Real: formaggio di fossa  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-004.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-004.a1
# True
# Word: cheese surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-005.a1
# False
# Word: Scimudin cheese  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-006.a1
# False
# Word: Taleggio cheeses  Prediction: cheese  Real: taleggio  Type: w2v
# Cosine Similarity: 0.976766374173662
#
# BB-norm-F-20167385-006.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-006.a1
# False
# Word: Gorgonzola cheese  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-006.a1
# False
# Word: Taleggio cheeses  Prediction: cheese  Real: taleggio  Type: w2v
# Cosine Similarity: 0.976766374173662
#
# BB-norm-F-20167385-006.a1
# False
# Word: Casera cheeses  Prediction: cheese  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9759205848192153
#
# BB-norm-F-20167385-006.a1
# True
# Word: Scimudin  Prediction: scimudin  Real: scimudin  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-20167385-006.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-006.a1
# True
# Word: Taleggio  Prediction: taleggio  Real: taleggio  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-006.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-006.a1
# False
# Word: Taleggio cheeses  Prediction: cheese  Real: taleggio  Type: w2v
# Cosine Similarity: 0.976766374173662
#
# BB-norm-F-20167385-006.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-006.a1
# False
# Word: Casera cheeses  Prediction: cheese  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9759205848192153
#
# BB-norm-F-20167385-006.a1
# False
# Word: Gorgonzola cheeses  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-006.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-006.a1
# True
# Word: Scimudin  Prediction: scimudin  Real: scimudin  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-20167385-006.a1
# True
# Word: Taleggio  Prediction: taleggio  Real: taleggio  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-007.a1
# True
# Word: microbiota  Prediction: microflora  Real: microflora  Type: w2v
# Cosine Similarity: 0.8761803699868432
#
# BB-norm-F-20167385-007.a1
# True
# Word: microbiota  Prediction: microflora  Real: microflora  Type: w2v
# Cosine Similarity: 0.8847228969144936
#
# BB-norm-F-20167385-007.a1
# True
# Word: microbiota  Prediction: microflora  Real: microflora  Type: w2v
# Cosine Similarity: 0.862229507796636
#
# BB-norm-F-20167385-007.a1
# False
# Word: Formaggio di Fossa cheeses  Prediction: streched curd cheese  Real: formaggio di fossa  Type: w2v
# Cosine Similarity: 0.954841197848903
#
# BB-norm-F-20167385-007.a1
# False
# Word: Gorgonzola cheeses  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-007.a1
# False
# Word: Taleggio  cheeses  Prediction: cheese  Real: taleggio  Type: w2v
# Cosine Similarity: 0.976766374173662
#
# BB-norm-F-20167385-008.a1
# True
# Word: white mould rind  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9540195653722688
#
# BB-norm-F-20167385-008.a1
# False
# Word: Scimudin cheese  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-008.a1
# True
# Word: valtellina  Prediction: valtellina casera  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.8811614871455461
#
# BB-norm-F-20167385-008.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-008.a1
# False
# Word: rind  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9791910080217243
#
# BB-norm-F-20167385-009.a1
# False
# Word: Casera cheese  Prediction: cheese  Real: valtellina casera  Type: w2v
# Cosine Similarity: 0.9759205848192153
#
# BB-norm-F-20167385-009.a1
# True
# Word: Casera cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9834803052664585
#
# BB-norm-F-20167385-009.a1
# True
# Word: Gorgonzola cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9852592998319119
#
# BB-norm-F-20167385-009.a1
# False
# Word: Gorgonzola cheese  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-009.a1
# False
# Word: Scimudin cheese  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-009.a1
# True
# Word: Scimudin cheese  surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9864664225811108
#
# BB-norm-F-20167385-009.a1
# True
# Word: smear cheeses  Prediction: smear ripened cheese  Real: smear ripened cheese  Type: w2v
# Cosine Similarity: 0.9880842640257074
#
# BB-norm-F-20167385-010.a1
# True
# Word: cheese rinds  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-010.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-010.a1
# True
# Word: rind of Gorgonzola cheeses  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9903940504289233
#
# BB-norm-F-20167385-010.a1
# True
# Word: rind of Scimudin cheeses  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9900661154813011
#
# BB-norm-F-20167385-010.a1
# False
# Word: Gorgonzola cheeses  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-010.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-010.a1
# True
# Word: surface of Gobbeen cheese  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.986460603161131
#
# BB-norm-F-20167385-010.a1
# False
# Word: Gobbeen cheese  Prediction: cheese  Real: gubbeen  Type: w2v
# Cosine Similarity: 0.9804334166405914
#
# BB-norm-F-20167385-011.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-011.a1
# True
# Word: cheese surface  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-011.a1
# True
# Word: Fontina cheese surface  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9731318334824949
#
# BB-norm-F-20167385-011.a1
# False
# Word: Fontina cheese  Prediction: brined cheese  Real: fontina  Type: w2v
# Cosine Similarity: 0.9649924049159686
#
# BB-norm-F-20167385-011.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola rind  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9742519827163115
#
# BB-norm-F-20167385-011.a1
# True
# Word: Taleggio  Prediction: taleggio  Real: taleggio  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-011.a1
# False
# Word: Taleggio rind  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9684565333304416
#
# BB-norm-F-20167385-011.a1
# True
# Word: surface of Gorgonzola cheeses  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9852592998319119
#
# BB-norm-F-20167385-011.a1
# True
# Word: surface of Scimudin cheeses  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9864664225811108
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola cheeses  Prediction: cheese  Real: gorgonzola  Type: w2v
# Cosine Similarity: 0.9813142160901855
#
# BB-norm-F-20167385-011.a1
# False
# Word: Scimudin cheeses  Prediction: cheese  Real: scimudin  Type: w2v
# Cosine Similarity: 0.9807977384628713
#
# BB-norm-F-20167385-011.a1
# False
# Word: Formaggio di Fossa cheese  Prediction: streched curd cheese  Real: formaggio di fossa  Type: w2v
# Cosine Similarity: 0.954841197848903
#
# BB-norm-F-20167385-011.a1
# False
# Word: fermented fish  Prediction: cooked fish  Real: fermented fish product  Type: w2v
# Cosine Similarity: 0.9744909733390658
#
# BB-norm-F-20167385-011.a1
# True
# Word: Greek cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.972445813386533
#
# BB-norm-F-20167385-011.a1
# True
# Word: Scimudin surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9415840728757642
#
# BB-norm-F-20167385-011.a1
# True
# Word: Scimudin  Prediction: scimudin  Real: scimudin  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-20167385-011.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-011.a1
# True
# Word: Gorgonzola surfaces  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9601732061670537
#
# BB-norm-F-20167385-011.a1
# True
# Word: Fontina  Prediction: fontina  Real: fontina  Type: w2v
# Cosine Similarity: 0.9999999999999999
#
# BB-norm-F-20167385-011.a1
# False
# Word: Fontina rind  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9568917446372224
#
# BB-norm-F-20167385-011.a1
# True
# Word: Gorgonzola  Prediction: gorgonzola  Real: gorgonzola  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-011.a1
# False
# Word: Gorgonzola rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9742519827163115
#
# BB-norm-F-20167385-013.a1
# True
# Word: cheese surface  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-20167385-013.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-20167385-014.a1
# True
# Word: surface of Formaggio di  Fossa cheese  Prediction: surface of cheese  Real: surface of cheese  Type: w2v
# Cosine Similarity: 0.9537401377679332
#
# BB-norm-F-20167385-014.a1
# False
# Word: Formaggio di  Fossa cheese  Prediction: streched curd cheese  Real: formaggio di fossa  Type: w2v
# Cosine Similarity: 0.954841197848903
#
# BB-norm-F-20167385-015.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-000.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-000.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-000.a1
# False
# Word: food  Prediction: food  Real: food for human  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-000.a1
# True
# Word: marine environments  Prediction: marine environment  Real: marine environment  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-25036636-000.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-000.a1
# False
# Word: cheese communities  Prediction: community  Real: microflora  Type: w2v
# Cosine Similarity: 0.9500708512411541
#
# BB-norm-F-25036636-001.a1
# False
# Word: moist bloomy rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9615806116983527
#
# BB-norm-F-25036636-001.a1
# False
# Word: dry natural rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9553371664102025
#
# BB-norm-F-25036636-002.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-003.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-003.a1
# True
# Word: cheeses  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-003.a1
# True
# Word: cheeses  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-003.a1
# False
# Word: polar seawater  Prediction: polluted seawater  Real: marine water  Type: w2v
# Cosine Similarity: 0.9587015666250456
#
# BB-norm-F-25036636-004.a1
# True
# Word: cheeses  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-004.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-004.a1
# True
# Word: cheese rind  Prediction: cheese rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-005.a1
# True
# Word: cheese  Prediction: cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9999999999999998
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-005.a1
# True
# Word: raw milk  Prediction: raw milk  Real: raw milk  Type: w2v
# Cosine Similarity: 1.0000000000000002
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-005.a1
# False
# Word: rinds  Prediction: cantaloupe rind  Real: cheese rind  Type: w2v
# Cosine Similarity: 0.9791910080217243
#
# BB-norm-F-25036636-005.a1
# False
# Word: community  Prediction: community  Real: microflora  Type: w2v
# Cosine Similarity: 1.0
#
# BB-norm-F-25036636-005.a1
# False
# Word: mature cheeses  Prediction: processed cheese  Real: cheese  Type: w2v
# Cosine Similarity: 0.9738006239239174

# %%
recall = true_pred_count/total_count
recall
# Out:
# 0.5540983606557377

# %%
precision = true_pred_count/(true_pred_count + false_pred_count)
precision
# Out:
# 0.5540983606557377

# %% [markdown]
# ## Denemeler

# %%
qwe = get_phrase_embedding("gastric mucosal",model,phrase_reducer)
ewq = get_phrase_embedding("gastric mucosa",model,phrase_reducer)
np.dot(qwe,ewq)/(norm(qwe)*norm(ewq))
# Out:
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:14: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
#
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:21: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# C:\Users\eges9\Anaconda3\lib\site-packages\ipykernel_launcher.py:29: DeprecationWarning: Call to deprecated `__getitem__` (Method will be removed in 4.0.0, use self.wv.__getitem__() instead).
# 0.9562591972720985
